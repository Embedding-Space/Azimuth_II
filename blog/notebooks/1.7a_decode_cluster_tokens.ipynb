# %% [markdown]
# # 1.7a: Decode Cluster Tokens
#
# This notebook decodes all 2,212 cluster tokens to see what text they represent.
#
# ## The Question
#
# We've found a geometrically anomalous cluster: 2,212 tokens packed into a tiny volume (diameter ~0.0016), isolated from the rest of the vocabulary by a conspicuous void.
#
# **What *are* these tokens?**
#
# This is where geometric cartography meets linguistics. We have token IDs—now let's see what they decode to.
#
# ## Method
#
# We'll:
# 1. Load the cluster token IDs from 1.4h
# 2. Sort by token ID (BPE natural order)
# 3. Decode each token with the tokenizer
# 4. Build a dataframe with metadata (byte length, printability, script)
# 5. Display the full table and summary statistics

# %% [markdown]
# ## Parameters

# %%
# Model to analyze
MODEL_NAME = "Qwen3-4B-Instruct-2507"
HF_MODEL_NAME = "Qwen/Qwen3-4B-Instruct-2507"

# %% [markdown]
# ## Imports

# %%
import torch
import pandas as pd
import unicodedata
from safetensors.torch import load_file
from pathlib import Path
from transformers import AutoTokenizer
from collections import Counter

# %% [markdown]
# ## Load Cluster Token IDs

# %%
# Load cluster tokens from 1.4h
tensor_path = Path(f"../tensors/{MODEL_NAME}/1.4h_cluster_tokens.safetensors")
data = load_file(tensor_path)
cluster_token_ids = data['cluster_token_ids']

print(f"Loaded {len(cluster_token_ids):,} cluster token IDs from {tensor_path.name}")
print(f"  Token ID range: [{cluster_token_ids.min().item()}, {cluster_token_ids.max().item()}]")
# Out:
# Loaded 2,212 cluster token IDs from 1.4h_cluster_tokens.safetensors
#   Token ID range: [124, 151935]

# %%
# Sort by token ID (BPE natural order)
cluster_token_ids_sorted = torch.sort(cluster_token_ids)[0]

print(f"\nSorted token IDs:")
print(f"  First 10: {cluster_token_ids_sorted[:10].tolist()}")
print(f"  Last 10: {cluster_token_ids_sorted[-10:].tolist()}")
# Out:
# Sorted token IDs:
#   First 10: [124, 125, 177, 178, 179, 180, 181, 182, 183, 184]
#   Last 10: [151926, 151927, 151928, 151929, 151930, 151931, 151932, 151933, 151934, 151935]

# %% [markdown]
# ## Load Tokenizer

# %%
print(f"\nLoading tokenizer from {HF_MODEL_NAME}...\n")
tokenizer = AutoTokenizer.from_pretrained(HF_MODEL_NAME)
print(f"✓ Tokenizer loaded")
print(f"  Vocabulary size: {len(tokenizer):,} tokens")
# Out:
# Loading tokenizer from Qwen/Qwen3-4B-Instruct-2507...
#
# ✓ Tokenizer loaded
#   Vocabulary size: 151,669 tokens

# %% [markdown]
# ## Helper Functions

# %%
def classify_script(text):
    """
    Classify text by dominant script using Unicode properties.
    Returns primary script name (e.g., 'Thai', 'Han', 'Latin').
    """
    if not text or not text.strip():
        return 'Empty/Whitespace'
    
    # Count characters by script
    script_counts = Counter()
    
    for char in text:
        # Skip whitespace and control characters for classification
        if char.isspace() or unicodedata.category(char).startswith('C'):
            continue
            
        # Get Unicode script name
        try:
            script = unicodedata.name(char).split()[0]
            script_counts[script] += 1
        except (ValueError, IndexError):
            # Handle characters without names or unnamed characters
            category = unicodedata.category(char)
            if category.startswith('P'):
                script_counts['Punctuation'] += 1
            elif category.startswith('S'):
                script_counts['Symbol'] += 1
            else:
                script_counts['Other'] += 1
    
    if not script_counts:
        return 'Empty/Whitespace'
    
    # Return most common script
    return script_counts.most_common(1)[0][0]


def is_printable(text):
    """
    Check if text contains only printable characters.
    """
    if not text:
        return False
    
    for char in text:
        cat = unicodedata.category(char)
        # Allow letters, numbers, punctuation, symbols, and whitespace
        # Exclude control characters (Cc, Cf, Co, Cn)
        if cat.startswith('C') and not char.isspace():
            return False
    
    return True


print("Helper functions defined:")
print("  classify_script(text) - Identify dominant Unicode script")
print("  is_printable(text) - Check if all characters are printable")
# Out:
# Helper functions defined:
#   classify_script(text) - Identify dominant Unicode script
#   is_printable(text) - Check if all characters are printable

# %% [markdown]
# ## Decode All Tokens

# %%
print(f"\nDecoding {len(cluster_token_ids_sorted):,} tokens...\n")

# Build list of records
records = []

for token_id in cluster_token_ids_sorted:
    tid = token_id.item()
    
    # Decode
    decoded = tokenizer.decode([tid])
    
    # Compute metadata
    byte_len = len(decoded.encode('utf-8'))
    printable = is_printable(decoded)
    script = classify_script(decoded)
    
    records.append({
        'token_id': tid,
        'decoded': decoded,
        'byte_length': byte_len,
        'printable': printable,
        'script': script,
    })

# Create dataframe
df = pd.DataFrame(records)

print(f"✓ Decoded {len(df):,} tokens")
print(f"\nDataframe shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
# Out:
# Decoding 2,212 tokens...
#
# ✓ Decoded 2,212 tokens
#
# Dataframe shape: (2212, 5)
# Columns: ['token_id', 'decoded', 'byte_length', 'printable', 'script']

# %% [markdown]
# ## Summary Statistics

# %%
print("\n" + "="*60)
print("CLUSTER TOKEN SUMMARY")
print("="*60)

print(f"\nTotal tokens: {len(df):,}")
print(f"\nByte length statistics:")
print(f"  Min: {df['byte_length'].min()}")
print(f"  Max: {df['byte_length'].max()}")
print(f"  Mean: {df['byte_length'].mean():.2f}")
print(f"  Median: {df['byte_length'].median():.0f}")

print(f"\nPrintability:")
print(f"  Printable: {df['printable'].sum():,} ({100*df['printable'].sum()/len(df):.1f}%)")
print(f"  Non-printable: {(~df['printable']).sum():,} ({100*(~df['printable']).sum()/len(df):.1f}%)")

print(f"\nScript distribution:")
script_counts = df['script'].value_counts()
for script, count in script_counts.items():
    pct = 100 * count / len(df)
    print(f"  {script:20s}: {count:4,} ({pct:5.1f}%)")

print("\n" + "="*60)
# Out:
# ============================================================
# CLUSTER TOKEN SUMMARY
# ============================================================
#
# Total tokens: 2,212
#
# Byte length statistics:
#   Min: 0
#   Max: 42
#   Mean: 11.29
#   Median: 12
#
# Printability:
#   Printable: 1,945 (87.9%)
#   Non-printable: 267 (12.1%)
#
# Script distribution:
#   THAI                : 1,579 ( 71.4%)
#   Empty/Whitespace    :  267 ( 12.1%)
#   CJK                 :  198 (  9.0%)
#   ARABIC              :   75 (  3.4%)
#   HEBREW              :   25 (  1.1%)
#   LATIN               :   25 (  1.1%)
#   REPLACEMENT         :   18 (  0.8%)
#   GREEK               :   12 (  0.5%)
#   LESS-THAN           :    3 (  0.1%)
#   FULLWIDTH           :    2 (  0.1%)
#   OHM                 :    1 (  0.0%)
#   LEFT-POINTING       :    1 (  0.0%)
#   TIBETAN             :    1 (  0.0%)
#   ANGSTROM            :    1 (  0.0%)
#   KELVIN              :    1 (  0.0%)
#   DEVANAGARI          :    1 (  0.0%)
#   BENGALI             :    1 (  0.0%)
#   RIGHT-POINTING      :    1 (  0.0%)
#
# ============================================================

# %% [markdown]
# ## Full Token Table

# %%
# Display settings for full table
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 50)

print(f"\nFull table of {len(df):,} cluster tokens:\n")
display(df)
# Out:
# Full table of 2,212 cluster tokens:
#       token_id               decoded  byte_length  printable            script
# 0          124                     �            3       True       REPLACEMENT
# 1          125                     �            3       True       REPLACEMENT
# 2          177                     �            3       True       REPLACEMENT
# 3          178                     �            3       True       REPLACEMENT
# 4          179                     �            3       True       REPLACEMENT
# 5          180                     �            3       True       REPLACEMENT
# 6          181                     �            3       True       REPLACEMENT
# 7          182                     �            3       True       REPLACEMENT
# 8          183                     �            3       True       REPLACEMENT
# 9          184                     �            3       True       REPLACEMENT
# 10         185                     �            3       True       REPLACEMENT
# 11         186                     �            3       True       REPLACEMENT
# 12         187                     �            3       True       REPLACEMENT
# 13       77150                    １０            6       True         FULLWIDTH
# 14       80091                    ２０            6       True         FULLWIDTH
# 15       83971        $PostalCodesNL           14       True             LATIN
# 16      119346                    珊�            6       True               CJK
# 17      119347                    珊�            6       True               CJK
# 18      119348                    珊�            6       True               CJK
# 19      119349                    珊󠄁            7       True               CJK
# 20      123806                     �            3       True       REPLACEMENT
# 21      123821                     �            3       True       REPLACEMENT
# 22      123828                   ที่            9       True              THAI
# 23      123848                     �            3       True       REPLACEMENT
# 24      123870                     �            3       True       REPLACEMENT
# 25      123876                     �            3       True       REPLACEMENT
# 26      123939                    ร์            6       True              THAI
# 27      123948                    ติ            6       True              THAI
# 28      123952                    ด้            6       True              THAI
# 29      124027                  เป็น           12       True              THAI
# 30      124030                   ว่า            9       True              THAI
# 31      124031                    มี            6       True              THAI
# 32      124033                   ไม่            9       True              THAI
# 33      124055                   ได้            9       True              THAI
# 34      124060                    ริ            6       True              THAI
# 35      124076                    ก็            6       True              THAI
# 36      124083                   ั้ง            9       True              THAI
# 37      124084                   รับ            9       True              THAI
# 38      124105                   ให้            9       True              THAI
# 39      124121                    วิ            6       True              THAI
# 40      124129                   อร์            9       True              THAI
# 41      124132                    สิ            6       True              THAI
# 42      124139                   นี้            9       True              THAI
# 43      124171                    ต่            6       True              THAI
# 44      124175                    คุ            6       True              THAI
# 45      124178                   ื่อ            9       True              THAI
# 46      124212                  ื่อง           12       True              THAI
# 47      124238                    สั            6       True              THAI
# 48      124254                   กัน            9       True              THAI
# 49      124258                   ผู้            9       True              THAI
# 50      124294                    วั            6       True              THAI
# 51      124311                    ดี            6       True              THAI
# 52      124316                   คุณ            9       True              THAI
# 53      124350                  เรีย           12       True              THAI
# 54      124361                    ณ์            6       True              THAI
# 55      124377                   กับ            9       True              THAI
# 56      124380                 อย่าง           15       True              THAI
# 57      124383                  ต้อง           12       True              THAI
# 58      124403                   นัก            9       True              THAI
# 59      124418                   สุด            9       True              THAI
# 60      124439                   รู้            9       True              THAI
# 61      124440                   ี่ย            9       True              THAI
# 62      124458                    ตุ            6       True              THAI
# 63      124479                   ตัว            9       True              THAI
# 64      124482                   ใช้            9       True              THAI
# 65      124484                    นั            6       True              THAI
# 66      124496                    ทุ            6       True              THAI
# 67      124497                   ยัง            9       True              THAI
# 68      124500                    ขึ            6       True              THAI
# 69      124501                  ขึ้น           12       True              THAI
# 70      124502                    ก่            6       True              THAI
# 71      124512                    ที            6       True              THAI
# 72      124524                   ื้อ            9       True              THAI
# 73      124530                    ค่            6       True              THAI
# 74      124531                   ช่ว            9       True              THAI
# 75      124540                   บริ            9       True              THAI
# 76      124559                    พิ            6       True              THAI
# 77      124568                    ธิ            6       True              THAI
# 78      124573                    ค์            6       True              THAI
# 79      124602                  แล้ว           12       True              THAI
# 80      124604                  ด้วย           12       True              THAI
# 81      124608                   แต่            9       True              THAI
# 82      124610                  อยู่           12       True              THAI
# 83      124620                  เข้า           12       True              THAI
# 84      124627                    อี            6       True              THAI
# 85      124630                   วัน            9       True              THAI
# 86      124652                   ค้า            9       True              THAI
# 87      124658                    ย์            6       True              THAI
# 88      124673                    รี            6       True              THAI
# 89      124707                    ต์            6       True              THAI
# 90      124731                    บุ            6       True              THAI
# 91      124737                   พัน            9       True              THAI
# 92      124742                   าร์            9       True              THAI
# 93      124767                  หน้า           12       True              THAI
# 94      124769                   ต่อ            9       True              THAI
# 95      124770                  ทั้ง           12       True              THAI
# 96      124779                   ึ่ง            9       True              THAI
# 97      124783                เรื่อง           18       True              THAI
# 98      124831                  ส่วน           12       True              THAI
# 99      124832                   ลัง            9       True              THAI
# 100     124845                  ตั้ง           12       True              THAI
# 101     124849                 สร้าง           15       True              THAI
# 102     124850                    ชี            6       True              THAI
# 103     124854                   รัก            9       True              THAI
# 104     124859                  ต่าง           12       True              THAI
# 105     124860                 ครั้ง           15       True              THAI
# 106     124866                   ิ่ม            9       True              THAI
# 107     124884                    ชั            6       True              THAI
# 108     124891                    รั            6       True              THAI
# 109     124903                    กิ            6       True              THAI
# 110     124918                    พื            6       True              THAI
# 111     124926                  ื่อน           12       True              THAI
# 112     124939                    อั            6       True              THAI
# 113     124942                   เร็            9       True              THAI
# 114     124946                  ชาติ           12       True              THAI
# 115     124963                    ทั            6       True              THAI
# 116     124986                    ด์            6       True              THAI
# 117     125015                  นั้น           12       True              THAI
# 118     125016                   น้ำ            9       True              THAI
# 119     125026                  หรือ           12       True              THAI
# 120     125031                   อีก            9       True              THAI
# 121     125034                   ทุก            9       True              THAI
# 122     125047                    ปี            6       True              THAI
# 123     125053                  กว่า           12       True              THAI
# 124     125060                   ส่ง            9       True              THAI
# 125     125062                   ถูก            9       True              THAI
# 126     125063                   จัด            9       True              THAI
# 127     125071                  เห็น           12       True              THAI
# 128     125073                    นิ            6       True              THAI
# 129     125079                  เกิด           12       True              THAI
# 130     125082                    มิ            6       True              THAI
# 131     125084                 ทำให้           15       True              THAI
# 132     125087                  ช่วย           12       True              THAI
# 133     125095                    สู            6       True              THAI
# 134     125104                   ข้อ            9       True              THAI
# 135     125112                   น่า            9       True              THAI
# 136     125125                    สุ            6       True              THAI
# 137     125130                   คิด            9       True              THAI
# 138     125133                    น์            6       True              THAI
# 139     125140                   ร่ว            9       True              THAI
# 140     125141                  ร่วม           12       True              THAI
# 141     125142                    รุ            6       True              THAI
# 142     125147                   ติด            9       True              THAI
# 143     125181                 เรียน           15       True              THAI
# 144     125195                   กิจ            9       True              THAI
# 145     125213                   ปัญ            9       True              THAI
# 146     125219                   ดัง            9       True              THAI
# 147     125226                  พื้น           12       True              THAI
# 148     125279                   บัน            9       True              THAI
# 149     125292                  เหตุ           12       True              THAI
# 150     125294                   พัก            9       True              THAI
# 151     125297                    ล์            6       True              THAI
# 152     125306                   ศึก            9       True              THAI
# 153     125337                   ตร์            9       True              THAI
# 154     125359                 การณ์           15       True              THAI
# 155     125363                    ยุ            6       True              THAI
# 156     125366                   ถือ            9       True              THAI
# 157     125392                   สิท            9       True              THAI
# 158     125393                 สิทธิ           15       True              THAI
# 159     125396                  พันธ           12       True              THAI
# 160     125398                    มั            6       True              THAI
# 161     125436                   ถึง            9       True              THAI
# 162     125441                    ดู            6       True              THAI
# 163     125442                   แต่           10       True              THAI
# 164     125454                   มัน            9       True              THAI
# 165     125458                  ซึ่ง           12       True              THAI
# 166     125459                  ครับ           12       True              THAI
# 167     125460                  บ้าน           12       True              THAI
# 168     125488                  เล่น           12       True              THAI
# 169     125491                   คือ            9       True              THAI
# 170     125499                สำหรับ           18       True              THAI
# 171     125507               เครื่อง           21       True              THAI
# 172     125514                   สิน            9       True              THAI
# 173     125517                  เปิด           12       True              THAI
# 174     125518                   ค่า            9       True              THAI
# 175     125527                  ใหญ่           12       True              THAI
# 176     125538                  เจ้า           12       True              THAI
# 177     125552                   มือ            9       True              THAI
# 178     125554                    รู            6       True              THAI
# 179     125557                   ต้น            9       True              THAI
# 180     125564                   เด็            9       True              THAI
# 181     125566                   ทีม            9       True              THAI
# 182     125576                  แห่ง           12       True              THAI
# 183     125577                   ดับ            9       True              THAI
# 184     125597                  ร้าน           12       True              THAI
# 185     125605                ที่สุด           18       True              THAI
# 186     125611                 พร้อม           15       True              THAI
# 187     125613                บริการ           18       True              THAI
# 188     125622                   ุ่ม            9       True              THAI
# 189     125623                   ถ้า            9       True              THAI
# 190     125627                 เพิ่ม           15       True              THAI
# 191     125636                ได้รับ           18       True              THAI
# 192     125654                 เดียว           15       True              THAI
# 193     125655                มีความ           18       True              THAI
# 194     125663                  สิ่ง           12       True              THAI
# 195     125667                  หลัก           12       True              THAI
# 196     125680                   หัว            9       True              THAI
# 197     125687                   อัน            9       True              THAI
# 198     125688                  ี่ยว           12       True              THAI
# 199     125690                  เดิน           12       True              THAI
# 200     125707                    ยิ            6       True              THAI
# 201     125710                    ธี            6       True              THAI
# 202     125734                    อุ            6       True              THAI
# 203     125736                 ปัญหา           15       True              THAI
# 204     125739                   อื่            9       True              THAI
# 205     125740                  อื่น           12       True              THAI
# 206     125752                   ไม้            9       True              THAI
# 207     125753                  กลับ           12       True              THAI
# 208     125771                  ช่วง           12       True              THAI
# 209     125794                    ลี            6       True              THAI
# 210     125803                  ง่าย           12       True              THAI
# 211     125816                  เท่า           12       True              THAI
# 212     125835                   สุข            9       True              THAI
# 213     125850                    ท์            6       True              THAI
# 214     125853                 กล่าว           15       True              THAI
# 215     125858                   เติ            9       True              THAI
# 216     125860                    จุ            6       True              THAI
# 217     125869                  เร็ว           12       True              THAI
# 218     125872                 เชื่อ           15       True              THAI
# 219     125878                   ริม            9       True              THAI
# 220     125885                  ชั่น           12       True              THAI
# 221     125887                เนื่อง           18       True              THAI
# 222     125891                   สัง            9       True              THAI
# 223     125892                  เที่           12       True              THAI
# 224     125893                เที่ยว           18       True              THAI
# 225     125914                  ผลิต           12       True              THAI
# 226     125918                 ศึกษา           15       True              THAI
# 227     125919                    บั            6       True              THAI
# 228     125934                   ทุน            9       True              THAI
# 229     125950                  ทั่ว           12       True              THAI
# 230     125956                   ภัย            9       True              THAI
# 231     125972                ศาสตร์           18       True              THAI
# 232     125987                    ทิ            6       True              THAI
# 233     126012                    مْ            4       True            ARABIC
# 234     126021                  วิทย           12       True              THAI
# 235     126022                 วิทยา           15       True              THAI
# 236     126036                   แก้            9       True              THAI
# 237     126044                  องค์           12       True              THAI
# 238     126078                    ห์            6       True              THAI
# 239     126088                   นด์            9       True              THAI
# 240     126105                  เกิน           12       True              THAI
# 241     126125                    พุ            6       True              THAI
# 242     126140                   สัม            9       True              THAI
# 243     126152                 พันธ์           15       True              THAI
# 244     126156                  กรุง           12       True              THAI
# 245     126169                    ลุ            6       True              THAI
# 246     126171                  หมู่           12       True              THAI
# 247     126233                  ใหม่           12       True              THAI
# 248     126240                  ซึ่ง           13       True              THAI
# 249     126243                 เพื่อ           15       True              THAI
# 250     126248                  เงิน           12       True              THAI
# 251     126250                    มี            7       True              THAI
# 252     126261                  ก่อน           12       True              THAI
# 253     126268                    สี            6       True              THAI
# 254     126275                  เลือ           12       True              THAI
# 255     126296                  ด้าน           12       True              THAI
# 256     126301                   ไว้            9       True              THAI
# 257     126308                   ลูก            9       True              THAI
# 258     126314                  หลัง           12       True              THAI
# 259     126315                  ข่าว           12       True              THAI
# 260     126316                 เมือง           15       True              THAI
# 261     126324                  เป็น           13       True              THAI
# 262     126334                  ผ่าน           12       True              THAI
# 263     126343                 เมื่อ           15       True              THAI
# 264     126351                  ซื้อ           12       True              THAI
# 265     126356                    ส์            6       True              THAI
# 266     126361                 กำลัง           15       True              THAI
# 267     126363                   จริ            9       True              THAI
# 268     126364                  จริง           12       True              THAI
# 269     126367                   ค่ะ            9       True              THAI
# 270     126388                   สูง            9       True              THAI
# 271     126396                   รูป            9       True              THAI
# 272     126404                  เสีย           12       True              THAI
# 273     126425                  ห้อง           12       True              THAI
# 274     126431                  ชีวิ           12       True              THAI
# 275     126432                 ชีวิต           15       True              THAI
# 276     126476               ออนไลน์           21       True              THAI
# 277     126481                 เพียง           15       True              THAI
# 278     126496                วันที่           18       True              THAI
# 279     126521                    อิ            6       True              THAI
# 280     126526                   ได้           10       True              THAI
# 281     126553               ต้องการ           21       True              THAI
# 282     126561                เหมือน           18       True              THAI
# 283     126576                   จึง            9       True              THAI
# 284     126618                 เริ่ม           15       True              THAI
# 285     126630                   จัง            9       True              THAI
# 286     126637                เกี่ยว           18       True              THAI
# 287     126638                    ดิ            6       True              THAI
# 288     126651                   แค่            9       True              THAI
# 289     126653                  หนัง           12       True              THAI
# 290     126668                  ยิ่ง           12       True              THAI
# 291     126670                   นี่            9       True              THAI
# 292     126671                  วิธี           12       True              THAI
# 293     126677                  เว็บ           12       True              THAI
# 294     126681                 สำคัญ           15       True              THAI
# 295     126694                   ผิด            9       True              THAI
# 296     126697                 เตอร์           15       True              THAI
# 297     126740                เปลี่ย           18       True              THAI
# 298     126741               เปลี่ยน           21       True              THAI
# 299     126749                   เต็            9       True              THAI
# 300     126769                    พั            6       True              THAI
# 301     126770                   พัฒ            9       True              THAI
# 302     126771                 พัฒนา           15       True              THAI
# 303     126772                    ชิ            6       True              THAI
# 304     126775                   รัฐ            9       True              THAI
# 305     126792                  แต่ง           12       True              THAI
# 306     126795               พื้นที่           21       True              THAI
# 307     126809                   แก่            9       True              THAI
# 308     126812                  ปรับ           12       True              THAI
# 309     126816                   สมั            9       True              THAI
# 310     126817                 สมัคร           15       True              THAI
# 311     126834                  ข้าง           12       True              THAI
# 312     126845                    วี            6       True              THAI
# 313     126848                   เดิ            9       True              THAI
# 314     126849                  เดิม           12       True              THAI
# 315     126874                เพื่อน           18       True              THAI
# 316     126876               เดินทาง           21       True              THAI
# 317     126892                   ล่า            9       True              THAI
# 318     126902                   สู่            9       True              THAI
# 319     126909                 รักษา           15       True              THAI
# 320     126927                   แม้            9       True              THAI
# 321     126940                    يّ            4       True            ARABIC
# 322     126953                 ที่ดี           15       True              THAI
# 323     126969                ตัวเอง           18       True              THAI
# 324     126974                    จี            6       True              THAI
# 325     126978                   ลับ            9       True              THAI
# 326     126982               อย่างไร           21       True              THAI
# 327     126984                   ใช่            9       True              THAI
# 328     126999                  เติม           12       True              THAI
# 329     127003                  เช่น           12       True              THAI
# 330     127007                    ปั            6       True              THAI
# 331     127008                   ปัจ            9       True              THAI
# 332     127014                    هُ            4       True            ARABIC
# 333     127019                 เนื้อ           15       True              THAI
# 334     127036                 เสริม           15       True              THAI
# 335     127074                    ภู            6       True              THAI
# 336     127089                    لّ            4       True            ARABIC
# 337     127092                  สั่ง           12       True              THAI
# 338     127102                   ปฏิ            9       True              THAI
# 339     127103                  บัติ           12       True              THAI
# 340     127108                   ใต้            9       True              THAI
# 341     127133                    กุ            6       True              THAI
# 342     127135                  รู้ส           12       True              THAI
# 343     127136                รู้สึก           18       True              THAI
# 344     127143                  ใช้ง           12       True              THAI
# 345     127144                ใช้งาน           18       True              THAI
# 346     127150                สมาชิก           18       True              THAI
# 347     127155                   ผ้า            9       True              THAI
# 348     127158                    ภั            6       True              THAI
# 349     127167                   ข้า            9       True              THAI
# 350     127179                  ล้าน           12       True              THAI
# 351     127198                ละเอีย           18       True              THAI
# 352     127199               ละเอียด           21       True              THAI
# 353     127204                  ร่าง           12       True              THAI
# 354     127222                  ท่อง           12       True              THAI
# 355     127223            ท่องเที่ยว           30       True              THAI
# 356     127240                   ตัด            9       True              THAI
# 357     127249                  ช่อง           12       True              THAI
# 358     127259                  จ่าย           12       True              THAI
# 359     127263                   ขับ            9       True              THAI
# 360     127271                   ลีก            9       True              THAI
# 361     127283                  หนัก           12       True              THAI
# 362     127289                   นต์            9       True              THAI
# 363     127291                    ว์            6       True              THAI
# 364     127293                  สื่อ           12       True              THAI
# 365     127321                  นั่น           12       True              THAI
# 366     127340                   นัน            9       True              THAI
# 367     127345                นักงาน           18       True              THAI
# 368     127346               หน้าที่           21       True              THAI
# 369     127361                   ฟ้า            9       True              THAI
# 370     127369                    ê�            5       True             LATIN
# 371     127379                    กี            6       True              THAI
# 372     127383                   ทัน            9       True              THAI
# 373     127400                 เหลือ           15       True              THAI
# 374     127408                  หญิง           12       True              THAI
# 375     127410                  เส้น           12       True              THAI
# 376     127427                  ท้าย           12       True              THAI
# 377     127430                  ครัว           12       True              THAI
# 378     127448                  ลักษ           12       True              THAI
# 379     127469                    نّ            4       True            ARABIC
# 380     127492                   สนุ            9       True              THAI
# 381     127509                   ชุม            9       True              THAI
# 382     127531                    บู            6       True              THAI
# 383     127532                    มุ            6       True              THAI
# 384     127577                  ท้อง           12       True              THAI
# 385     127582                บริหาร           18       True              THAI
# 386     127644                   ชีพ            9       True              THAI
# 387     127653                 เหล่า           15       True              THAI
# 388     127655                   รณ์            9       True              THAI
# 389     127665                 เสื้อ           15       True              THAI
# 390     127678                   จัย            9       True              THAI
# 391     127679                   ก่อ            9       True              THAI
# 392     127686                ดำเนิน           18       True              THAI
# 393     127695                   อนุ            9       True              THAI
# 394     127714                  แข่ง           12       True              THAI
# 395     127720                  สูตร           12       True              THAI
# 396     127740                 เยี่ย           15       True              THAI
# 397     127741                เยี่ยม           18       True              THAI
# 398     127747                   ตรี            9       True              THAI
# 399     127777                   สัญ            9       True              THAI
# 400     127778                 สัญญา           15       True              THAI
# 401     127779                  มั่น           12       True              THAI
# 402     127813                 ลงทุน           15       True              THAI
# 403     127822               ความคิด           21       True              THAI
# 404     127861                    ขั            6       True              THAI
# 405     127862                  ขั้น           12       True              THAI
# 406     127885                   อัง            9       True              THAI
# 407     127886                  อังก           12       True              THAI
# 408     127887                อังกฤษ           18       True              THAI
# 409     127907                  พลัง           12       True              THAI
# 410     127928                   มัก            9       True              THAI
# 411     127932                   แข็            9       True              THAI
# 412     127933                  แข็ง           12       True              THAI
# 413     127938                   ชัด            9       True              THAI
# 414     127939                   สต์            9       True              THAI
# 415     127945                   ยืน            9       True              THAI
# 416     127946                   ยัน            9       True              THAI
# 417     127965              สัมพันธ์           24       True              THAI
# 418     127966                   ิ่น            9       True              THAI
# 419     127974               ปลอดภัย           21       True              THAI
# 420     127984                  เท้า           12       True              THAI
# 421     127993                  เจ็บ           12       True              THAI
# 422     127995                   วัต            9       True              THAI
# 423     127996                    ถุ            6       True              THAI
# 424     128016                   ดื่            9       True              THAI
# 425     128017                  ดื่ม           12       True              THAI
# 426     128025               เคลื่อน           21       True              THAI
# 427     128027                จำเป็น           18       True              THAI
# 428     128043                  พุทธ           12       True              THAI
# 429     128047                 ก็ตาม           15       True              THAI
# 430     128059                  ค่อย           12       True              THAI
# 431     128063                   วัฒ            9       True              THAI
# 432     128064                  วัฒน           12       True              THAI
# 433     128068                  คาสิ           12       True              THAI
# 434     128069                คาสิโน           18       True              THAI
# 435     128072                 หน่วย           15       True              THAI
# 436     128078                  เกีย           12       True              THAI
# 437     128081                   ปริ            9       True              THAI
# 438     128090                  เมีย           12       True              THAI
# 439     128107               กรุงเทพ           21       True              THAI
# 440     128119                ขณะที่           18       True              THAI
# 441     128142                   คับ            9       True              THAI
# 442     128170               แตกต่าง           21       True              THAI
# 443     128180                 ประวั           15       True              THAI
# 444     128181               ประวัติ           21       True              THAI
# 445     128190                    ศิ            6       True              THAI
# 446     128191                   ศิล            9       True              THAI
# 447     128192                  ศิลป           12       True              THAI
# 448     128202              ประสิทธิ           24       True              THAI
# 449     128203           ประสิทธิภาพ           33       True              THAI
# 450     128204                    ย่            6       True              THAI
# 451     128207               รวดเร็ว           21       True              THAI
# 452     128217                   ทับ            9       True              THAI
# 453     128221                 เปล่า           15       True              THAI
# 454     128244                 <unk>            5       True             LATIN
# 455     128245                   <s>            3       True         LESS-THAN
# 456     128246                   </s            3       True         LESS-THAN
# 457     128247                  </s>            4       True         LESS-THAN
# 458     128257                    اً            4       True            ARABIC
# 459     128404                  หรือ           13       True              THAI
# 460     128477                   ที่           10       True              THAI
# 461     128511                 หนึ่ง           15       True              THAI
# 462     128527                 เลือก           15       True              THAI
# 463     128563                 ที่มี           15       True              THAI
# 464     128592                 ที่จะ           15       True              THAI
# 465     128620                  ท่าน           12       True              THAI
# 466     128673                สินค้า           18       True              THAI
# 467     128676                ไม่ได้           18       True              THAI
# 468     128711                  ข้อม           12       True              THAI
# 469     128712                ข้อมูล           18       True              THAI
# 470     128736                    ลิ            6       True              THAI
# 471     128741                 ไม่มี           15       True              THAI
# 472     128752                  ชื่อ           12       True              THAI
# 473     128806                    ปี            7       True              THAI
# 474     128833                   แม่            9       True              THAI
# 475     128840                 เพื่อ           16       True              THAI
# 476     128898                  น้อย           12       True              THAI
# 477     128903                 เมื่อ           16       True              THAI
# 478     128908                  เด็ก           12       True              THAI
# 479     128948                 เดือน           15       True              THAI
# 480     128964                 ระดับ           15       True              THAI
# 481     129048                  บริษ           12       True              THAI
# 482     129049                 บริษั           15       True              THAI
# 483     129050                บริษัท           18       True              THAI
# 484     129081                    ซี            6       True              THAI
# 485     129095                    وَ            5       True            ARABIC
# 486     129114                 ต่างๆ           15       True              THAI
# 487     129115                 มีการ           15       True              THAI
# 488     129140                  รุ่น           12       True              THAI
# 489     129184                 กลุ่ม           15       True              THAI
# 490     129186                  อ่าน           12       True              THAI
# 491     129190                   ถ้า           10       True              THAI
# 492     129214                   ไม่           10       True              THAI
# 493     129243                   ฉัน            9       True              THAI
# 494     129277                   คู่            9       True              THAI
# 495     129300                    ก็            7       True              THAI
# 496     129323                    ซิ            6       True              THAI
# 497     129342                   ใส่            9       True              THAI
# 498     129351                  จะมี           12       True              THAI
# 499     129397                   จุด            9       True              THAI
# 500     129420                    ผิ            6       True              THAI
# 501     129421                   ผิว            9       True              THAI
# 502     129438                    تُ            4       True            ARABIC
# 503     129441                   ياً            6       True            ARABIC
# 504     129444                อยู่ใน           18       True              THAI
# 505     129453                    يُ            5       True            ARABIC
# 506     129454                   กิน            9       True              THAI
# 507     129456                    مُ            4       True            ARABIC
# 508     129457                   คือ           10       True              THAI
# 509     129497                วันนี้           18       True              THAI
# 510     129508                 เสียง           15       True              THAI
# 511     129513                   วัด            9       True              THAI
# 512     129524                  ชั้น           12       True              THAI
# 513     129543                   ผู้           10       True              THAI
# 514     129575                 พร้อม           16       True              THAI
# 515     129583                 จังหว           15       True              THAI
# 516     129584               จังหวัด           21       True              THAI
# 517     129593             เกี่ยวกับ           27       True              THAI
# 518     129603                   ชุด            9       True              THAI
# 519     129604                    พู            6       True              THAI
# 520     129605                   พูด            9       True              THAI
# 521     129621                ของคุณ           18       True              THAI
# 522     129629                สำหรับ           19       True              THAI
# 523     129658                    ยู            6       True              THAI
# 524     129683               ตั้งแต่           21       True              THAI
# 525     129732                    ธุ            6       True              THAI
# 526     129733                   ธุร            9       True              THAI
# 527     129734                ธุรกิจ           18       True              THAI
# 528     129750               ทั้งหมด           21       True              THAI
# 529     129774                   พี่            9       True              THAI
# 530     129775                  แล้ว           13       True              THAI
# 531     129779               ระหว่าง           21       True              THAI
# 532     129795                  เก็บ           12       True              THAI
# 533     129853                   ฟรี            9       True              THAI
# 534     129909                    لَ            4       True            ARABIC
# 535     129910                  เต็ม           12       True              THAI
# 536     129927                ลูกค้า           18       True              THAI
# 537     129936                  บ้าง           12       True              THAI
# 538     129959                  พิเศ           12       True              THAI
# 539     129960                 พิเศษ           15       True              THAI
# 540     129978                 เขียน           15       True              THAI
# 541     129979                  น้อง           12       True              THAI
# 542     129983                  ส่วน           13       True              THAI
# 543     130001                  ถ่าย           12       True              THAI
# 544     130024                เข้ามา           18       True              THAI
# 545     130049                   الْ            7       True            ARABIC
# 546     130065                  อายุ           12       True              THAI
# 547     130080                   ดิน            9       True              THAI
# 548     130082                  เล็ก           12       True              THAI
# 549     130091                   อิน            9       True              THAI
# 550     130159                    فَ            4       True            ARABIC
# 551     130167                   คุณ           10       True              THAI
# 552     130175                   วัน           10       True              THAI
# 553     130183                   คืน            9       True              THAI
# 554     130200               หลังจาก           21       True              THAI
# 555     130218                    كَ            4       True            ARABIC
# 556     130247                  เช่น           13       True              THAI
# 557     130285               สิ่งที่           21       True              THAI
# 558     130301                   จึง           10       True              THAI
# 559     130320                   พ่อ            9       True              THAI
# 560     130367                    لِ            4       True            ARABIC
# 561     130373                 ต่อไป           15       True              THAI
# 562     130415                เว็บไซ           18       True              THAI
# 563     130416              เว็บไซต์           24       True              THAI
# 564     130447                   ฟัง            9       True              THAI
# 565     130460                ล่าสุด           18       True              THAI
# 566     130493                    ซั            6       True              THAI
# 567     130522                   จับ            9       True              THAI
# 568     130531                    مَ            4       True            ARABIC
# 569     130542              เท่านั้น           24       True              THAI
# 570     130551               กิจกรรม           21       True              THAI
# 571     130557                จะเป็น           18       True              THAI
# 572     130560                  ร้อน           12       True              THAI
# 573     130585                ให้กับ           18       True              THAI
# 574     130610                  ดูแล           12       True              THAI
# 575     130618                  นั่ง           12       True              THAI
# 576     130628                  แจ้ง           12       True              THAI
# 577     130634                    จิ            6       True              THAI
# 578     130658                  ก็จะ           12       True              THAI
# 579     130659                 ทำให้           16       True              THAI
# 580     130686                สุขภาพ           18       True              THAI
# 581     130709                    ศู            6       True              THAI
# 582     130710                   ศูน            9       True              THAI
# 583     130711                 ศูนย์           15       True              THAI
# 584     130742                ที่นี่           18       True              THAI
# 585     130748               มากกว่า           21       True              THAI
# 586     130750                    بِ            4       True            ARABIC
# 587     130754                   จีน            9       True              THAI
# 588     130760                คุณภาพ           18       True              THAI
# 589     130764               ไม่ต้อง           21       True              THAI
# 590     130784                จัดการ           18       True              THAI
# 591     130789                 แต่ละ           15       True              THAI
# 592     130791               ที่เป็น           21       True              THAI
# 593     130799                ไม่ใช่           18       True              THAI
# 594     130818                   ปิด            9       True              THAI
# 595     130835                 จำกัด           15       True              THAI
# 596     130845                   บิน            9       True              THAI
# 597     130846               สถานที่           21       True              THAI
# 598     130880             เพิ่มเติม           27       True              THAI
# 599     130899                 ปัจจุ           15       True              THAI
# 600     130900              ปัจจุบัน           24       True              THAI
# 601     130905                เตรียม           18       True              THAI
# 602     130932              ประโยชน์           24       True              THAI
# 603     130944                    تَ            4       True            ARABIC
# 604     130970                ติดต่อ           18       True              THAI
# 605     131041                ยังไม่           18       True              THAI
# ...
# 2010    151734                                  0      False  Empty/Whitespace
# 2011    151735                                  0      False  Empty/Whitespace
# 2012    151736                                  0      False  Empty/Whitespace
# 2013    151737                                  0      False  Empty/Whitespace
# 2014    151738                                  0      False  Empty/Whitespace
# 2015    151739                                  0      False  Empty/Whitespace
# 2016    151740                                  0      False  Empty/Whitespace
# 2017    151741                                  0      False  Empty/Whitespace
# 2018    151742                                  0      False  Empty/Whitespace
# 2019    151743                                  0      False  Empty/Whitespace
# 2020    151744                                  0      False  Empty/Whitespace
# 2021    151745                                  0      False  Empty/Whitespace
# 2022    151746                                  0      False  Empty/Whitespace
# 2023    151747                                  0      False  Empty/Whitespace
# 2024    151748                                  0      False  Empty/Whitespace
# 2025    151749                                  0      False  Empty/Whitespace
# 2026    151750                                  0      False  Empty/Whitespace
# 2027    151751                                  0      False  Empty/Whitespace
# 2028    151752                                  0      False  Empty/Whitespace
# 2029    151753                                  0      False  Empty/Whitespace
# 2030    151754                                  0      False  Empty/Whitespace
# 2031    151755                                  0      False  Empty/Whitespace
# 2032    151756                                  0      False  Empty/Whitespace
# 2033    151757                                  0      False  Empty/Whitespace
# 2034    151758                                  0      False  Empty/Whitespace
# 2035    151759                                  0      False  Empty/Whitespace
# 2036    151760                                  0      False  Empty/Whitespace
# 2037    151761                                  0      False  Empty/Whitespace
# 2038    151762                                  0      False  Empty/Whitespace
# 2039    151763                                  0      False  Empty/Whitespace
# 2040    151764                                  0      False  Empty/Whitespace
# 2041    151765                                  0      False  Empty/Whitespace
# 2042    151766                                  0      False  Empty/Whitespace
# 2043    151767                                  0      False  Empty/Whitespace
# 2044    151768                                  0      False  Empty/Whitespace
# 2045    151769                                  0      False  Empty/Whitespace
# 2046    151770                                  0      False  Empty/Whitespace
# 2047    151771                                  0      False  Empty/Whitespace
# 2048    151772                                  0      False  Empty/Whitespace
# 2049    151773                                  0      False  Empty/Whitespace
# 2050    151774                                  0      False  Empty/Whitespace
# 2051    151775                                  0      False  Empty/Whitespace
# 2052    151776                                  0      False  Empty/Whitespace
# 2053    151777                                  0      False  Empty/Whitespace
# 2054    151778                                  0      False  Empty/Whitespace
# 2055    151779                                  0      False  Empty/Whitespace
# 2056    151780                                  0      False  Empty/Whitespace
# 2057    151781                                  0      False  Empty/Whitespace
# 2058    151782                                  0      False  Empty/Whitespace
# 2059    151783                                  0      False  Empty/Whitespace
# 2060    151784                                  0      False  Empty/Whitespace
# 2061    151785                                  0      False  Empty/Whitespace
# 2062    151786                                  0      False  Empty/Whitespace
# 2063    151787                                  0      False  Empty/Whitespace
# 2064    151788                                  0      False  Empty/Whitespace
# 2065    151789                                  0      False  Empty/Whitespace
# 2066    151790                                  0      False  Empty/Whitespace
# 2067    151791                                  0      False  Empty/Whitespace
# 2068    151792                                  0      False  Empty/Whitespace
# 2069    151793                                  0      False  Empty/Whitespace
# 2070    151794                                  0      False  Empty/Whitespace
# 2071    151795                                  0      False  Empty/Whitespace
# 2072    151796                                  0      False  Empty/Whitespace
# 2073    151797                                  0      False  Empty/Whitespace
# 2074    151798                                  0      False  Empty/Whitespace
# 2075    151799                                  0      False  Empty/Whitespace
# 2076    151800                                  0      False  Empty/Whitespace
# 2077    151801                                  0      False  Empty/Whitespace
# 2078    151802                                  0      False  Empty/Whitespace
# 2079    151803                                  0      False  Empty/Whitespace
# 2080    151804                                  0      False  Empty/Whitespace
# 2081    151805                                  0      False  Empty/Whitespace
# 2082    151806                                  0      False  Empty/Whitespace
# 2083    151807                                  0      False  Empty/Whitespace
# 2084    151808                                  0      False  Empty/Whitespace
# 2085    151809                                  0      False  Empty/Whitespace
# 2086    151810                                  0      False  Empty/Whitespace
# 2087    151811                                  0      False  Empty/Whitespace
# 2088    151812                                  0      False  Empty/Whitespace
# 2089    151813                                  0      False  Empty/Whitespace
# 2090    151814                                  0      False  Empty/Whitespace
# 2091    151815                                  0      False  Empty/Whitespace
# 2092    151816                                  0      False  Empty/Whitespace
# 2093    151817                                  0      False  Empty/Whitespace
# 2094    151818                                  0      False  Empty/Whitespace
# 2095    151819                                  0      False  Empty/Whitespace
# 2096    151820                                  0      False  Empty/Whitespace
# 2097    151821                                  0      False  Empty/Whitespace
# 2098    151822                                  0      False  Empty/Whitespace
# 2099    151823                                  0      False  Empty/Whitespace
# 2100    151824                                  0      False  Empty/Whitespace
# 2101    151825                                  0      False  Empty/Whitespace
# 2102    151826                                  0      False  Empty/Whitespace
# 2103    151827                                  0      False  Empty/Whitespace
# 2104    151828                                  0      False  Empty/Whitespace
# 2105    151829                                  0      False  Empty/Whitespace
# 2106    151830                                  0      False  Empty/Whitespace
# 2107    151831                                  0      False  Empty/Whitespace
# 2108    151832                                  0      False  Empty/Whitespace
# 2109    151833                                  0      False  Empty/Whitespace
# 2110    151834                                  0      False  Empty/Whitespace
# 2111    151835                                  0      False  Empty/Whitespace
# 2112    151836                                  0      False  Empty/Whitespace
# 2113    151837                                  0      False  Empty/Whitespace
# 2114    151838                                  0      False  Empty/Whitespace
# 2115    151839                                  0      False  Empty/Whitespace
# 2116    151840                                  0      False  Empty/Whitespace
# 2117    151841                                  0      False  Empty/Whitespace
# 2118    151842                                  0      False  Empty/Whitespace
# 2119    151843                                  0      False  Empty/Whitespace
# 2120    151844                                  0      False  Empty/Whitespace
# 2121    151845                                  0      False  Empty/Whitespace
# 2122    151846                                  0      False  Empty/Whitespace
# 2123    151847                                  0      False  Empty/Whitespace
# 2124    151848                                  0      False  Empty/Whitespace
# 2125    151849                                  0      False  Empty/Whitespace
# 2126    151850                                  0      False  Empty/Whitespace
# 2127    151851                                  0      False  Empty/Whitespace
# 2128    151852                                  0      False  Empty/Whitespace
# 2129    151853                                  0      False  Empty/Whitespace
# 2130    151854                                  0      False  Empty/Whitespace
# 2131    151855                                  0      False  Empty/Whitespace
# 2132    151856                                  0      False  Empty/Whitespace
# 2133    151857                                  0      False  Empty/Whitespace
# 2134    151858                                  0      False  Empty/Whitespace
# 2135    151859                                  0      False  Empty/Whitespace
# 2136    151860                                  0      False  Empty/Whitespace
# 2137    151861                                  0      False  Empty/Whitespace
# 2138    151862                                  0      False  Empty/Whitespace
# 2139    151863                                  0      False  Empty/Whitespace
# 2140    151864                                  0      False  Empty/Whitespace
# 2141    151865                                  0      False  Empty/Whitespace
# 2142    151866                                  0      False  Empty/Whitespace
# 2143    151867                                  0      False  Empty/Whitespace
# 2144    151868                                  0      False  Empty/Whitespace
# 2145    151869                                  0      False  Empty/Whitespace
# 2146    151870                                  0      False  Empty/Whitespace
# 2147    151871                                  0      False  Empty/Whitespace
# 2148    151872                                  0      False  Empty/Whitespace
# 2149    151873                                  0      False  Empty/Whitespace
# 2150    151874                                  0      False  Empty/Whitespace
# 2151    151875                                  0      False  Empty/Whitespace
# 2152    151876                                  0      False  Empty/Whitespace
# 2153    151877                                  0      False  Empty/Whitespace
# 2154    151878                                  0      False  Empty/Whitespace
# 2155    151879                                  0      False  Empty/Whitespace
# 2156    151880                                  0      False  Empty/Whitespace
# 2157    151881                                  0      False  Empty/Whitespace
# 2158    151882                                  0      False  Empty/Whitespace
# 2159    151883                                  0      False  Empty/Whitespace
# 2160    151884                                  0      False  Empty/Whitespace
# 2161    151885                                  0      False  Empty/Whitespace
# 2162    151886                                  0      False  Empty/Whitespace
# 2163    151887                                  0      False  Empty/Whitespace
# 2164    151888                                  0      False  Empty/Whitespace
# 2165    151889                                  0      False  Empty/Whitespace
# 2166    151890                                  0      False  Empty/Whitespace
# 2167    151891                                  0      False  Empty/Whitespace
# 2168    151892                                  0      False  Empty/Whitespace
# 2169    151893                                  0      False  Empty/Whitespace
# 2170    151894                                  0      False  Empty/Whitespace
# 2171    151895                                  0      False  Empty/Whitespace
# 2172    151896                                  0      False  Empty/Whitespace
# 2173    151897                                  0      False  Empty/Whitespace
# 2174    151898                                  0      False  Empty/Whitespace
# 2175    151899                                  0      False  Empty/Whitespace
# 2176    151900                                  0      False  Empty/Whitespace
# 2177    151901                                  0      False  Empty/Whitespace
# 2178    151902                                  0      False  Empty/Whitespace
# 2179    151903                                  0      False  Empty/Whitespace
# 2180    151904                                  0      False  Empty/Whitespace
# 2181    151905                                  0      False  Empty/Whitespace
# 2182    151906                                  0      False  Empty/Whitespace
# 2183    151907                                  0      False  Empty/Whitespace
# 2184    151908                                  0      False  Empty/Whitespace
# 2185    151909                                  0      False  Empty/Whitespace
# 2186    151910                                  0      False  Empty/Whitespace
# 2187    151911                                  0      False  Empty/Whitespace
# 2188    151912                                  0      False  Empty/Whitespace
# 2189    151913                                  0      False  Empty/Whitespace
# 2190    151914                                  0      False  Empty/Whitespace
# 2191    151915                                  0      False  Empty/Whitespace
# 2192    151916                                  0      False  Empty/Whitespace
# 2193    151917                                  0      False  Empty/Whitespace
# 2194    151918                                  0      False  Empty/Whitespace
# 2195    151919                                  0      False  Empty/Whitespace
# 2196    151920                                  0      False  Empty/Whitespace
# 2197    151921                                  0      False  Empty/Whitespace
# 2198    151922                                  0      False  Empty/Whitespace
# 2199    151923                                  0      False  Empty/Whitespace
# 2200    151924                                  0      False  Empty/Whitespace
# 2201    151925                                  0      False  Empty/Whitespace
# 2202    151926                                  0      False  Empty/Whitespace
# 2203    151927                                  0      False  Empty/Whitespace
# 2204    151928                                  0      False  Empty/Whitespace
# 2205    151929                                  0      False  Empty/Whitespace
# 2206    151930                                  0      False  Empty/Whitespace
# 2207    151931                                  0      False  Empty/Whitespace
# 2208    151932                                  0      False  Empty/Whitespace
# 2209    151933                                  0      False  Empty/Whitespace
# 2210    151934                                  0      False  Empty/Whitespace
# 2211    151935                                  0      False  Empty/Whitespace

# %% [markdown]
# ## Observations
#
# What patterns do we see in the decoded tokens?
#
# **Key questions:**
# 1. What's the dominant script? (Thai? CJK? Mixed?)
# 2. Are these common words or rare sequences?
# 3. Are there any obvious patterns in token ID ranges?
# 4. How many are high-byte-count sequences (complex Unicode)?
# 5. Do the non-printable tokens cluster in specific ID ranges?
#
# The script distribution will tell us whether this is a linguistic phenomenon (e.g., "dead Thai tokens") or something more general.
