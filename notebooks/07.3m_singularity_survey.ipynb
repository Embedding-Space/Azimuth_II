# %% [markdown]
# # 07.3m: Singularity Survey
#
# **Search an unembedding matrix for singularities (bit-for-bit identical vectors)**
#
# We discovered that Qwen3-4B-Instruct-2507 has 2,100 "black hole" tokens that deduplicate to just 13 unique vectors. These represent dead vocabulary—tokens the tokenizer never emits, so their embeddings never got trained.
#
# Question: Is this unique to Qwen, or do other models have similar structures?
#
# This notebook loads an arbitrary model's unembedding matrix and searches for non-unique vectors using hash-based deduplication (`torch.unique()`) instead of pairwise comparison.
#
# ## Method
#
# 1. Load model's lm_head weight matrix (unembedding matrix)
# 2. Use `torch.unique()` to find all unique vectors
# 3. Identify singularities: groups of 2+ tokens sharing identical vectors
# 4. Report statistics and optionally decode tokens in each group
#
# ## Parameters

# %%
# Model to analyze
MODEL_NAME = "Qwen/Qwen2.5-3B-Instruct"  # Change this to test different models

# Display options
DECODE_TOKENS = True  # Whether to decode and display tokens in singularity groups
MAX_TOKENS_PER_GROUP = 20  # Limit display for very large singularity groups
RANDOM_SEED = 42

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm.auto import tqdm
from collections import defaultdict

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Load Model
#
# We only need the lm_head (unembedding matrix), not the full model.

# %%
print(f"Loading model: {MODEL_NAME}")
print("(This may take a while for large models...)\n")

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.bfloat16,
    device_map="cpu"
)

print("✓ Model loaded successfully")
# Out:
# Loading model: Qwen/Qwen2.5-3B-Instruct
# (This may take a while for large models...)
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ✓ Model loaded successfully

# %% [markdown]
# ## Extract Unembedding Matrix

# %%
# Get unembedding matrix (typically model.lm_head.weight)
gamma = model.lm_head.weight.data.clone().to(torch.float32)
vocab_size, hidden_dim = gamma.shape

print(f"Unembedding matrix shape: {gamma.shape}")
print(f"Vocabulary size: {vocab_size:,}")
print(f"Hidden dimension: {hidden_dim:,}")
print(f"Total parameters: {vocab_size * hidden_dim:,}")
print(f"Memory footprint: {gamma.element_size() * gamma.numel() / 1e9:.2f} GB (float32)")
# Out:
# Unembedding matrix shape: torch.Size([151936, 2048])
# Vocabulary size: 151,936
# Hidden dimension: 2,048
# Total parameters: 311,164,928
# Memory footprint: 1.24 GB (float32)

# %% [markdown]
# ## Find Singularities
#
# Use `torch.unique()` to find all unique vectors and identify groups of tokens that share identical vectors.

# %%
print("Searching for singularities...\n")

# Find unique vectors
unique_vectors, inverse_indices, counts = torch.unique(
    gamma,
    dim=0,
    return_inverse=True,
    return_counts=True
)

n_unique = len(unique_vectors)
n_total = vocab_size
n_duplicate = n_total - n_unique

print(f"Total tokens: {n_total:,}")
print(f"Unique vectors: {n_unique:,}")
print(f"Duplicate tokens: {n_duplicate:,}")
print(f"Uniqueness: {100 * n_unique / n_total:.2f}%\n")

if n_duplicate == 0:
    print("✓ No singularities found. Every token has a unique vector.")
else:
    print(f"⚠ Found {n_duplicate:,} duplicate tokens")
# Out:
# Searching for singularities...
#
# Total tokens: 151,936
# Unique vectors: 149,784
# Duplicate tokens: 2,152
# Uniqueness: 98.58%
#
# ⚠ Found 2,152 duplicate tokens

# %% [markdown]
# ## Analyze Singularity Groups
#
# Group tokens by their shared vector and report statistics.

# %%
if n_duplicate > 0:
    # Build map from unique vector index to list of token IDs
    singularity_groups = defaultdict(list)
    
    for token_id, unique_idx in enumerate(inverse_indices.tolist()):
        if counts[unique_idx] > 1:  # Only include vectors shared by 2+ tokens
            singularity_groups[unique_idx].append(token_id)
    
    n_groups = len(singularity_groups)
    group_sizes = [len(tokens) for tokens in singularity_groups.values()]
    
    print(f"\nSingularity groups: {n_groups:,}")
    print(f"Largest group: {max(group_sizes):,} tokens")
    print(f"Smallest group: {min(group_sizes):,} tokens")
    print(f"Mean group size: {np.mean(group_sizes):.1f} tokens")
    print(f"Median group size: {np.median(group_sizes):.1f} tokens")
    
    # Histogram of group sizes
    size_counts = defaultdict(int)
    for size in group_sizes:
        size_counts[size] += 1
    
    print("\nGroup size distribution:")
    for size in sorted(size_counts.keys()):
        count = size_counts[size]
        print(f"  {size:4d} tokens: {count:4d} groups")
# Out:
# Singularity groups: 60
# Largest group: 600 tokens
# Smallest group: 2 tokens
# Mean group size: 36.9 tokens
# Median group size: 6.5 tokens
#
# Group size distribution:
#      2 tokens:   11 groups
#      3 tokens:    3 groups
#      4 tokens:    7 groups
#      5 tokens:    5 groups
#      6 tokens:    4 groups
#      7 tokens:    3 groups
#      8 tokens:    1 groups
#      9 tokens:    2 groups
#     10 tokens:    1 groups
#     12 tokens:    1 groups
#     14 tokens:    1 groups
#     15 tokens:    1 groups
#     16 tokens:    1 groups
#     17 tokens:    1 groups
#     19 tokens:    1 groups
#     21 tokens:    2 groups
#     25 tokens:    1 groups
#     27 tokens:    1 groups
#     32 tokens:    1 groups
#     38 tokens:    1 groups
#     46 tokens:    1 groups
#     63 tokens:    1 groups
#     92 tokens:    1 groups
#     94 tokens:    1 groups
#    112 tokens:    2 groups
#    135 tokens:    1 groups
#    144 tokens:    1 groups
#    188 tokens:    1 groups
#    204 tokens:    1 groups
#    600 tokens:    1 groups

# %% [markdown]
# ## Decode Singularity Tokens
#
# Load tokenizer and decode tokens in each singularity group.

# %%
if n_duplicate > 0 and DECODE_TOKENS:
    print(f"\nLoading tokenizer for {MODEL_NAME}...")
    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
    print("✓ Tokenizer loaded\n")
    
    # Sort groups by size (largest first)
    sorted_groups = sorted(
        singularity_groups.items(),
        key=lambda x: len(x[1]),
        reverse=True
    )
    
    print(f"Displaying up to {MAX_TOKENS_PER_GROUP} tokens per group\n")
    print("=" * 80)
    
    for group_idx, (unique_idx, token_ids) in enumerate(sorted_groups, 1):
        n_tokens = len(token_ids)
        print(f"\nGroup {group_idx}/{n_groups}: {n_tokens} tokens sharing vector #{unique_idx}")
        print("-" * 80)
        
        # Show first N tokens
        display_tokens = token_ids[:MAX_TOKENS_PER_GROUP]
        
        for token_id in display_tokens:
            try:
                token_str = tokenizer.decode([token_id])
                # Show repr for visibility of whitespace/control chars
                print(f"  Token {token_id:6d}: {repr(token_str)}")
            except Exception as e:
                print(f"  Token {token_id:6d}: <decode error: {e}>")
        
        if n_tokens > MAX_TOKENS_PER_GROUP:
            print(f"  ... and {n_tokens - MAX_TOKENS_PER_GROUP} more tokens")
        
        print("=" * 80)
# Out:
# Loading tokenizer for Qwen/Qwen2.5-3B-Instruct...
# ✓ Tokenizer loaded
#
# Displaying up to 20 tokens per group
#
# ================================================================================
#
# Group 1/60: 600 tokens sharing vector #77384
# --------------------------------------------------------------------------------
#   Token    177: '�'
#   Token    187: '�'
#   Token  77150: '１０'
#   Token  80091: '２０'
#   Token  83969: 'PostalCodesNL'
#   Token 119346: '珊�'
#   Token 123806: '�'
#   Token 123828: 'ที่'
#   Token 123870: '�'
#   Token 123939: 'ร์'
#   Token 123948: 'ติ'
#   Token 124033: 'ไม่'
#   Token 124055: 'ได้'
#   Token 124139: 'นี้'
#   Token 124175: 'คุ'
#   Token 124254: 'กัน'
#   Token 124258: 'ผู้'
#   Token 124294: 'วั'
#   Token 124311: 'ดี'
#   Token 124361: 'ณ์'
#   ... and 580 more tokens
# ================================================================================
#
# Group 2/60: 204 tokens sharing vector #77422
# --------------------------------------------------------------------------------
#   Token 151554: '臘'
#   Token 151555: '怒'
#   Token 151556: '辰'
#   Token 151618: '嘆'
#   Token 151638: '見'
#   Token 151649: '<|box_end|>'
#   Token 151651: '<|quad_end|>'
#   Token 151652: '<|vision_start|>'
#   Token 151654: '<|vision_pad|>'
#   Token 151655: '<|image_pad|>'
#   Token 151656: '<|video_pad|>'
#   Token 151661: '<|fim_suffix|>'
#   Token 151663: '<|repo_name|>'
#   Token 151664: '<|file_sep|>'
#   Token 151665: ''
#   Token 151667: ''
#   Token 151669: ''
#   Token 151672: ''
#   Token 151673: ''
#   Token 151674: ''
#   ... and 184 more tokens
# ================================================================================
#
# Group 3/60: 188 tokens sharing vector #77383
# --------------------------------------------------------------------------------
#   Token 123876: '�'
#   Token 125488: 'เล่น'
#   Token 125507: 'เครื่อง'
#   Token 125557: 'ต้น'
#   Token 125622: 'ุ่ม'
#   Token 125627: 'เพิ่ม'
#   Token 125655: 'มีความ'
#   Token 125687: 'อัน'
#   Token 125734: 'อุ'
#   Token 125740: 'อื่น'
#   Token 126044: 'องค์'
#   Token 126088: 'นด์'
#   Token 126125: 'พุ'
#   Token 126476: 'ออนไลน์'
#   Token 126834: 'ข้าง'
#   Token 127007: 'ปั'
#   Token 127019: 'เนื้อ'
#   Token 127158: 'ภั'
#   Token 127179: 'ล้าน'
#   Token 127223: 'ท่องเที่ยว'
#   ... and 168 more tokens
# ================================================================================
#
# Group 4/60: 144 tokens sharing vector #77359
# --------------------------------------------------------------------------------
#   Token    178: '�'
#   Token    186: '�'
#   Token 124076: 'ก็'
#   Token 124121: 'วิ'
#   Token 124380: 'อย่าง'
#   Token 124986: 'ด์'
#   Token 125016: 'น้ำ'
#   Token 125026: 'หรือ'
#   Token 125279: 'บัน'
#   Token 125306: 'ศึก'
#   Token 125337: 'ตร์'
#   Token 125359: 'การณ์'
#   Token 125458: 'ซึ่ง'
#   Token 125527: 'ใหญ่'
#   Token 125552: 'มือ'
#   Token 125576: 'แห่ง'
#   Token 125605: 'ที่สุด'
#   Token 125835: 'สุข'
#   Token 125869: 'เร็ว'
#   Token 125872: 'เชื่อ'
#   ... and 124 more tokens
# ================================================================================
#
# Group 5/60: 135 tokens sharing vector #77399
# --------------------------------------------------------------------------------
#   Token    124: '�'
#   Token 124030: 'ว่า'
#   Token 124060: 'ริ'
#   Token 124105: 'ให้'
#   Token 124171: 'ต่'
#   Token 124440: 'ี่ย'
#   Token 124500: 'ขึ'
#   Token 124502: 'ก่'
#   Token 124512: 'ที'
#   Token 124524: 'ื้อ'
#   Token 124559: 'พิ'
#   Token 124731: 'บุ'
#   Token 125181: 'เรียน'
#   Token 125363: 'ยุ'
#   Token 125392: 'สิท'
#   Token 125454: 'มัน'
#   Token 125459: 'ครับ'
#   Token 125460: 'บ้าน'
#   Token 125514: 'สิน'
#   Token 125794: 'ลี'
#   ... and 115 more tokens
# ================================================================================
#
# Group 6/60: 112 tokens sharing vector #77362
# --------------------------------------------------------------------------------
#   Token    182: '�'
#   Token    185: '�'
#   Token  97000: '(stypy'
#   Token 119349: '珊󠄁'
#   Token 123848: '�'
#   Token 123952: 'ด้'
#   Token 124083: 'ั้ง'
#   Token 124439: 'รู้'
#   Token 125095: 'สู'
#   Token 125142: 'รุ'
#   Token 125292: 'เหตุ'
#   Token 125850: 'ท์'
#   Token 125860: 'จุ'
#   Token 125878: 'ริม'
#   Token 126021: 'วิทย'
#   Token 126314: 'หลัง'
#   Token 126694: 'ผิด'
#   Token 126982: 'อย่างไร'
#   Token 127862: 'ขั้น'
#   Token 127938: 'ชัด'
#   ... and 92 more tokens
# ================================================================================
#
# Group 7/60: 112 tokens sharing vector #77373
# --------------------------------------------------------------------------------
#   Token 125499: 'สำหรับ'
#   Token 125538: 'เจ้า'
#   Token 125577: 'ดับ'
#   Token 125611: 'พร้อม'
#   Token 125623: 'ถ้า'
#   Token 125654: 'เดียว'
#   Token 125663: 'สิ่ง'
#   Token 125667: 'หลัก'
#   Token 125680: 'หัว'
#   Token 125690: 'เดิน'
#   Token 125707: 'ยิ'
#   Token 125739: 'อื่'
#   Token 125752: 'ไม้'
#   Token 125753: 'กลับ'
#   Token 125803: 'ง่าย'
#   Token 125858: 'เติ'
#   Token 125887: 'เนื่อง'
#   Token 125892: 'เที่'
#   Token 125919: 'บั'
#   Token 125972: 'ศาสตร์'
#   ... and 92 more tokens
# ================================================================================
#
# Group 8/60: 94 tokens sharing vector #77369
# --------------------------------------------------------------------------------
#   Token  79269: ' ForCanBeConverted'
#   Token  79270: ' ForCanBeConvertedToF'
#   Token 124458: 'ตุ'
#   Token 124482: 'ใช้'
#   Token 124484: 'นั'
#   Token 124573: 'ค์'
#   Token 124602: 'แล้ว'
#   Token 124707: 'ต์'
#   Token 125015: 'นั้น'
#   Token 125034: 'ทุก'
#   Token 125436: 'ถึง'
#   Token 125442: ' แต่'
#   Token 125564: 'เด็'
#   Token 125816: 'เท่า'
#   Token 125853: 'กล่าว'
#   Token 125893: 'เที่ยว'
#   Token 126140: 'สัม'
#   Token 126250: ' มี'
#   Token 126324: ' เป็น'
#   Token 126576: 'จึง'
#   ... and 74 more tokens
# ================================================================================
#
# Group 9/60: 92 tokens sharing vector #77360
# --------------------------------------------------------------------------------
#   Token  83971: '$PostalCodesNL'
#   Token 119347: '珊�'
#   Token 124027: 'เป็น'
#   Token 124767: 'หน้า'
#   Token 124779: 'ึ่ง'
#   Token 124939: 'อั'
#   Token 125079: 'เกิด'
#   Token 125398: 'มั'
#   Token 126243: 'เพื่อ'
#   Token 126296: 'ด้าน'
#   Token 126301: 'ไว้'
#   Token 126361: 'กำลัง'
#   Token 126526: ' ได้'
#   Token 126769: 'พั'
#   Token 127133: 'กุ'
#   Token 127143: 'ใช้ง'
#   Token 127291: 'ว์'
#   Token 127340: 'นัน'
#   Token 127777: 'สัญ'
#   Token 127886: 'อังก'
#   ... and 72 more tokens
# ================================================================================
#
# Group 10/60: 63 tokens sharing vector #77371
# --------------------------------------------------------------------------------
#   Token    180: '�'
#   Token    184: '�'
#   Token 127003: 'เช่น'
#   Token 127092: 'สั่ง'
#   Token 127155: 'ผ้า'
#   Token 127346: 'หน้าที่'
#   Token 127966: 'ิ่น'
#   Token 128081: 'ปริ'
#   Token 128107: 'กรุงเทพ'
#   Token 128190: 'ศิ'
#   Token 128202: 'ประสิทธิ'
#   Token 128204: 'ย่'
#   Token 131437: 'ที่ผ่านมา'
#   Token 131557: 'เกิดขึ้น'
#   Token 131787: 'บริเว'
#   Token 131864: 'ในช่วง'
#   Token 132007: 'ญี่'
#   Token 132507: 'ร้าย'
#   Token 132882: 'กีฬา'
#   Token 132952: 'วิธีการ'
#   ... and 43 more tokens
# ================================================================================
#
# Group 11/60: 46 tokens sharing vector #77367
# --------------------------------------------------------------------------------
#   Token    125: '�'
#   Token 124942: 'เร็'
#   Token 125393: 'สิทธิ'
#   Token 125554: 'รู'
#   Token 125566: 'ทีม'
#   Token 125597: 'ร้าน'
#   Token 125710: 'ธี'
#   Token 125950: 'ทั่ว'
#   Token 126481: 'เพียง'
#   Token 126671: 'วิธี'
#   Token 127430: 'ครัว'
#   Token 127965: 'สัมพันธ์'
#   Token 127984: 'เท้า'
#   Token 129733: 'ธุร'
#   Token 129959: 'พิเศ'
#   Token 130218: 'كَ'
#   Token 130560: 'ร้อน'
#   Token 132328: 'دّ'
#   Token 132398: 'นี'
#   Token 132504: 'งค์'
#   ... and 26 more tokens
# ================================================================================
#
# Group 12/60: 38 tokens sharing vector #77351
# --------------------------------------------------------------------------------
#   Token 124316: 'คุณ'
#   Token 124866: 'ิ่ม'
#   Token 124918: 'พื'
#   Token 124946: 'ชาติ'
#   Token 125125: 'สุ'
#   Token 125130: 'คิด'
#   Token 125771: 'ช่วง'
#   Token 126012: 'مْ'
#   Token 126334: 'ผ่าน'
#   Token 126809: 'แก่'
#   Token 126876: 'เดินทาง'
#   Token 127014: 'هُ'
#   Token 127289: 'นต์'
#   Token 127678: 'จัย'
#   Token 127741: 'เยี่ยม'
#   Token 127813: 'ลงทุน'
#   Token 128247: '</s>'
#   Token 131202: 'เป็นการ'
#   Token 131532: 'ฟิ'
#   Token 132395: 'ประตู'
#   ... and 18 more tokens
# ================================================================================
#
# Group 13/60: 32 tokens sharing vector #77412
# --------------------------------------------------------------------------------
#   Token 124418: 'สุด'
#   Token 124620: 'เข้า'
#   Token 125613: 'บริการ'
#   Token 125688: 'ี่ยว'
#   Token 125891: 'สัง'
#   Token 125914: 'ผลิต'
#   Token 126775: 'รัฐ'
#   Token 127293: 'สื่อ'
#   Token 127379: 'กี'
#   Token 129140: 'รุ่น'
#   Token 129184: 'กลุ่ม'
#   Token 129774: 'พี่'
#   Token 131240: 'มากขึ้น'
#   Token 132105: 'ครู'
#   Token 132680: 'คลิป'
#   Token 132735: 'ที่คุณ'
#   Token 133080: 'رّ'
#   Token 134932: 'ấ'
#   Token 135263: 'เศรษฐกิจ'
#   Token 135314: 'ที่เกี่ยวข้อง'
#   ... and 12 more tokens
# ================================================================================
#
# Group 14/60: 27 tokens sharing vector #77424
# --------------------------------------------------------------------------------
#   Token 151646: '<|object_ref_start|>'
#   Token 151647: '<|object_ref_end|>'
#   Token 151662: '<|fim_pad|>'
#   Token 151727: ''
#   Token 151731: ''
#   Token 151740: ''
#   Token 151761: ''
#   Token 151762: ''
#   Token 151769: ''
#   Token 151799: ''
#   Token 151811: ''
#   Token 151819: ''
#   Token 151820: ''
#   Token 151827: ''
#   Token 151829: ''
#   Token 151832: ''
#   Token 151854: ''
#   Token 151862: ''
#   Token 151875: ''
#   Token 151877: ''
#   ... and 7 more tokens
# ================================================================================
#
# Group 15/60: 25 tokens sharing vector #77382
# --------------------------------------------------------------------------------
#   Token 125956: 'ภัย'
#   Token 130628: 'แจ้ง'
#   Token 130742: 'ที่นี่'
#   Token 135546: 'กล้า'
#   Token 136131: 'หุ'
#   Token 139094: 'สรุป'
#   Token 142867: 'ประจำปี'
#   Token 142873: 'เรื่อย'
#   Token 147356: '益'
#   Token 150619: 'ι'
#   Token 151666: ''
#   Token 151668: ''
#   Token 151677: ''
#   Token 151735: ''
#   Token 151810: ''
#   Token 151818: ''
#   Token 151821: ''
#   Token 151833: ''
#   Token 151836: ''
#   Token 151837: ''
#   ... and 5 more tokens
# ================================================================================
#
# Group 16/60: 21 tokens sharing vector #77380
# --------------------------------------------------------------------------------
#   Token 124031: 'มี'
#   Token 124132: 'สิ'
#   Token 124178: 'ื่อ'
#   Token 124212: 'ื่อง'
#   Token 124627: 'อี'
#   Token 124742: 'าร์'
#   Token 124860: 'ครั้ง'
#   Token 124891: 'รั'
#   Token 124926: 'ื่อน'
#   Token 125060: 'ส่ง'
#   Token 125062: 'ถูก'
#   Token 125195: 'กิจ'
#   Token 125226: 'พื้น'
#   Token 125366: 'ถือ'
#   Token 125736: 'ปัญหา'
#   Token 130658: 'ก็จะ'
#   Token 138991: 'กรุ'
#   Token 140378: 'นักท่องเที่ยว'
#   Token 142534: 'ล้ำ'
#   Token 143178: 'ข้อเสนอ'
#   ... and 1 more tokens
# ================================================================================
#
# Group 17/60: 21 tokens sharing vector #77356
# --------------------------------------------------------------------------------
#   Token 125071: 'เห็น'
#   Token 125294: 'พัก'
#   Token 128673: 'สินค้า'
#   Token 128676: 'ไม่ได้'
#   Token 129583: 'จังหว'
#   Token 129605: 'พูด'
#   Token 129629: ' สำหรับ'
#   Token 130247: ' เช่น'
#   Token 131661: 'ข้าว'
#   Token 133793: ' ดัง'
#   Token 134606: 'อาชีพ'
#   Token 134643: 'จะทำให้'
#   Token 134795: 'رُ'
#   Token 135366: 'เสร็'
#   Token 135529: 'วิ่ง'
#   Token 139158: 'ค่อนข้าง'
#   Token 141286: ' แต่ถ้า'
#   Token 141459: 'เดอร์'
#   Token 142230: 'ด้านล่าง'
#   Token 142698: ' ธันวา'
#   ... and 1 more tokens
# ================================================================================
#
# Group 18/60: 19 tokens sharing vector #77357
# --------------------------------------------------------------------------------
#   Token 129444: 'อยู่ใน'
#   Token 129508: 'เสียง'
#   Token 130080: 'ดิน'
#   Token 133164: 'ขึ้นมา'
#   Token 134646: 'เหล่านี้'
#   Token 134755: 'ผู้หญิง'
#   Token 134781: 'คลิก'
#   Token 134911: 'ดุ'
#   Token 135202: 'รัง'
#   Token 140456: 'มิถุนายน'
#   Token 140790: 'อันตราย'
#   Token 140816: 'ที่น่าสนใจ'
#   Token 141287: 'ดาวน์'
#   Token 141553: 'บอร์'
#   Token 141623: 'พิษ'
#   Token 143480: 'อธิบาย'
#   Token 146207: 'ή'
#   Token 147111: '樂'
#   Token 147225: '量'
# ================================================================================
#
# Group 19/60: 17 tokens sharing vector #77425
# --------------------------------------------------------------------------------
#   Token 151681: ''
#   Token 151685: ''
#   Token 151692: ''
#   Token 151707: ''
#   Token 151738: ''
#   Token 151781: ''
#   Token 151790: ''
#   Token 151802: ''
#   Token 151804: ''
#   Token 151825: ''
#   Token 151826: ''
#   Token 151834: ''
#   Token 151845: ''
#   Token 151846: ''
#   Token 151873: ''
#   Token 151907: ''
#   Token 151924: ''
# ================================================================================
#
# Group 20/60: 16 tokens sharing vector #77413
# --------------------------------------------------------------------------------
#   Token 125053: 'กว่า'
#   Token 126171: 'หมู่'
#   Token 128203: 'ประสิทธิภาพ'
#   Token 130784: 'จัดการ'
#   Token 132445: 'บุค'
#   Token 135830: 'نَا'
#   Token 135989: 'น้ำหนัก'
#   Token 137242: 'จ้าง'
#   Token 137856: 'กรี'
#   Token 138160: 'วิน'
#   Token 141435: 'ค่าใช้จ่าย'
#   Token 143893: 'ส้ม'
#   Token 147489: '怜'
#   Token 148425: '柳'
#   Token 151142: '了'
#   Token 151144: '料'
# ================================================================================
#
# Group 21/60: 15 tokens sharing vector #77420
# --------------------------------------------------------------------------------
#   Token 124568: 'ธิ'
#   Token 124652: 'ค้า'
#   Token 127383: 'ทัน'
#   Token 127995: 'วัต'
#   Token 131882: 'การใช้'
#   Token 135245: 'ล่ะ'
#   Token 137755: 'คอมพิวเตอร์'
#   Token 138193: 'ความปลอดภัย'
#   Token 138199: 'ขึ้นไป'
#   Token 139278: 'เกือ'
#   Token 141065: 'จะได้รับ'
#   Token 141988: 'พรีเมียร์'
#   Token 143469: 'ทักษะ'
#   Token 143820: 'สมาร์ทโฟน'
#   Token 149365: '鶴'
# ================================================================================
#
# Group 22/60: 14 tokens sharing vector #77423
# --------------------------------------------------------------------------------
#   Token 151648: '<|box_start|>'
#   Token 151653: '<|vision_end|>'
#   Token 151659: '<|fim_prefix|>'
#   Token 151660: '<|fim_middle|>'
#   Token 151670: ''
#   Token 151671: ''
#   Token 151690: ''
#   Token 151697: ''
#   Token 151698: ''
#   Token 151711: ''
#   Token 151713: ''
#   Token 151734: ''
#   Token 151850: ''
#   Token 151900: ''
# ================================================================================
#
# Group 23/60: 12 tokens sharing vector #77387
# --------------------------------------------------------------------------------
#   Token 148885: '良'
#   Token 149468: '領'
#   Token 151715: ''
#   Token 151758: ''
#   Token 151759: ''
#   Token 151768: ''
#   Token 151784: ''
#   Token 151817: ''
#   Token 151828: ''
#   Token 151847: ''
#   Token 151849: ''
#   Token 151865: ''
# ================================================================================
#
# Group 24/60: 10 tokens sharing vector #77379
# --------------------------------------------------------------------------------
#   Token 126927: 'แม้'
#   Token 126974: 'จี'
#   Token 127655: 'รณ์'
#   Token 129603: 'ชุด'
#   Token 131516: 'ชัย'
#   Token 132628: 'قَ'
#   Token 135161: 'ยังไง'
#   Token 141186: 'เม็ด'
#   Token 142447: ' สิงหาคม'
#   Token 142449: 'หน้าจอ'
# ================================================================================
#
# Group 25/60: 9 tokens sharing vector #77402
# --------------------------------------------------------------------------------
#   Token    183: '�'
#   Token 126036: 'แก้'
#   Token 127410: 'เส้น'
#   Token 132129: 'หวัง'
#   Token 133263: 'لَّ'
#   Token 136631: 'ส่งเสริม'
#   Token 142908: 'เนอร์'
#   Token 142970: 'ลงทะเบียน'
#   Token 149527: 'য়'
# ================================================================================
#
# Group 26/60: 9 tokens sharing vector #77390
# --------------------------------------------------------------------------------
#   Token 124530: 'ค่'
#   Token 125491: 'คือ'
#   Token 128016: 'ดื่'
#   Token 132008: 'ญี่ป'
#   Token 136381: 'ครั้งที่'
#   Token 138673: 'â�'
#   Token 143273: 'เท่าไหร'
#   Token 146267: 'וֹ'
#   Token 148359: '列'
# ================================================================================
#
# Group 27/60: 8 tokens sharing vector #77414
# --------------------------------------------------------------------------------
#   Token    179: '�'
#   Token 125934: 'ทุน'
#   Token 130905: 'เตรียม'
#   Token 132641: 'เหนือ'
#   Token 132715: 'พนัน'
#   Token 136153: 'มาร์'
#   Token 148029: 'תּ'
#   Token 148758: '例'
# ================================================================================
#
# Group 28/60: 7 tokens sharing vector #77375
# --------------------------------------------------------------------------------
#   Token 126521: 'อิ'
#   Token 128563: 'ที่มี'
#   Token 131872: 'ชนิด'
#   Token 133685: 'อ่อน'
#   Token 135355: 'สิทธิ์'
#   Token 138035: 'รีบ'
#   Token 139556: 'สงสั'
# ================================================================================
#
# Group 29/60: 7 tokens sharing vector #77403
# --------------------------------------------------------------------------------
#   Token 127469: 'نّ'
#   Token 129457: ' คือ'
#   Token 131955: 'ฟุต'
#   Token 136401: 'ปู'
#   Token 136565: 'พิจารณา'
#   Token 137405: 'สมัครสมาชิก'
#   Token 140181: 'เสียชีวิต'
# ================================================================================
#
# Group 30/60: 7 tokens sharing vector #77354
# --------------------------------------------------------------------------------
#   Token 127932: 'แข็'
#   Token 127939: 'สต์'
#   Token 130585: 'ให้กับ'
#   Token 133355: 'ค้น'
#   Token 137045: 'וּ'
#   Token 142680: 'ย่อม'
#   Token 143136: ' กันยายน'
# ================================================================================
#
# Group 31/60: 6 tokens sharing vector #77397
# --------------------------------------------------------------------------------
#   Token 124238: 'สั'
#   Token 131421: 'บี'
#   Token 136379: 'หิน'
#   Token 136793: 'เป็นเรื่อง'
#   Token 149255: '露'
#   Token 151135: '璉'
# ================================================================================
#
# Group 32/60: 6 tokens sharing vector #77388
# --------------------------------------------------------------------------------
#   Token 124630: 'วัน'
#   Token 126812: 'ปรับ'
#   Token 142229: 'ด้านล'
#   Token 145470: 'Ω'
#   Token 149346: '精'
#   Token 149820: '遼'
# ================================================================================
#
# Group 33/60: 6 tokens sharing vector #77418
# --------------------------------------------------------------------------------
#   Token 125517: 'เปิด'
#   Token 125518: 'ค่า'
#   Token 126308: 'ลูก'
#   Token 133466: 'กล้อง'
#   Token 149815: '麗'
#   Token 149823: '泥'
# ================================================================================
#
# Group 34/60: 6 tokens sharing vector #77400
# --------------------------------------------------------------------------------
#   Token 130091: 'อิน'
#   Token 132470: 'ใกล้'
#   Token 134554: 'แผ่น'
#   Token 139967: 'คนอื่น'
#   Token 141434: 'ค่าใช้'
#   Token 151123: '鹿'
# ================================================================================
#
# Group 35/60: 5 tokens sharing vector #77389
# --------------------------------------------------------------------------------
#   Token 124084: 'รับ'
#   Token 141389: 'บุก'
#   Token 141408: 'ปุ่ม'
#   Token 143238: 'ฝรั่งเศส'
#   Token 143441: 'บรรจุ'
# ================================================================================
#
# Group 36/60: 5 tokens sharing vector #77352
# --------------------------------------------------------------------------------
#   Token 125636: 'ได้รับ'
#   Token 126240: ' ซึ่ง'
#   Token 142513: 'ไม่เกิน'
#   Token 147056: '切'
#   Token 148028: '林'
# ================================================================================
#
# Group 37/60: 5 tokens sharing vector #77410
# --------------------------------------------------------------------------------
#   Token 127778: 'สัญญา'
#   Token 130791: 'ที่เป็น'
#   Token 131319: 'عَ'
#   Token 134698: 'เข้าสู่'
#   Token 137888: 'มาแล้ว'
# ================================================================================
#
# Group 38/60: 5 tokens sharing vector #77398
# --------------------------------------------------------------------------------
#   Token 129190: ' ถ้า'
#   Token 133117: 'หนุ่ม'
#   Token 133148: 'มหาวิทยาล'
#   Token 136737: 'มั่นใจ'
#   Token 151497: '句'
# ================================================================================
#
# Group 39/60: 5 tokens sharing vector #77411
# --------------------------------------------------------------------------------
#   Token 138632: 'كُمْ'
#   Token 138656: 'เด่น'
#   Token 138662: 'รองรับ'
#   Token 142914: ' ตุ'
#   Token 143991: 'เคลื่อนไหว'
# ================================================================================
#
# Group 40/60: 4 tokens sharing vector #77417
# --------------------------------------------------------------------------------
#   Token 119348: '珊�'
#   Token 126749: 'เต็'
#   Token 145569: ';'
#   Token 151136: '練'
# ================================================================================
#
# Group 41/60: 4 tokens sharing vector #77404
# --------------------------------------------------------------------------------
#   Token 124129: 'อร์'
#   Token 135441: 'บันทึก'
#   Token 139473: 'สืบ'
#   Token 140036: 'ก็สามารถ'
# ================================================================================
#
# Group 42/60: 4 tokens sharing vector #77419
# --------------------------------------------------------------------------------
#   Token 124770: 'ทั้ง'
#   Token 133794: ' ดังนั้น'
#   Token 134263: 'ลึก'
#   Token 140835: 'อยากให้'
# ================================================================================
#
# Group 43/60: 4 tokens sharing vector #77363
# --------------------------------------------------------------------------------
#   Token 126792: 'แต่ง'
#   Token 140191: 'เบีย'
#   Token 142800: 'ไขมัน'
#   Token 150088: '暴'
# ================================================================================
#
# Group 44/60: 4 tokens sharing vector #77415
# --------------------------------------------------------------------------------
#   Token 127102: 'ปฏิ'
#   Token 138922: 'เน็'
#   Token 140724: 'คริส'
#   Token 140963: 'เอ็'
# ================================================================================
#
# Group 45/60: 4 tokens sharing vector #77406
# --------------------------------------------------------------------------------
#   Token 133902: 'กลายเป็น'
#   Token 136672: 'ที่สำคัญ'
#   Token 143212: ' กุมภาพันธ์'
#   Token 151139: '裂'
# ================================================================================
#
# Group 46/60: 4 tokens sharing vector #77368
# --------------------------------------------------------------------------------
#   Token 151650: '<|quad_start|>'
#   Token 151789: ''
#   Token 151840: ''
#   Token 151868: ''
# ================================================================================
#
# Group 47/60: 3 tokens sharing vector #77408
# --------------------------------------------------------------------------------
#   Token 123821: '�'
#   Token 124350: 'เรีย'
#   Token 132379: 'หรือไม่'
# ================================================================================
#
# Group 48/60: 3 tokens sharing vector #77353
# --------------------------------------------------------------------------------
#   Token 126351: 'ซื้อ'
#   Token 143045: ' อีก'
#   Token 148193: '省'
# ================================================================================
#
# Group 49/60: 3 tokens sharing vector #77396
# --------------------------------------------------------------------------------
#   Token 136571: 'เกาหลี'
#   Token 136579: 'ของผู้'
#   Token 141717: 'หล่อ'
# ================================================================================
#
# Group 50/60: 2 tokens sharing vector #77372
# --------------------------------------------------------------------------------
#   Token    181: '�'
#   Token 125213: 'ปัญ'
# ================================================================================
#
# Group 51/60: 2 tokens sharing vector #77374
# --------------------------------------------------------------------------------
#   Token 125147: 'ติด'
#   Token 129604: 'พู'
# ================================================================================
#
# Group 52/60: 2 tokens sharing vector #77405
# --------------------------------------------------------------------------------
#   Token 126356: 'ส์'
#   Token 126363: 'จริ'
# ================================================================================
#
# Group 53/60: 2 tokens sharing vector #77391
# --------------------------------------------------------------------------------
#   Token 126653: 'หนัง'
#   Token 149806: '裸'
# ================================================================================
#
# Group 54/60: 2 tokens sharing vector #77409
# --------------------------------------------------------------------------------
#   Token 135383: 'ดีกว่า'
#   Token 136601: 'لُ'
# ================================================================================
#
# Group 55/60: 2 tokens sharing vector #77355
# --------------------------------------------------------------------------------
#   Token 136715: 'กุล'
#   Token 136749: 'จนถึง'
# ================================================================================
#
# Group 56/60: 2 tokens sharing vector #77421
# --------------------------------------------------------------------------------
#   Token 140743: 'กลับไป'
#   Token 141322: 'น้ำตาล'
# ================================================================================
#
# Group 57/60: 2 tokens sharing vector #77392
# --------------------------------------------------------------------------------
#   Token 141017: 'จัดส่ง'
#   Token 141044: 'พระองค์'
# ================================================================================
#
# Group 58/60: 2 tokens sharing vector #77394
# --------------------------------------------------------------------------------
#   Token 141994: 'สมเด็'
#   Token 143479: 'อธิ'
# ================================================================================
#
# Group 59/60: 2 tokens sharing vector #77385
# --------------------------------------------------------------------------------
#   Token 142416: 'ทำให้เกิด'
#   Token 148831: 'K'
# ================================================================================
#
# Group 60/60: 2 tokens sharing vector #77361
# --------------------------------------------------------------------------------
#   Token 143307: 'สร้างสรร'
#   Token 151153: '什'
# ================================================================================

# %% [markdown]
# ## Summary Statistics

# %%
print(f"\n{'='*80}")
print("SUMMARY")
print(f"{'='*80}")
print(f"Model: {MODEL_NAME}")
print(f"Vocabulary size: {vocab_size:,}")
print(f"Unique vectors: {n_unique:,}")
print(f"Duplicate tokens: {n_duplicate:,} ({100 * n_duplicate / n_total:.2f}%)")

if n_duplicate > 0:
    print(f"Singularity groups: {n_groups:,}")
    print(f"Largest singularity: {max(group_sizes):,} tokens")
    print(f"Deduplication ratio: {n_total / n_unique:.2f}x")
else:
    print("No singularities detected.")

print(f"{'='*80}")
# Out:
# ================================================================================
# SUMMARY
# ================================================================================
# Model: Qwen/Qwen2.5-3B-Instruct
# Vocabulary size: 151,936
# Unique vectors: 149,784
# Duplicate tokens: 2,152 (1.42%)
# Singularity groups: 60
# Largest singularity: 600 tokens
# Deduplication ratio: 1.01x
# ================================================================================
