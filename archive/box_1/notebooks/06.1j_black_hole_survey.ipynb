# %% [markdown]
# # 06.1j: Black Hole Survey
#
# **Goal:** Comprehensive analysis of each of the 13 primordial black holes.
#
# For each black hole cluster, we examine:
# 1. **Identity:** Rank, size, representative token, complete token list with decoding
# 2. **Spatial properties:** Norm, distance from centroid, deviation from mean radius
# 3. **Pairwise relationships:** Distances and angular separations to all other black holes
# 4. **Token linguistics:** Script types, character patterns
# 5. **Statistical summary:** Nearest/farthest neighbors, outlier detection
#
# This is Volume 6: Pathologies and Singularities

# %% [markdown]
# ## Parameters

# %%
TENSOR_DIR = "../data/tensors"
GAMMA_FILE = "gamma_qwen3_4b_instruct_2507.safetensors"
MODEL_NAME = "Qwen/Qwen3-4B-Instruct-2507"

# The 13 black hole clusters (from 06.1h)
# Format: (representative_token_id, cluster_size, all_token_ids)
BLACK_HOLE_CLUSTERS = [
    (80091, 814, list(range(80091, 80091+814))),  # Placeholder - will load from 06.1h results
    (125, 704, None),
    (124, 306, None),
    (124350, 228, None),
    (123939, 11, [123939, 131955, 134350, 134430, 138099, 139299, 139794, 140074]),  # From 06.1h output
    (119349, 10, [119349, 125087, 126630, 137856, 138110, 139345, 142061, 143029, 143036, 143048]),
    (126268, 6, [126268, 132713, 138041, 146501, 148028, 151889]),
    (132383, 5, [132383, 132398, 139050, 142718, 142719]),
    (135619, 4, [135619, 138490, 140815, 143457]),
    (136831, 4, [136831, 138068, 138072, 139278]),
    (180, 3, [180, 138979, 141503]),
    (126775, 3, [126775, 140303, 147056]),
    (126816, 2, [126816, 147836]),
]

# NOTE: For large clusters, we'll need to re-run 06.1h or load token IDs from saved data
# For now, using placeholders for the big 4

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
from safetensors.torch import load_file
from pathlib import Path
from transformers import AutoTokenizer
from collections import Counter
import unicodedata

print("Imports loaded successfully.")
# Out:
# Imports loaded successfully.

# %% [markdown]
# ## Step 1: Load Data

# %%
print("Loading gamma matrix...")
gamma_path = Path(TENSOR_DIR) / GAMMA_FILE
gamma = load_file(gamma_path)['gamma']
print(f"Loaded: {gamma.shape}\n")

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
print(f"Tokenizer loaded. Vocab size: {len(tokenizer):,}\n")
# Out:
# Loading gamma matrix...
# Loaded: torch.Size([151936, 2560])
#
# Loading tokenizer...
# Tokenizer loaded. Vocab size: 151,669

# %% [markdown]
# ## Step 2: Re-identify All Clusters
#
# We need the complete token lists for all 13 clusters. Let's re-run the deduplication to get them.

# %%
print("Finding all degenerate clusters...\n")

from collections import defaultdict

gamma_np = gamma.cpu().numpy()
unique_vecs, inverse_indices, counts = np.unique(
    gamma_np, 
    axis=0, 
    return_inverse=True, 
    return_counts=True
)

# Build clusters
clusters = defaultdict(list)
for token_id, unique_idx in enumerate(inverse_indices):
    clusters[unique_idx].append(token_id)

# Filter to degenerate clusters
degenerate_clusters = {idx: tokens for idx, tokens in clusters.items() if len(tokens) > 1}

# Sort by size, descending
sorted_clusters = sorted(degenerate_clusters.items(), key=lambda x: len(x[1]), reverse=True)

print(f"Found {len(sorted_clusters)} degenerate clusters\n")

# Extract black hole data
black_holes_data = []
for rank, (unique_idx, token_ids) in enumerate(sorted_clusters[:13], 1):
    rep_token = token_ids[0]
    size = len(token_ids)
    black_holes_data.append({
        'rank': rank,
        'size': size,
        'representative': rep_token,
        'token_ids': token_ids,
        'embedding': gamma[rep_token],
    })

print(f"Extracted data for top 13 black holes")
# Out:
# Finding all degenerate clusters...
#
# Found 13 degenerate clusters
#
# Extracted data for top 13 black holes

# %% [markdown]
# ## Step 3: Compute Global Statistics

# %%
print("\nComputing global statistics...\n")

# Extract embeddings for the 13 representative tokens
black_hole_embeddings = torch.stack([bh['embedding'] for bh in black_holes_data])
n_holes = len(black_holes_data)

# Compute norms
norms = torch.norm(black_hole_embeddings, dim=1)
mean_norm = norms.mean()

# Compute centroid of 13 black holes
centroid = black_hole_embeddings.mean(dim=0)
centroid_norm = torch.norm(centroid)

# Distances to centroid
distances_to_centroid = torch.norm(black_hole_embeddings - centroid, dim=1)

# Pairwise distances (Euclidean)
pairwise_distances = torch.cdist(black_hole_embeddings, black_hole_embeddings, p=2)

# Pairwise angular separations
black_holes_normed = black_hole_embeddings / torch.norm(black_hole_embeddings, dim=1, keepdim=True)
cosine_sims = black_holes_normed @ black_holes_normed.T
cosine_sims_clamped = torch.clamp(cosine_sims, -1.0, 1.0)
angular_distances = torch.acos(cosine_sims_clamped)
angular_distances_deg = angular_distances * 180 / np.pi

# Store in black_holes_data
for i, bh in enumerate(black_holes_data):
    bh['norm'] = norms[i].item()
    bh['distance_to_centroid'] = distances_to_centroid[i].item()
    bh['norm_deviation'] = (norms[i] - mean_norm).item()

print(f"Global statistics:")
print(f"  Mean norm: {mean_norm.item():.12f}")
print(f"  Centroid norm: {centroid_norm.item():.12f}")
print(f"  RMS spread: {torch.sqrt((distances_to_centroid**2).mean()).item():.12f}")
# Out:
# Computing global statistics...
#
# Global statistics:
#   Mean norm: 0.370916843414
#   Centroid norm: 0.370916843414
#   RMS spread: 0.000026409623

# %% [markdown]
# ## Step 4: Survey Each Black Hole
#
# Now we generate a detailed report for each of the 13 black holes.

# %%
def classify_character(char):
    """Classify a character by its Unicode category."""
    if not char:
        return 'Empty'
    try:
        cat = unicodedata.category(char[0])
        name = unicodedata.name(char[0], '<UNNAMED>')
        
        # Broad classification
        if cat.startswith('L'):  # Letter
            # Try to identify script
            if 'THAI' in name:
                return 'Thai'
            elif 'CJK' in name or 'HANZI' in name or 'KANJI' in name:
                return 'CJK'
            elif 'ARABIC' in name:
                return 'Arabic'
            elif 'HEBREW' in name:
                return 'Hebrew'
            elif 'CYRILLIC' in name:
                return 'Cyrillic'
            elif 'LATIN' in name:
                return 'Latin'
            else:
                return 'Other Letter'
        elif cat.startswith('M'):  # Mark/diacritic
            return 'Diacritic'
        elif cat.startswith('N'):  # Number
            return 'Number'
        elif cat.startswith('P'):  # Punctuation
            return 'Punctuation'
        elif cat.startswith('S'):  # Symbol
            return 'Symbol'
        elif cat.startswith('Z'):  # Separator
            return 'Whitespace'
        elif cat.startswith('C'):  # Control/other
            return 'Control'
        else:
            return 'Other'
    except:
        return 'Unknown'

def survey_black_hole(bh_idx):
    """Generate comprehensive report for a single black hole."""
    bh = black_holes_data[bh_idx]
    
    print("\n" + "="*80)
    print(f"BLACK HOLE #{bh['rank']}: {bh['size']} TOKENS")
    print("="*80)
    print()
    
    # SECTION 1: Identity
    print(f"**IDENTITY**")
    print(f"  Representative token ID: {bh['representative']}")
    print(f"  Cluster size: {bh['size']} tokens")
    print()
    
    # SECTION 2: Spatial Properties
    print(f"**SPATIAL PROPERTIES**")
    print(f"  Norm (distance from origin): {bh['norm']:.12f}")
    print(f"  Distance from constellation centroid: {bh['distance_to_centroid']:.12f}")
    print(f"  Deviation from mean norm: {bh['norm_deviation']:.12e}")
    print()
    
    # SECTION 3: Pairwise Relationships
    print(f"**RELATIONSHIPS TO OTHER BLACK HOLES**")
    print(f"{'To BH':>7} {'Euclidean Dist':>18} {'Angular Sep (°)':>18}")
    print("-" * 50)
    
    euclidean_dists = []
    angular_seps = []
    
    for j in range(n_holes):
        if j == bh_idx:
            continue
        euclidean_dist = pairwise_distances[bh_idx, j].item()
        angular_sep = angular_distances_deg[bh_idx, j].item()
        
        euclidean_dists.append(euclidean_dist)
        angular_seps.append(angular_sep)
        
        print(f"#{j+1:>6} {euclidean_dist:>18.12f} {angular_sep:>18.6f}")
    
    # Summary statistics
    print()
    print(f"  Mean distance to others: {np.mean(euclidean_dists):.12f}")
    print(f"  Min distance (nearest): {np.min(euclidean_dists):.12f} → BH #{np.argmin(euclidean_dists)+1 + (1 if np.argmin(euclidean_dists) >= bh_idx else 0)}")
    print(f"  Max distance (farthest): {np.max(euclidean_dists):.12f} → BH #{np.argmax(euclidean_dists)+1 + (1 if np.argmax(euclidean_dists) >= bh_idx else 0)}")
    print()
    print(f"  Mean angular separation: {np.mean(angular_seps):.6f}°")
    print(f"  Min angular separation: {np.min(angular_seps):.6f}°")
    print(f"  Max angular separation: {np.max(angular_seps):.6f}°")
    print()
    
    # SECTION 4: Token Linguistics
    print(f"**TOKEN ANALYSIS**")
    
    # Decode all tokens
    token_data = []
    char_types = []
    
    for token_id in bh['token_ids']:
        try:
            decoded = tokenizer.decode([token_id])
            decoded_repr = repr(decoded)
            char_type = classify_character(decoded)
            char_types.append(char_type)
            token_data.append((token_id, decoded_repr, decoded))
        except:
            token_data.append((token_id, '<ERROR>', '<ERROR>'))
            char_types.append('Error')
    
    # Character type distribution
    char_type_counts = Counter(char_types)
    print(f"\n  Character type distribution:")
    for char_type, count in char_type_counts.most_common():
        pct = count / len(char_types) * 100
        print(f"    {char_type:>15}: {count:>4} ({pct:>5.1f}%)")
    
    # Token table (show all for small clusters, sample for large)
    print(f"\n  Tokens in this cluster:")
    print(f"  {'Token ID':>10} {'Repr':>40}  Token String")
    print("  " + "-" * 80)
    
    if bh['size'] <= 50:
        # Show all
        for token_id, decoded_repr, decoded in token_data:
            # Truncate repr if too long
            if len(decoded_repr) > 40:
                decoded_repr_display = decoded_repr[:37] + "..."
            else:
                decoded_repr_display = decoded_repr
            print(f"  {token_id:>10} {decoded_repr_display:>40}  '{decoded}'")
    else:
        # Show first 20, ellipsis, last 10
        for token_id, decoded_repr, decoded in token_data[:20]:
            if len(decoded_repr) > 40:
                decoded_repr_display = decoded_repr[:37] + "..."
            else:
                decoded_repr_display = decoded_repr
            print(f"  {token_id:>10} {decoded_repr_display:>40}  '{decoded}'")
        
        print(f"\n  ... ({bh['size'] - 30} tokens omitted) ...\n")
        
        for token_id, decoded_repr, decoded in token_data[-10:]:
            if len(decoded_repr) > 40:
                decoded_repr_display = decoded_repr[:37] + "..."
            else:
                decoded_repr_display = decoded_repr
            print(f"  {token_id:>10} {decoded_repr_display:>40}  '{decoded}'")
    
    print()

print("Survey function defined. Ready to iterate over all 13 black holes.")
# Out:
# Survey function defined. Ready to iterate over all 13 black holes.

# %% [markdown]
# ## Step 5: Generate Reports for All 13 Black Holes

# %%
print("\n" + "#"*80)
print("# COMPREHENSIVE BLACK HOLE SURVEY")
print("#"*80)

for i in range(n_holes):
    survey_black_hole(i)

print("\n" + "#"*80)
print("# END OF SURVEY")
print("#"*80)
# Out:
# ################################################################################
# # COMPREHENSIVE BLACK HOLE SURVEY
# ################################################################################
#
# ================================================================================
# BLACK HOLE #1: 814 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 80091
#   Cluster size: 814 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916754007
#   Distance from constellation centroid: 0.000019422885
#   Deviation from mean norm: -8.940696716309e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     2     0.000034137182           0.000000
# #     3     0.000034975299           0.000000
# #     4     0.000015258789           0.000000
# #     5     0.000017059845           0.000000
# #     6     0.000017192635           0.000000
# #     7     0.000034975306           0.000000
# #     8     0.000046574147           0.000000
# #     9     0.000000007451           0.000000
# #    10     0.000070585222           0.000000
# #    11     0.000034975299           0.000000
# #    12     0.000000010537           0.000000
# #    13     0.000034137185           0.000000
#
#   Mean distance to others: 0.000028324075
#   Min distance (nearest): 0.000000007451 → BH #9
#   Max distance (farthest): 0.000070585222 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:  681 ( 83.7%)
#                 CJK:   40 (  4.9%)
#          Whitespace:   32 (  3.9%)
#              Arabic:   29 (  3.6%)
#              Hebrew:   13 (  1.6%)
#        Other Letter:    7 (  0.9%)
#           Diacritic:    4 (  0.5%)
#              Symbol:    3 (  0.4%)
#               Latin:    3 (  0.4%)
#              Number:    1 (  0.1%)
#         Punctuation:    1 (  0.1%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#        80091                                     '２０'  '２０'
#       119346                                     '珊�'  '珊�'
#       119348                                     '珊�'  '珊�'
#       123806                                      '�'  '�'
#       123828                                    'ที่'  'ที่'
#       123870                                      '�'  '�'
#       124027                                   'เป็น'  'เป็น'
#       124033                                    'ไม่'  'ไม่'
#       124055                                    'ได้'  'ได้'
#       124060                                     'ริ'  'ริ'
#       124083                                    'ั้ง'  'ั้ง'
#       124105                                    'ให้'  'ให้'
#       124132                                     'สิ'  'สิ'
#       124139                                    'นี้'  'นี้'
#       124212                                   'ื่อง'  'ื่อง'
#       124238                                     'สั'  'สั'
#       124254                                    'กัน'  'กัน'
#       124258                                    'ผู้'  'ผู้'
#       124311                                     'ดี'  'ดี'
#       124380                                  'อย่าง'  'อย่าง'
#
#   ... (784 tokens omitted) ...
#
#       149122                                      '略'  '略'
#       149124                                      '尿'  '尿'
#       149125                                      '劉'  '劉'
#       149346                                      '精'  '精'
#       149354                                      '難'  '難'
#       149357                                      '說'  '說'
#       149358                                      '礼'  '礼'
#       149415                                      'נּ'  'נּ'
#       149444                                      'יּ'  'יּ'
#       149445                                      'סּ'  'סּ'
#
#
# ================================================================================
# BLACK HOLE #2: 704 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 125
#   Cluster size: 704 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916962624
#   Distance from constellation centroid: 0.000017990298
#   Deviation from mean norm: 1.192092895508e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000034137182           0.000000
# #     3     0.000022894412           0.000000
# #     4     0.000030537132           0.000000
# #     5     0.000031475771           0.000000
# #     6     0.000038198363           0.000000
# #     7     0.000007648071           0.000000
# #     8     0.000038364713           0.000000
# #     9     0.000034137178           0.000000
# #    10     0.000065445813           0.000000
# #    11     0.000007648056           0.000000
# #    12     0.000034137185           0.000000
# #    13     0.000000014901           0.000000
#
#   Mean distance to others: 0.000028719898
#   Min distance (nearest): 0.000000014901 → BH #13
#   Max distance (farthest): 0.000065445813 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:  475 ( 67.5%)
#               Empty:   80 ( 11.4%)
#                 CJK:   64 (  9.1%)
#          Whitespace:   24 (  3.4%)
#              Arabic:   18 (  2.6%)
#              Symbol:   17 (  2.4%)
#              Hebrew:    7 (  1.0%)
#        Other Letter:    6 (  0.9%)
#           Diacritic:    5 (  0.7%)
#               Latin:    5 (  0.7%)
#         Punctuation:    2 (  0.3%)
#              Number:    1 (  0.1%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#          125                                      '�'  '�'
#          177                                      '�'  '�'
#          178                                      '�'  '�'
#          179                                      '�'  '�'
#          181                                      '�'  '�'
#          182                                      '�'  '�'
#          183                                      '�'  '�'
#          184                                      '�'  '�'
#          185                                      '�'  '�'
#          186                                      '�'  '�'
#          187                                      '�'  '�'
#        77150                                     '１０'  '１０'
#       119347                                     '珊�'  '珊�'
#       123848                                      '�'  '�'
#       124030                                    'ว่า'  'ว่า'
#       124031                                     'มี'  'มี'
#       124121                                     'วิ'  'วิ'
#       124294                                     'วั'  'วั'
#       124316                                    'คุณ'  'คุณ'
#       124361                                     'ณ์'  'ณ์'
#
#   ... (674 tokens omitted) ...
#
#       151923                                       ''  ''
#       151924                                       ''  ''
#       151925                                       ''  ''
#       151926                                       ''  ''
#       151927                                       ''  ''
#       151928                                       ''  ''
#       151930                                       ''  ''
#       151932                                       ''  ''
#       151933                                       ''  ''
#       151934                                       ''  ''
#
#
# ================================================================================
# BLACK HOLE #3: 306 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 124
#   Cluster size: 306 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370917201042
#   Distance from constellation centroid: 0.000020432299
#   Deviation from mean norm: 3.576278686523e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000034975299           0.000000
# #     2     0.000022894412           0.000000
# #     4     0.000038158905           0.000000
# #     5     0.000038914135           0.000000
# #     6     0.000030577128           0.000000
# #     7     0.000024126268           0.000000
# #     8     0.000030784689           0.000000
# #     9     0.000034975295           0.000000
# #    10     0.000062252839           0.000000
# #    11     0.000021579228           0.000000
# #    12     0.000034975306           0.000000
# #    13     0.000022894415           0.000000
#
#   Mean distance to others: 0.000033092327
#   Min distance (nearest): 0.000021579228 → BH #11
#   Max distance (farthest): 0.000062252839 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:  179 ( 58.5%)
#               Empty:   66 ( 21.6%)
#                 CJK:   32 ( 10.5%)
#          Whitespace:   15 (  4.9%)
#              Arabic:    7 (  2.3%)
#              Symbol:    2 (  0.7%)
#              Hebrew:    2 (  0.7%)
#           Diacritic:    1 (  0.3%)
#         Punctuation:    1 (  0.3%)
#        Other Letter:    1 (  0.3%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#          124                                      '�'  '�'
#       123876                                      '�'  '�'
#       123948                                     'ติ'  'ติ'
#       124076                                     'ก็'  'ก็'
#       124129                                    'อร์'  'อร์'
#       124171                                     'ต่'  'ต่'
#       124175                                     'คุ'  'คุ'
#       124779                                    'ึ่ง'  'ึ่ง'
#       124939                                     'อั'  'อั'
#       124942                                    'เร็'  'เร็'
#       124946                                   'ชาติ'  'ชาติ'
#       124963                                     'ทั'  'ทั'
#       125015                                   'นั้น'  'นั้น'
#       125034                                    'ทุก'  'ทุก'
#       125213                                    'ปัญ'  'ปัญ'
#       125442                                   ' แต่'  ' แต่'
#       125491                                    'คือ'  'คือ'
#       125507                                'เครื่อง'  'เครื่อง'
#       125707                                     'ยิ'  'ยิ'
#       125794                                     'ลี'  'ลี'
#
#   ... (276 tokens omitted) ...
#
#       151901                                       ''  ''
#       151904                                       ''  ''
#       151905                                       ''  ''
#       151907                                       ''  ''
#       151910                                       ''  ''
#       151913                                       ''  ''
#       151914                                       ''  ''
#       151915                                       ''  ''
#       151916                                       ''  ''
#       151919                                       ''  ''
#
#
# ================================================================================
# BLACK HOLE #4: 228 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 124350
#   Cluster size: 228 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916694403
#   Distance from constellation centroid: 0.000019878664
#   Deviation from mean norm: -1.490116119385e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000015258789           0.000000
# #     2     0.000030537132           0.000000
# #     3     0.000038158905           0.000000
# #     5     0.000007629395           0.000000
# #     6     0.000022987329           0.000000
# #     7     0.000031471282           0.000000
# #     8     0.000049010017           0.000000
# #     9     0.000015258791           0.000000
# #    10     0.000072215676           0.000000
# #    11     0.000031471271           0.000000
# #    12     0.000015258793           0.000000
# #    13     0.000030537136           0.000000
#
#   Mean distance to others: 0.000029982876
#   Min distance (nearest): 0.000007629395 → BH #5
#   Max distance (farthest): 0.000072215676 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#               Empty:  116 ( 50.9%)
#                Thai:   55 ( 24.1%)
#                 CJK:   42 ( 18.4%)
#          Whitespace:    6 (  2.6%)
#              Symbol:    6 (  2.6%)
#              Hebrew:    2 (  0.9%)
#        Other Letter:    1 (  0.4%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       124350                                   'เรีย'  'เรีย'
#       124658                                     'ย์'  'ย์'
#       125147                                    'ติด'  'ติด'
#       125460                                   'บ้าน'  'บ้าน'
#       126425                                   'ห้อง'  'ห้อง'
#       126849                                   'เดิม'  'เดิม'
#       127720                                   'สูตร'  'สูตร'
#       127740                                  'เยี่ย'  'เยี่ย'
#       130880                              'เพิ่มเติม'  'เพิ่มเติม'
#       131312                                  'อุปกร'  'อุปกร'
#       131886                                'ร่างกาย'  'ร่างกาย'
#       136799                                  'ง่ายๆ'  'ง่ายๆ'
#       136811                                  'อนุญา'  'อนุญา'
#       139157                                   'ค่อน'  'ค่อน'
#       139170                                 'รับประ'  'รับประ'
#       139635                                   'เติบ'  'เติบ'
#       141495                                 'พฤศจิก'  'พฤศจิก'
#       141510                                 'เลยค่ะ'  'เลยค่ะ'
#       141511                                  'พบกับ'  'พบกับ'
#       142271                                     'ผี'  'ผี'
#
#   ... (198 tokens omitted) ...
#
#       151872                                       ''  ''
#       151873                                       ''  ''
#       151878                                       ''  ''
#       151881                                       ''  ''
#       151882                                       ''  ''
#       151883                                       ''  ''
#       151899                                       ''  ''
#       151908                                       ''  ''
#       151917                                       ''  ''
#       151935                                       ''  ''
#
#
# ================================================================================
# BLACK HOLE #5: 11 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 123939
#   Cluster size: 11 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916634798
#   Distance from constellation centroid: 0.000020867670
#   Deviation from mean norm: -2.086162567139e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000017059845           0.000000
# #     2     0.000031475771           0.000000
# #     3     0.000038914135           0.000000
# #     4     0.000007629395           0.000000
# #     6     0.000024220342           0.000000
# #     7     0.000030532505           0.000000
# #     8     0.000049600298           0.000000
# #     9     0.000017059847           0.000000
# #    10     0.000072617571           0.000000
# #    11     0.000032382843           0.000000
# #    12     0.000017059849           0.000000
# #    13     0.000031475774           0.000000
#
#   Mean distance to others: 0.000030835681
#   Min distance (nearest): 0.000007629395 → BH #4
#   Max distance (farthest): 0.000072617571 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    9 ( 81.8%)
#              Arabic:    1 (  9.1%)
#          Whitespace:    1 (  9.1%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       123939                                     'ร์'  'ร์'
#       131955                                    'ฟุต'  'ฟุต'
#       131957                                   'ฝ่าย'  'ฝ่าย'
#       134988                               'ส่วนใหญ่'  'ส่วนใหญ่'
#       134991                                   'ว่าง'  'ว่าง'
#       138524                                'ห้องพัก'  'ห้องพัก'
#       138538                                     'دُ'  'دُ'
#       138547                               ' เป็นต้น'  ' เป็นต้น'
#       139123                                  'ศักดิ'  'ศักดิ'
#       140073                              'ในพื้นที่'  'ในพื้นที่'
#       140074                                  'เครือ'  'เครือ'
#
#
# ================================================================================
# BLACK HOLE #6: 10 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 119349
#   Cluster size: 10 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916903019
#   Distance from constellation centroid: 0.000022172837
#   Deviation from mean norm: 5.960464477539e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000017192635           0.000000
# #     2     0.000038198363           0.000000
# #     3     0.000030577128           0.000000
# #     4     0.000022987329           0.000000
# #     5     0.000024220342           0.000000
# #     7     0.000038949172           0.000000
# #     8     0.000043389624           0.000000
# #     9     0.000017192635           0.000000
# #    10     0.000069304413           0.000000
# #    11     0.000037424910           0.000000
# #    12     0.000017192649           0.000000
# #    13     0.000038198363           0.000000
#
#   Mean distance to others: 0.000032902297
#   Min distance (nearest): 0.000017192635 → BH #1
#   Max distance (farthest): 0.000069304413 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    7 ( 70.0%)
#          Whitespace:    2 ( 20.0%)
#                 CJK:    1 ( 10.0%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       119349                                     '珊󠄁'  '珊󠄁'
#       125087                                   'ช่วย'  'ช่วย'
#       126630                                    'จัง'  'จัง'
#       137856                                    'กรี'  'กรี'
#       138110                                 'ผู้ใช้'  'ผู้ใช้'
#       139345                                   'ภาษี'  'ภาษี'
#       142061                               ' อย่างไร'  ' อย่างไร'
#       143029                              'เชื่อมต่อ'  'เชื่อมต่อ'
#       143036                                 ' مساءً'  ' مساءً'
#       143048                                  'ศิลปะ'  'ศิลปะ'
#
#
# ================================================================================
# BLACK HOLE #7: 6 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 126268
#   Cluster size: 6 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916932821
#   Distance from constellation centroid: 0.000019072308
#   Deviation from mean norm: 8.940696716309e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000034975306           0.000000
# #     2     0.000007648071           0.000000
# #     3     0.000024126268           0.000000
# #     4     0.000031471282           0.000000
# #     5     0.000030532505           0.000000
# #     6     0.000038949172           0.000000
# #     8     0.000039112299           0.000000
# #     9     0.000034975303           0.000000
# #    10     0.000065886845           0.000000
# #    11     0.000010789686           0.000000
# #    12     0.000034975321           0.000000
# #    13     0.000007648086           0.000000
#
#   Mean distance to others: 0.000030090845
#   Min distance (nearest): 0.000007648071 → BH #2
#   Max distance (farthest): 0.000065886845 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    3 ( 50.0%)
#                 CJK:    2 ( 33.3%)
#               Empty:    1 ( 16.7%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       126268                                     'สี'  'สี'
#       132713                                 'ประกัน'  'ประกัน'
#       138041                                    'ซี่'  'ซี่'
#       146501                                      '龍'  '龍'
#       148028                                      '林'  '林'
#       151889                                       ''  ''
#
#
# ================================================================================
# BLACK HOLE #8: 5 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 132383
#   Cluster size: 5 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370917588472
#   Distance from constellation centroid: 0.000034877572
#   Deviation from mean norm: 7.450580596924e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000046574147           0.000000
# #     2     0.000038364713           0.000000
# #     3     0.000030784689           0.000000
# #     4     0.000049010017           0.000000
# #     5     0.000049600298           0.000000
# #     6     0.000043389624           0.000000
# #     7     0.000039112299           0.000000
# #     9     0.000046574136           0.000000
# #    10     0.000069238740           0.000000
# #    11     0.000037594680           0.000000
# #    12     0.000046574165           0.000000
# #    13     0.000038364713           0.000000
#
#   Mean distance to others: 0.000044598518
#   Min distance (nearest): 0.000030784689 → BH #3
#   Max distance (farthest): 0.000069238740 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    5 (100.0%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       132383                                   'เย็น'  'เย็น'
#       132398                                     'นี'  'นี'
#       139050                                  'เพิ่ง'  'เพิ่ง'
#       142718                                  'มะเร็'  'มะเร็'
#       142719                                 'มะเร็ง'  'มะเร็ง'
#
#
# ================================================================================
# BLACK HOLE #9: 4 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 135619
#   Cluster size: 4 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916754007
#   Distance from constellation centroid: 0.000019422880
#   Deviation from mean norm: -8.940696716309e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000000007451           0.000000
# #     2     0.000034137178           0.000000
# #     3     0.000034975295           0.000000
# #     4     0.000015258791           0.000000
# #     5     0.000017059847           0.000000
# #     6     0.000017192635           0.000000
# #     7     0.000034975303           0.000000
# #     8     0.000046574136           0.000000
# #    10     0.000070585214           0.000000
# #    11     0.000034975295           0.000000
# #    12     0.000000016660           0.000000
# #    13     0.000034137182           0.000000
#
#   Mean distance to others: 0.000028324582
#   Min distance (nearest): 0.000000007451 → BH #1
#   Max distance (farthest): 0.000070585214 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    3 ( 75.0%)
#          Whitespace:    1 ( 25.0%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       135619                                  'เปอร์'  'เปอร์'
#       138490                                'ร่วมกัน'  'ร่วมกัน'
#       140815                                 'ที่น่า'  'ที่น่า'
#       143457                                  ' của'  ' của'
#
#
# ================================================================================
# BLACK HOLE #10: 4 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 136831
#   Cluster size: 4 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370915770531
#   Distance from constellation centroid: 0.000060185255
#   Deviation from mean norm: -1.072883605957e-06
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000070585222           0.000000
# #     2     0.000065445813           0.000000
# #     3     0.000062252839           0.000000
# #     4     0.000072215676           0.000000
# #     5     0.000072617571           0.000000
# #     6     0.000069304413           0.000000
# #     7     0.000065886845           0.000000
# #     8     0.000069238740           0.000000
# #     9     0.000070585214           0.000000
# #    11     0.000065886859           0.000000
# #    12     0.000070585229           0.000000
# #    13     0.000065445813           0.000000
#
#   Mean distance to others: 0.000068337520
#   Min distance (nearest): 0.000062252839 → BH #3
#   Max distance (farthest): 0.000072617571 → BH #5
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    2 ( 50.0%)
#               Latin:    1 ( 25.0%)
#          Whitespace:    1 ( 25.0%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       136831                                    'สติ'  'สติ'
#       138068                                     'ể'  'ể'
#       138072                               ' จากนั้น'  ' จากนั้น'
#       139278                                   'เกือ'  'เกือ'
#
#
# ================================================================================
# BLACK HOLE #11: 3 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 180
#   Cluster size: 3 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916932821
#   Distance from constellation centroid: 0.000018596838
#   Deviation from mean norm: 8.940696716309e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000034975299           0.000000
# #     2     0.000007648056           0.000000
# #     3     0.000021579228           0.000000
# #     4     0.000031471271           0.000000
# #     5     0.000032382843           0.000000
# #     6     0.000037424910           0.000000
# #     7     0.000010789686           0.000000
# #     8     0.000037594680           0.000000
# #     9     0.000034975295           0.000000
# #    10     0.000065886859           0.000000
# #    12     0.000034975303           0.000000
# #    13     0.000007648013           0.000000
#
#   Mean distance to others: 0.000029779287
#   Min distance (nearest): 0.000007648013 → BH #13
#   Max distance (farthest): 0.000065886859 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    2 ( 66.7%)
#              Symbol:    1 ( 33.3%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#          180                                      '�'  '�'
#       138979                                 'รับรอง'  'รับรอง'
#       141503                              'การบริหาร'  'การบริหาร'
#
#
# ================================================================================
# BLACK HOLE #12: 3 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 126775
#   Cluster size: 3 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916754007
#   Distance from constellation centroid: 0.000019422898
#   Deviation from mean norm: -8.940696716309e-08
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000000010537           0.000000
# #     2     0.000034137185           0.000000
# #     3     0.000034975306           0.000000
# #     4     0.000015258793           0.000000
# #     5     0.000017059849           0.000000
# #     6     0.000017192649           0.000000
# #     7     0.000034975321           0.000000
# #     8     0.000046574165           0.000000
# #     9     0.000000016660           0.000000
# #    10     0.000070585229           0.000000
# #    11     0.000034975303           0.000000
# #    13     0.000034137189           0.000000
#
#   Mean distance to others: 0.000028324849
#   Min distance (nearest): 0.000000010537 → BH #1
#   Max distance (farthest): 0.000070585229 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    2 ( 66.7%)
#                 CJK:    1 ( 33.3%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       126775                                    'รัฐ'  'รัฐ'
#       140303                                    'ซ้ำ'  'ซ้ำ'
#       147056                                      '切'  '切'
#
#
# ================================================================================
# BLACK HOLE #13: 2 TOKENS
# ================================================================================
#
# **IDENTITY**
#   Representative token ID: 126816
#   Cluster size: 2 tokens
#
# **SPATIAL PROPERTIES**
#   Norm (distance from origin): 0.370916962624
#   Distance from constellation centroid: 0.000017990302
#   Deviation from mean norm: 1.192092895508e-07
#
# **RELATIONSHIPS TO OTHER BLACK HOLES**
#   To BH     Euclidean Dist    Angular Sep (°)
# --------------------------------------------------
# #     1     0.000034137185           0.000000
# #     2     0.000000014901           0.000000
# #     3     0.000022894415           0.000000
# #     4     0.000030537136           0.000000
# #     5     0.000031475774           0.000000
# #     6     0.000038198363           0.000000
# #     7     0.000007648086           0.000000
# #     8     0.000038364713           0.000000
# #     9     0.000034137182           0.000000
# #    10     0.000065445813           0.000000
# #    11     0.000007648013           0.000000
# #    12     0.000034137189           0.000000
#
#   Mean distance to others: 0.000028719897
#   Min distance (nearest): 0.000000014901 → BH #2
#   Max distance (farthest): 0.000065445813 → BH #10
#
#   Mean angular separation: 0.000000°
#   Min angular separation: 0.000000°
#   Max angular separation: 0.000000°
#
# **TOKEN ANALYSIS**
#
#   Character type distribution:
#                Thai:    1 ( 50.0%)
#              Hebrew:    1 ( 50.0%)
#
#   Tokens in this cluster:
#     Token ID                                     Repr  Token String
#   --------------------------------------------------------------------------------
#       126816                                    'สมั'  'สมั'
#       147836                                      'אַ'  'אַ'
#
#
# ################################################################################
# # END OF SURVEY
# ################################################################################

# %% [markdown]
# ## Summary
#
# We've surveyed all 13 primordial black holes in detail.
#
# **Key observations to look for:**
# 1. **Black hole #9** - Is it significantly more distant from the others?
# 2. **Token types** - Are certain clusters dominated by specific scripts (Thai, CJK, Hebrew)?
# 3. **Angular clustering** - Within the constellation, are black holes angularly close or spread out?
# 4. **Outliers** - Do any black holes have unusual properties?
#
# The fact that all 13 lie at essentially the same radius (r ≈ 0.3709) suggests a common formation mechanism—likely tokens that were initialized near this radius and received minimal or zero training signal, leaving them frozen in place.
