# %% [markdown]
# # 06.1p: Cuckoo Zone Survey
#
# **Goal:** Comprehensive analysis of the 27 tokens in the "cuckoo zone" (1e-4 to 1e-3 from black hole centroid).
#
# These are the tokens that sit just outside the ultra-dense black hole cluster, in the region with wild density variation. For each cuckoo token we'll report:
# - Token ID and decoded string
# - Distance from black hole centroid
# - Pairwise Euclidean distances to all other cuckoos
# - Angular separations from other cuckoos
# - Character classification
# - Nearest black hole
#
# This is Volume 6: Pathologies and Singularities

# %% [markdown]
# ## Parameters

# %%
TENSOR_DIR = "../data/tensors"
GAMMA_FILE = "gamma_qwen3_4b_instruct_2507.safetensors"
MODEL_NAME = "Qwen/Qwen3-4B-Instruct-2507"

# Cuckoo zone boundaries
CUCKOO_R_INNER = 1e-4
CUCKOO_R_OUTER = 1e-3

# Random seed
RANDOM_SEED = 42

# %% [markdown]
# ## Imports

# %%
import torch
import numpy as np
from safetensors.torch import load_file
from pathlib import Path
from collections import defaultdict
from transformers import AutoTokenizer
import unicodedata

print("Imports loaded successfully.")
# Out:
# Imports loaded successfully.

# %% [markdown]
# ## Step 1: Load Data and Identify Black Hole Centroid

# %%
print("Loading gamma matrix...")
gamma_path = Path(TENSOR_DIR) / GAMMA_FILE
gamma = load_file(gamma_path)['gamma']
N, d = gamma.shape
print(f"Loaded: {gamma.shape}\n")

print("Finding degenerate clusters...\n")

gamma_np = gamma.cpu().numpy()
unique_vecs, inverse_indices, counts = np.unique(
    gamma_np, 
    axis=0, 
    return_inverse=True, 
    return_counts=True
)

# Build clusters
clusters = defaultdict(list)
for token_id, unique_idx in enumerate(inverse_indices):
    clusters[unique_idx].append(token_id)

# Filter to degenerate clusters
degenerate_clusters = {idx: tokens for idx, tokens in clusters.items() if len(tokens) > 1}

# Sort by size, descending
sorted_clusters = sorted(degenerate_clusters.items(), key=lambda x: len(x[1]), reverse=True)

# Extract all black hole token IDs (top 13 clusters)
black_hole_token_ids = []
for unique_idx, token_ids in sorted_clusters[:13]:
    black_hole_token_ids.extend(token_ids)

black_hole_token_ids = sorted(black_hole_token_ids)
black_hole_set = set(black_hole_token_ids)

print(f"Identified {len(black_hole_token_ids)} black hole tokens")

# Compute centroid
black_hole_embeddings = gamma[black_hole_token_ids]
centroid = black_hole_embeddings.mean(dim=0)
centroid_norm = torch.norm(centroid)

print(f"Black hole centroid norm: {centroid_norm.item():.12f}")
# Out:
# Loading gamma matrix...
# Loaded: torch.Size([151936, 2560])
#
# Finding degenerate clusters...
#
# Identified 2100 black hole tokens
# Black hole centroid norm: 0.370916873217

# %% [markdown]
# ## Step 2: Extract Cuckoo Zone Tokens

# %%
print("\n" + "="*70)
print(f"EXTRACTING CUCKOO ZONE TOKENS ({CUCKOO_R_INNER:.0e} < r < {CUCKOO_R_OUTER:.0e})")
print("="*70)
print()

# Compute distances from centroid
distances = torch.norm(gamma - centroid, dim=1)

# Find tokens in cuckoo zone
in_cuckoo_zone = (distances > CUCKOO_R_INNER) & (distances <= CUCKOO_R_OUTER)
cuckoo_token_ids = torch.where(in_cuckoo_zone)[0].tolist()
cuckoo_distances = distances[in_cuckoo_zone]
cuckoo_embeddings = gamma[in_cuckoo_zone]

print(f"Found {len(cuckoo_token_ids)} tokens in the cuckoo zone")
print(f"\nDistance range:")
print(f"  Min: {cuckoo_distances.min().item():.12e}")
print(f"  Max: {cuckoo_distances.max().item():.12e}")
print(f"  Mean: {cuckoo_distances.mean().item():.12e}")
print(f"  Median: {cuckoo_distances.median().item():.12e}")
# Out:
# ======================================================================
# EXTRACTING CUCKOO ZONE TOKENS (1e-04 < r < 1e-03)
# ======================================================================
#
# Found 27 tokens in the cuckoo zone
#
# Distance range:
#   Min: 1.011977947201e-04
#   Max: 9.954774286598e-04
#   Mean: 3.191469004378e-04
#   Median: 1.878242037492e-04

# %% [markdown]
# ## Step 3: Load Tokenizer

# %%
print("\n" + "="*70)
print("LOADING TOKENIZER")
print("="*70)
print()

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
print(f"Tokenizer loaded: {len(tokenizer)} tokens\n")
# Out:
# ======================================================================
# LOADING TOKENIZER
# ======================================================================
#
# Tokenizer loaded: 151669 tokens

# %% [markdown]
# ## Step 4: Character Classification Function

# %%
def classify_character(char):
    """Classify a character by Unicode category and name."""
    if not char:
        return 'Empty'
    
    try:
        cat = unicodedata.category(char[0])
        name = unicodedata.name(char[0], '<UNNAMED>')
        
        # Check for specific scripts in the name
        if 'THAI' in name:
            return 'Thai'
        elif 'CJK' in name or 'HIRAGANA' in name or 'KATAKANA' in name or 'HANGUL' in name:
            return 'CJK'
        elif 'ARABIC' in name:
            return 'Arabic'
        elif 'HEBREW' in name:
            return 'Hebrew'
        elif 'CYRILLIC' in name:
            return 'Cyrillic'
        elif 'GREEK' in name:
            return 'Greek'
        elif 'LATIN' in name:
            # Further subdivide Latin
            if cat.startswith('L'):  # Letter
                return 'Latin Letter'
            elif cat.startswith('N'):  # Number
                return 'Latin Number'
            elif cat.startswith('P'):  # Punctuation
                return 'Latin Punctuation'
            else:
                return 'Latin Other'
        elif cat.startswith('Z'):  # Separator (space, etc.)
            return 'Whitespace'
        elif cat.startswith('P'):  # Punctuation
            return 'Punctuation'
        elif cat.startswith('N'):  # Number
            return 'Number'
        elif cat.startswith('S'):  # Symbol
            return 'Symbol'
        else:
            return 'Other'
    except Exception as e:
        return f'Error: {e}'

print("Character classification function defined.")
# Out:
# Character classification function defined.

# %% [markdown]
# ## Step 5: Compute Pairwise Distances

# %%
print("\n" + "="*70)
print("COMPUTING PAIRWISE DISTANCES BETWEEN CUCKOOS")
print("="*70)
print()

# Euclidean pairwise distances
pairwise_dists = torch.cdist(cuckoo_embeddings, cuckoo_embeddings, p=2)

# Angular distances (using normalized vectors)
cuckoo_normed = cuckoo_embeddings / torch.norm(cuckoo_embeddings, dim=1, keepdim=True)
cosine_sims = cuckoo_normed @ cuckoo_normed.T
angular_dists = torch.acos(torch.clamp(cosine_sims, -1.0, 1.0))

print(f"Computed {len(cuckoo_token_ids)}×{len(cuckoo_token_ids)} distance matrices")
print(f"\nEuclidean distance statistics:")
# Extract upper triangle (excluding diagonal)
mask = torch.triu(torch.ones_like(pairwise_dists, dtype=bool), diagonal=1)
unique_dists = pairwise_dists[mask]
print(f"  Min: {unique_dists.min().item():.12e}")
print(f"  Max: {unique_dists.max().item():.12e}")
print(f"  Mean: {unique_dists.mean().item():.12e}")
print(f"  Median: {unique_dists.median().item():.12e}")

print(f"\nAngular distance statistics:")
unique_angles = angular_dists[mask]
print(f"  Min: {unique_angles.min().item():.6f} rad ({torch.rad2deg(unique_angles.min()).item():.4f}°)")
print(f"  Max: {unique_angles.max().item():.6f} rad ({torch.rad2deg(unique_angles.max()).item():.4f}°)")
print(f"  Mean: {unique_angles.mean().item():.6f} rad ({torch.rad2deg(unique_angles.mean()).item():.4f}°)")
print(f"  Median: {unique_angles.median().item():.6f} rad ({torch.rad2deg(unique_angles.median()).item():.4f}°)")
# Out:
# ======================================================================
# COMPUTING PAIRWISE DISTANCES BETWEEN CUCKOOS
# ======================================================================
#
# Computed 27×27 distance matrices
#
# Euclidean distance statistics:
#   Min: 4.401307669468e-04
#   Max: 1.722013694234e-03
#   Mean: 9.701765957288e-04
#   Median: 9.533996344544e-04
#
# Angular distance statistics:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.003347 rad (0.1918°)
#   Mean: 0.000355 rad (0.0204°)
#   Median: 0.000000 rad (0.0000°)

# %% [markdown]
# ## Step 6: Find Nearest Black Hole for Each Cuckoo

# %%
print("\n" + "="*70)
print("FINDING NEAREST BLACK HOLE FOR EACH CUCKOO")
print("="*70)
print()

# Compute distances from each cuckoo to all black holes
cuckoo_to_bh_dists = torch.cdist(cuckoo_embeddings, black_hole_embeddings, p=2)

# For each cuckoo, find nearest black hole
nearest_bh_dists, nearest_bh_indices = cuckoo_to_bh_dists.min(dim=1)
nearest_bh_token_ids = [black_hole_token_ids[idx] for idx in nearest_bh_indices]

print(f"Computed nearest black hole for each of {len(cuckoo_token_ids)} cuckoos")
print(f"\nDistance to nearest black hole:")
print(f"  Min: {nearest_bh_dists.min().item():.12e}")
print(f"  Max: {nearest_bh_dists.max().item():.12e}")
print(f"  Mean: {nearest_bh_dists.mean().item():.12e}")
# Out:
# ======================================================================
# FINDING NEAREST BLACK HOLE FOR EACH CUCKOO
# ======================================================================
#
# Computed nearest black hole for each of 27 cuckoos
#
# Distance to nearest black hole:
#   Min: 5.459150415845e-04
#   Max: 1.170857343823e-03
#   Mean: 8.674336131662e-04

# %% [markdown]
# ## Step 7: Complete Dossier for Each Cuckoo

# %%
print("\n" + "="*70)
print("CUCKOO ZONE COMPLETE SURVEY")
print("="*70)
print()

for i, token_id in enumerate(cuckoo_token_ids):
    # Basic info
    token_str = tokenizer.decode([token_id])
    dist_from_centroid = cuckoo_distances[i].item()
    embedding = cuckoo_embeddings[i]
    embedding_norm = torch.norm(embedding).item()
    
    # Character classification
    char_type = classify_character(token_str)
    
    # Nearest black hole
    nearest_bh_id = nearest_bh_token_ids[i]
    nearest_bh_dist = nearest_bh_dists[i].item()
    nearest_bh_str = tokenizer.decode([nearest_bh_id])
    
    # Distances to other cuckoos
    dists_to_others = pairwise_dists[i].cpu().numpy()
    angles_to_others = angular_dists[i].cpu().numpy()
    
    # Exclude self (distance = 0)
    other_indices = [j for j in range(len(cuckoo_token_ids)) if j != i]
    dists_to_others_filtered = dists_to_others[other_indices]
    angles_to_others_filtered = angles_to_others[other_indices]
    
    closest_other_idx = other_indices[dists_to_others_filtered.argmin()]
    closest_other_id = cuckoo_token_ids[closest_other_idx]
    closest_other_dist = dists_to_others[closest_other_idx]
    
    farthest_other_idx = other_indices[dists_to_others_filtered.argmax()]
    farthest_other_id = cuckoo_token_ids[farthest_other_idx]
    farthest_other_dist = dists_to_others[farthest_other_idx]
    
    print(f"\n{'='*70}")
    print(f"CUCKOO #{i+1} of {len(cuckoo_token_ids)}")
    print(f"{'='*70}")
    print(f"Token ID: {token_id}")
    print(f"Token string: '{token_str}'")
    print(f"Character type: {char_type}")
    print()
    print(f"Spatial properties:")
    print(f"  Distance from black hole centroid: {dist_from_centroid:.12e}")
    print(f"  Embedding norm (distance from origin): {embedding_norm:.12f}")
    print()
    print(f"Nearest black hole:")
    print(f"  Token ID: {nearest_bh_id}")
    print(f"  Token string: '{nearest_bh_str}'")
    print(f"  Distance: {nearest_bh_dist:.12e}")
    print()
    print(f"Distances to other cuckoos:")
    print(f"  Closest: token {closest_other_id} at {closest_other_dist:.12e}")
    print(f"  Farthest: token {farthest_other_id} at {farthest_other_dist:.12e}")
    print(f"  Mean: {dists_to_others_filtered.mean():.12e}")
    print(f"  Median: {np.median(dists_to_others_filtered):.12e}")
    print()
    print(f"Angular separations from other cuckoos:")
    print(f"  Min: {angles_to_others_filtered.min():.6f} rad ({np.rad2deg(angles_to_others_filtered.min()):.4f}°)")
    print(f"  Max: {angles_to_others_filtered.max():.6f} rad ({np.rad2deg(angles_to_others_filtered.max()):.4f}°)")
    print(f"  Mean: {angles_to_others_filtered.mean():.6f} rad ({np.rad2deg(angles_to_others_filtered.mean()):.4f}°)")
# Out:
# ======================================================================
# CUCKOO ZONE COMPLETE SURVEY
# ======================================================================
#
#
# ======================================================================
# CUCKOO #1 of 27
# ======================================================================
# Token ID: 83971
# Token string: '$PostalCodesNL'
# Character type: Symbol
#
# Spatial properties:
#   Distance from black hole centroid: 7.319091237150e-04
#   Embedding norm (distance from origin): 0.370950996876
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 1.118792919442e-03
#
# Distances to other cuckoos:
#   Closest: token 133377 at 9.917039424181e-04
#   Farthest: token 125869 at 1.485049491748e-03
#   Mean: 1.138059189543e-03
#   Median: 1.108753611334e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002740 rad (0.1570°)
#   Mean: 0.000953 rad (0.0546°)
#
# ======================================================================
# CUCKOO #2 of 27
# ======================================================================
# Token ID: 123952
# Token string: 'ด้'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.268317428185e-04
#   Embedding norm (distance from origin): 0.370916336775
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 7.324218750000e-04
#
# Distances to other cuckoos:
#   Closest: token 127974 at 5.980199784972e-04
#   Farthest: token 125869 at 1.291870721616e-03
#   Mean: 8.691964903846e-04
#   Median: 8.501100819558e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002290 rad (0.1312°)
#   Mean: 0.000192 rad (0.0110°)
#
# ======================================================================
# CUCKOO #3 of 27
# ======================================================================
# Token ID: 125047
# Token string: 'ปี'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.289682113566e-04
#   Embedding norm (distance from origin): 0.370917707682
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 8.004685514607e-04
#
# Distances to other cuckoos:
#   Closest: token 136401 at 5.593964597210e-04
#   Farthest: token 125869 at 1.262705074623e-03
#   Mean: 9.059956646524e-04
#   Median: 9.011637885123e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002367 rad (0.1356°)
#   Mean: 0.000188 rad (0.0108°)
#
# ======================================================================
# CUCKOO #4 of 27
# ======================================================================
# Token ID: 125125
# Token string: 'สุ'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.488070265623e-04
#   Embedding norm (distance from origin): 0.370916575193
#
# Nearest black hole:
#   Token ID: 125
#   Token string: '�'
#   Distance: 6.459353608079e-04
#
# Distances to other cuckoos:
#   Closest: token 148826 at 5.179004510865e-04
#   Farthest: token 140964 at 1.331629930064e-03
#   Mean: 8.408192079514e-04
#   Median: 8.142977021635e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.001983 rad (0.1136°)
#   Mean: 0.000183 rad (0.0105°)
#
# ======================================================================
# CUCKOO #5 of 27
# ======================================================================
# Token ID: 125458
# Token string: 'ซึ่ง'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 3.626922843978e-04
#   Embedding norm (distance from origin): 0.370916575193
#
# Nearest black hole:
#   Token ID: 119349
#   Token string: '珊󠄁'
#   Distance: 7.117860950530e-04
#
# Distances to other cuckoos:
#   Closest: token 136401 at 6.573687423952e-04
#   Farthest: token 140964 at 1.303354278207e-03
#   Mean: 9.247540729120e-04
#   Median: 8.760089986026e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002128 rad (0.1219°)
#   Mean: 0.000194 rad (0.0111°)
#
# ======================================================================
# CUCKOO #6 of 27
# ======================================================================
# Token ID: 125687
# Token string: 'อัน'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.241522113560e-04
#   Embedding norm (distance from origin): 0.370916694403
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 8.279211469926e-04
#
# Distances to other cuckoos:
#   Closest: token 132191 at 7.012405549176e-04
#   Farthest: token 140964 at 1.250848523341e-03
#   Mean: 9.261350496672e-04
#   Median: 8.966835448518e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.001761 rad (0.1009°)
#   Mean: 0.000158 rad (0.0091°)
#
# ======================================================================
# CUCKOO #7 of 27
# ======================================================================
# Token ID: 125869
# Token string: 'เร็ว'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 9.215552709065e-04
#   Embedding norm (distance from origin): 0.370897650719
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 1.170857343823e-03
#
# Distances to other cuckoos:
#   Closest: token 136834 at 1.057159970514e-03
#   Farthest: token 140964 at 1.722013694234e-03
#   Mean: 1.254500704817e-03
#   Median: 1.229820540175e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000598 rad (0.0343°)
#   Max: 0.003347 rad (0.1918°)
#   Mean: 0.001705 rad (0.0977°)
#
# ======================================================================
# CUCKOO #8 of 27
# ======================================================================
# Token ID: 127974
# Token string: 'ปลอดภัย'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.878242037492e-04
#   Embedding norm (distance from origin): 0.370918333530
#
# Nearest black hole:
#   Token ID: 125
#   Token string: '�'
#   Distance: 8.279211469926e-04
#
# Distances to other cuckoos:
#   Closest: token 123952 at 5.980199784972e-04
#   Farthest: token 140964 at 1.262705074623e-03
#   Mean: 8.856945205480e-04
#   Median: 8.759263437241e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.001891 rad (0.1084°)
#   Mean: 0.000175 rad (0.0100°)
#
# ======================================================================
# CUCKOO #9 of 27
# ======================================================================
# Token ID: 129604
# Token string: 'พู'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.487159024691e-04
#   Embedding norm (distance from origin): 0.370916903019
#
# Nearest black hole:
#   Token ID: 125
#   Token string: '�'
#   Distance: 8.802615338936e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 7.117860950530e-04
#   Farthest: token 140964 at 1.202253159136e-03
#   Mean: 9.380342671648e-04
#   Median: 9.256352204829e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002100 rad (0.1203°)
#   Mean: 0.000134 rad (0.0077°)
#
# ======================================================================
# CUCKOO #10 of 27
# ======================================================================
# Token ID: 132191
# Token string: 'ติดตาม'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.396652805852e-04
#   Embedding norm (distance from origin): 0.370917230844
#
# Nearest black hole:
#   Token ID: 80091
#   Token string: '２０'
#   Distance: 8.886852883734e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 6.342959241010e-04
#   Farthest: token 140964 at 1.291870721616e-03
#   Mean: 8.885835995898e-04
#   Median: 8.717144955881e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002100 rad (0.1203°)
#   Mean: 0.000127 rad (0.0073°)
#
# ======================================================================
# CUCKOO #11 of 27
# ======================================================================
# Token ID: 133377
# Token string: 'เนีย'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.500094076619e-04
#   Embedding norm (distance from origin): 0.370916783810
#
# Nearest black hole:
#   Token ID: 80091
#   Token string: '２０'
#   Distance: 5.459150415845e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 5.980199784972e-04
#   Farthest: token 140964 at 1.331629930064e-03
#   Mean: 8.724816725589e-04
#   Median: 8.368719136342e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.001794 rad (0.1028°)
#   Mean: 0.000130 rad (0.0074°)
#
# ======================================================================
# CUCKOO #12 of 27
# ======================================================================
# Token ID: 136401
# Token string: 'ปู'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.592359767528e-04
#   Embedding norm (distance from origin): 0.370917022228
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 6.459353608079e-04
#
# Distances to other cuckoos:
#   Closest: token 143546 at 4.401307669468e-04
#   Farthest: token 140964 at 1.262705074623e-03
#   Mean: 8.395617478527e-04
#   Median: 8.004685514607e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002013 rad (0.1153°)
#   Mean: 0.000100 rad (0.0058°)
#
# ======================================================================
# CUCKOO #13 of 27
# ======================================================================
# Token ID: 136755
# Token string: 'จันท'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 4.254807427060e-04
#   Embedding norm (distance from origin): 0.370917856693
#
# Nearest black hole:
#   Token ID: 80091
#   Token string: '２０'
#   Distance: 6.573687423952e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 7.012405549176e-04
#   Farthest: token 125869 at 1.386452233419e-03
#   Mean: 9.750928147696e-04
#   Median: 8.886852883734e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002490 rad (0.1427°)
#   Mean: 0.000219 rad (0.0125°)
#
# ======================================================================
# CUCKOO #14 of 27
# ======================================================================
# Token ID: 136834
# Token string: 'เรื่องนี้'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.353654370178e-04
#   Embedding norm (distance from origin): 0.370916515589
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 8.886852883734e-04
#
# Distances to other cuckoos:
#   Closest: token 133377 at 6.342959241010e-04
#   Farthest: token 140964 at 1.359317451715e-03
#   Mean: 9.109132224694e-04
#   Median: 8.886852883734e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002013 rad (0.1153°)
#   Mean: 0.000123 rad (0.0071°)
#
# ======================================================================
# CUCKOO #15 of 27
# ======================================================================
# Token ID: 139765
# Token string: 'ช้า'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 5.738803301938e-04
#   Embedding norm (distance from origin): 0.370910197496
#
# Nearest black hole:
#   Token ID: 119349
#   Token string: '珊󠄁'
#   Distance: 1.084984629415e-03
#
# Distances to other cuckoos:
#   Closest: token 125125 at 9.611825807951e-04
#   Farthest: token 140964 at 1.386452233419e-03
#   Mean: 1.116052968428e-03
#   Median: 1.102013280615e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.003257 rad (0.1866°)
#   Mean: 0.000371 rad (0.0213°)
#
# ======================================================================
# CUCKOO #16 of 27
# ======================================================================
# Token ID: 139892
# Token string: 'เครดิต'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.011977947201e-04
#   Embedding norm (distance from origin): 0.370915889740
#
# Nearest black hole:
#   Token ID: 132383
#   Token string: 'เย็น'
#   Distance: 9.216106263921e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 6.573687423952e-04
#   Farthest: token 140964 at 1.232849666849e-03
#   Mean: 9.005194879137e-04
#   Median: 9.052976383828e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002290 rad (0.1312°)
#   Mean: 0.000202 rad (0.0116°)
#
# ======================================================================
# CUCKOO #17 of 27
# ======================================================================
# Token ID: 140964
# Token string: 'เอ็ม'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 9.954774286598e-04
#   Embedding norm (distance from origin): 0.370900869370
#
# Nearest black hole:
#   Token ID: 125
#   Token string: '�'
#   Distance: 1.164476620033e-03
#
# Distances to other cuckoos:
#   Closest: token 143546 at 1.158060622402e-03
#   Farthest: token 125869 at 1.722013694234e-03
#   Mean: 1.319795614108e-03
#   Median: 1.314688706771e-03
#
# Angular separations from other cuckoos:
#   Min: 0.001761 rad (0.1009°)
#   Max: 0.003347 rad (0.1918°)
#   Mean: 0.002293 rad (0.1314°)
#
# ======================================================================
# CUCKOO #18 of 27
# ======================================================================
# Token ID: 141989
# Token string: 'พรีเมียร์ลีก'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 2.427814615658e-04
#   Embedding norm (distance from origin): 0.370918780565
#
# Nearest black hole:
#   Token ID: 124
#   Token string: '�'
#   Distance: 9.455526014790e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 7.623288547620e-04
#   Farthest: token 140964 at 1.359317451715e-03
#   Mean: 9.536047000438e-04
#   Median: 9.336498333141e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002013 rad (0.1153°)
#   Mean: 0.000144 rad (0.0082°)
#
# ======================================================================
# CUCKOO #19 of 27
# ======================================================================
# Token ID: 143045
# Token string: ' อีก'
# Character type: Whitespace
#
# Spatial properties:
#   Distance from black hole centroid: 4.430872795638e-04
#   Embedding norm (distance from origin): 0.370914995670
#
# Nearest black hole:
#   Token ID: 132383
#   Token string: 'เย็น'
#   Distance: 8.097228710540e-04
#
# Distances to other cuckoos:
#   Closest: token 125047 at 6.796587258577e-04
#   Farthest: token 140964 at 1.418328844011e-03
#   Mean: 9.319775854237e-04
#   Median: 8.970299386419e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002013 rad (0.1153°)
#   Mean: 0.000225 rad (0.0129°)
#
# ======================================================================
# CUCKOO #20 of 27
# ======================================================================
# Token ID: 143546
# Token string: 'ขนส่ง'
# Character type: Thai
#
# Spatial properties:
#   Distance from black hole centroid: 1.385282230331e-04
#   Embedding norm (distance from origin): 0.370916992426
#
# Nearest black hole:
#   Token ID: 132383
#   Token string: 'เย็น'
#   Distance: 7.425247458741e-04
#
# Distances to other cuckoos:
#   Closest: token 136401 at 4.401307669468e-04
#   Farthest: token 125869 at 1.214584219269e-03
#   Mean: 8.747811662033e-04
#   Median: 8.588298223913e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.001983 rad (0.1136°)
#   Mean: 0.000124 rad (0.0071°)
#
# ======================================================================
# CUCKOO #21 of 27
# ======================================================================
# Token ID: 145341
# Token string: 'ί'
# Character type: Greek
#
# Spatial properties:
#   Distance from black hole centroid: 1.919038186315e-04
#   Embedding norm (distance from origin): 0.370916932821
#
# Nearest black hole:
#   Token ID: 126268
#   Token string: 'สี'
#   Distance: 7.012405549176e-04
#
# Distances to other cuckoos:
#   Closest: token 143546 at 6.459353608079e-04
#   Farthest: token 140964 at 1.303354278207e-03
#   Mean: 8.934351499192e-04
#   Median: 8.188725332730e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002043 rad (0.1170°)
#   Mean: 0.000105 rad (0.0060°)
#
# ======================================================================
# CUCKOO #22 of 27
# ======================================================================
# Token ID: 148826
# Token string: '視'
# Character type: CJK
#
# Spatial properties:
#   Distance from black hole centroid: 1.363770425087e-04
#   Embedding norm (distance from origin): 0.370916426182
#
# Nearest black hole:
#   Token ID: 125
#   Token string: '�'
#   Distance: 9.455526014790e-04
#
# Distances to other cuckoos:
#   Closest: token 125125 at 5.179004510865e-04
#   Farthest: token 125869 at 1.268591848202e-03
#   Mean: 8.940898696892e-04
#   Median: 8.802208467387e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002013 rad (0.1153°)
#   Mean: 0.000132 rad (0.0076°)
#
# ======================================================================
# CUCKOO #23 of 27
# ======================================================================
# Token ID: 148830
# Token string: '晴'
# Character type: CJK
#
# Spatial properties:
#   Distance from black hole centroid: 4.228814214002e-04
#   Embedding norm (distance from origin): 0.370912879705
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 8.457279182039e-04
#
# Distances to other cuckoos:
#   Closest: token 141989 at 7.816313882358e-04
#   Farthest: token 140964 at 1.386452233419e-03
#   Mean: 1.042897696607e-03
#   Median: 1.024948083796e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002290 rad (0.1312°)
#   Mean: 0.000246 rad (0.0141°)
#
# ======================================================================
# CUCKOO #24 of 27
# ======================================================================
# Token ID: 148932
# Token string: '魯'
# Character type: CJK
#
# Spatial properties:
#   Distance from black hole centroid: 3.859908902086e-04
#   Embedding norm (distance from origin): 0.370918035507
#
# Nearest black hole:
#   Token ID: 80091
#   Token string: '２０'
#   Distance: 8.717564051040e-04
#
# Distances to other cuckoos:
#   Closest: token 143045 at 7.816313882358e-04
#   Farthest: token 140964 at 1.444355468266e-03
#   Mean: 9.868745692074e-04
#   Median: 9.494761470705e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002290 rad (0.1312°)
#   Mean: 0.000262 rad (0.0150°)
#
# ======================================================================
# CUCKOO #25 of 27
# ======================================================================
# Token ID: 149121
# Token string: '漏'
# Character type: CJK
#
# Spatial properties:
#   Distance from black hole centroid: 1.412387791788e-04
#   Embedding norm (distance from origin): 0.370917946100
#
# Nearest black hole:
#   Token ID: 124
#   Token string: '�'
#   Distance: 9.376398520544e-04
#
# Distances to other cuckoos:
#   Closest: token 123952 at 5.980199784972e-04
#   Farthest: token 140964 at 1.238878350705e-03
#   Mean: 9.064835030586e-04
#   Median: 8.969914633781e-04
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002490 rad (0.1427°)
#   Mean: 0.000172 rad (0.0099°)
#
# ======================================================================
# CUCKOO #26 of 27
# ======================================================================
# Token ID: 151145
# Token string: '阮'
# Character type: CJK
#
# Spatial properties:
#   Distance from black hole centroid: 4.992238827981e-04
#   Embedding norm (distance from origin): 0.370916515589
#
# Nearest black hole:
#   Token ID: 119349
#   Token string: '珊󠄁'
#   Distance: 1.071162638254e-03
#
# Distances to other cuckoos:
#   Closest: token 125047 at 8.886852883734e-04
#   Farthest: token 125869 at 1.413066056557e-03
#   Mean: 1.109441858716e-03
#   Median: 1.074629137293e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.002950 rad (0.1690°)
#   Mean: 0.000396 rad (0.0227°)
#
# ======================================================================
# CUCKOO #27 of 27
# ======================================================================
# Token ID: 151929
# Token string: ''
# Character type: Empty
#
# Spatial properties:
#   Distance from black hole centroid: 4.531857557595e-04
#   Embedding norm (distance from origin): 0.370916098356
#
# Nearest black hole:
#   Token ID: 136831
#   Token string: 'สติ'
#   Distance: 1.035800902173e-03
#
# Distances to other cuckoos:
#   Closest: token 125047 at 9.052976383828e-04
#   Farthest: token 140964 at 1.375662512146e-03
#   Mean: 1.094989478588e-03
#   Median: 1.091808779165e-03
#
# Angular separations from other cuckoos:
#   Min: 0.000000 rad (0.0000°)
#   Max: 0.003069 rad (0.1758°)
#   Mean: 0.000342 rad (0.0196°)

# %% [markdown]
# ## Step 8: Character Type Summary

# %%
print("\n" + "="*70)
print("CHARACTER TYPE DISTRIBUTION")
print("="*70)
print()

# Classify all cuckoos
char_types = []
for token_id in cuckoo_token_ids:
    token_str = tokenizer.decode([token_id])
    char_type = classify_character(token_str)
    char_types.append(char_type)

# Count
from collections import Counter
type_counts = Counter(char_types)

print(f"{'Type':<20} {'Count':>8} {'Percentage':>12}")
print("-" * 45)
for char_type, count in sorted(type_counts.items(), key=lambda x: x[1], reverse=True):
    pct = 100 * count / len(cuckoo_token_ids)
    print(f"{char_type:<20} {count:>8} {pct:>11.1f}%")

print(f"\nTotal: {len(cuckoo_token_ids)} tokens")
# Out:
# ======================================================================
# CHARACTER TYPE DISTRIBUTION
# ======================================================================
#
# Type                    Count   Percentage
# ---------------------------------------------
# Thai                       18        66.7%
# CJK                         5        18.5%
# Symbol                      1         3.7%
# Whitespace                  1         3.7%
# Greek                       1         3.7%
# Empty                       1         3.7%
#
# Total: 27 tokens

# %% [markdown]
# ## Summary
#
# We've completed a comprehensive survey of the 27 tokens in the cuckoo zone.
#
# **Key questions answered:**
# 1. What are these tokens? (decoded strings and character types)
# 2. How are they spatially arranged? (distances from centroid, pairwise separations)
# 3. How close are they to the black holes? (nearest black hole for each)
# 4. Are they linguistically similar to black holes? (character distribution)
#
# The cuckoo zone is the chaotic region where tokens are close enough to feel the gravitational influence of the black hole cluster but far enough away that they didn't collapse into degeneracy during training.
