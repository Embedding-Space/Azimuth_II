# %% [markdown]
# # 1.9c: Decode Halo Tokens
#
# This notebook decodes the 1,423 "unreachable outside cluster" tokens to validate our reachability test.
#
# ## The Question
#
# In 1.8d, we found that 1,423 tokens are "unreachable" (fail round-trip test) but are NOT in the geometric cluster.
#
# **Are these truly unreachable, or is our test wrong?**
#
# ## The Concern
#
# The round-trip test (`decode(token_id) → encode(string) → compare`) might have false positives:
# - A token might be reachable via longer sequences but not when its decoded string is re-encoded in isolation
# - Greedy tokenization might prefer different tokens
# - Context dependency might matter
#
# ## Method
#
# 1. Load the 1,423 "unreachable_outside_cluster" token IDs from 1.8d
# 2. Decode each token
# 3. Classify by script, printability, content
# 4. Look for patterns that suggest genuine unreachability vs. test artifacts
#
# **If these are genuinely broken tokens (mojibake, malformed Unicode), the test is probably correct.**
# **If these are plausible linguistic content, the test might be wrong.**

# %% [markdown]
# ## Parameters

# %%
# Model to analyze
MODEL_NAME = "Qwen3-4B-Instruct-2507"
HF_MODEL_NAME = "Qwen/Qwen3-4B-Instruct-2507"

# Input from 1.8d
REACHABILITY_PATH = "../tensors/Qwen3-4B-Instruct-2507/1.8d_full_vocab_reachability.safetensors"

# %% [markdown]
# ## Imports

# %%
import torch
import pandas as pd
import unicodedata
from safetensors.torch import load_file
from pathlib import Path
from transformers import AutoTokenizer
from collections import Counter

# %% [markdown]
# ## Load Halo Token IDs

# %%
# Load reachability data from 1.8d
data = load_file(REACHABILITY_PATH)
halo_token_ids = data['unreachable_outside_cluster']

print(f"Loaded {len(halo_token_ids):,} halo token IDs from {Path(REACHABILITY_PATH).name}")
print(f"  Token ID range: [{halo_token_ids.min().item()}, {halo_token_ids.max().item()}]")
# Out:
# Loaded 1,423 halo token IDs from 1.8d_full_vocab_reachability.safetensors
#   Token ID range: [94, 151560]

# %%
# Sort by token ID (BPE natural order)
halo_token_ids_sorted = torch.sort(halo_token_ids)[0]

print(f"\nSorted token IDs:")
print(f"  First 10: {halo_token_ids_sorted[:10].tolist()}")
print(f"  Last 10: {halo_token_ids_sorted[-10:].tolist()}")
# Out:
# Sorted token IDs:
#   First 10: [94, 95, 96, 97, 98, 99, 100, 101, 102, 103]
#   Last 10: [151266, 151268, 151270, 151272, 151274, 151276, 151278, 151282, 151366, 151560]

# %% [markdown]
# ## Load Tokenizer

# %%
print(f"\nLoading tokenizer from {HF_MODEL_NAME}...\n")
tokenizer = AutoTokenizer.from_pretrained(HF_MODEL_NAME)
print(f"✓ Tokenizer loaded")
print(f"  Vocabulary size: {len(tokenizer):,} tokens")
# Out:
# Loading tokenizer from Qwen/Qwen3-4B-Instruct-2507...
#
# ✓ Tokenizer loaded
#   Vocabulary size: 151,669 tokens

# %% [markdown]
# ## Helper Functions

# %%
def classify_script(text):
    """
    Classify text by dominant script using Unicode properties.
    Returns primary script name (e.g., 'Thai', 'Han', 'Latin').
    """
    if not text or not text.strip():
        return 'Empty/Whitespace'
    
    # Count characters by script
    script_counts = Counter()
    
    for char in text:
        # Skip whitespace and control characters for classification
        if char.isspace() or unicodedata.category(char).startswith('C'):
            continue
            
        # Get Unicode script name
        try:
            script = unicodedata.name(char).split()[0]
            script_counts[script] += 1
        except (ValueError, IndexError):
            # Handle characters without names or unnamed characters
            category = unicodedata.category(char)
            if category.startswith('P'):
                script_counts['Punctuation'] += 1
            elif category.startswith('S'):
                script_counts['Symbol'] += 1
            else:
                script_counts['Other'] += 1
    
    if not script_counts:
        return 'Empty/Whitespace'
    
    # Return most common script
    return script_counts.most_common(1)[0][0]


def is_printable(text):
    """
    Check if text contains only printable characters.
    """
    if not text:
        return False
    
    for char in text:
        cat = unicodedata.category(char)
        # Allow letters, numbers, punctuation, symbols, and whitespace
        # Exclude control characters (Cc, Cf, Co, Cn)
        if cat.startswith('C') and not char.isspace():
            return False
    
    return True


def is_replacement_character(text):
    """
    Check if text consists only of Unicode replacement characters (U+FFFD).
    This indicates malformed/invalid UTF-8.
    """
    return all(c == '\ufffd' for c in text) and len(text) > 0


print("Helper functions defined:")
print("  classify_script(text) - Identify dominant Unicode script")
print("  is_printable(text) - Check if all characters are printable")
print("  is_replacement_character(text) - Check if text is U+FFFD (broken encoding)")
# Out:
# Helper functions defined:
#   classify_script(text) - Identify dominant Unicode script
#   is_printable(text) - Check if all characters are printable
#   is_replacement_character(text) - Check if text is U+FFFD (broken encoding)

# %% [markdown]
# ## Decode All Halo Tokens

# %%
print(f"\nDecoding {len(halo_token_ids_sorted):,} halo tokens...\n")

# Build list of records
records = []

for token_id in halo_token_ids_sorted:
    tid = token_id.item()
    
    # Decode
    decoded = tokenizer.decode([tid])
    
    # Compute metadata
    byte_len = len(decoded.encode('utf-8'))
    printable = is_printable(decoded)
    script = classify_script(decoded)
    is_mojibake = is_replacement_character(decoded)
    
    records.append({
        'token_id': tid,
        'decoded': decoded,
        'byte_length': byte_len,
        'printable': printable,
        'script': script,
        'is_mojibake': is_mojibake,
    })

# Create dataframe
df = pd.DataFrame(records)

print(f"✓ Decoded {len(df):,} tokens")
print(f"\nDataframe shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
# Out:
# Decoding 1,423 halo tokens...
#
# ✓ Decoded 1,423 tokens
#
# Dataframe shape: (1423, 6)
# Columns: ['token_id', 'decoded', 'byte_length', 'printable', 'script', 'is_mojibake']

# %% [markdown]
# ## Summary Statistics

# %%
print("\n" + "="*60)
print("HALO TOKEN SUMMARY")
print("="*60)

print(f"\nTotal tokens: {len(df):,}")
print(f"\nByte length statistics:")
print(f"  Min: {df['byte_length'].min()}")
print(f"  Max: {df['byte_length'].max()}")
print(f"  Mean: {df['byte_length'].mean():.2f}")
print(f"  Median: {df['byte_length'].median():.0f}")

print(f"\nPrintability:")
print(f"  Printable: {df['printable'].sum():,} ({100*df['printable'].sum()/len(df):.1f}%)")
print(f"  Non-printable: {(~df['printable']).sum():,} ({100*(~df['printable']).sum()/len(df):.1f}%)")

print(f"\nMojibake (U+FFFD replacement characters):")
print(f"  Mojibake: {df['is_mojibake'].sum():,} ({100*df['is_mojibake'].sum()/len(df):.1f}%)")
print(f"  Valid: {(~df['is_mojibake']).sum():,} ({100*(~df['is_mojibake']).sum()/len(df):.1f}%)")

print(f"\nScript distribution:")
script_counts = df['script'].value_counts()
for script, count in script_counts.items():
    pct = 100 * count / len(df)
    print(f"  {script:20s}: {count:4,} ({pct:5.1f}%)")

print("\n" + "="*60)
# Out:
# ============================================================
# HALO TOKEN SUMMARY
# ============================================================
#
# Total tokens: 1,423
#
# Byte length statistics:
#   Min: 3
#   Max: 15
#   Mean: 3.59
#   Median: 3
#
# Printability:
#   Printable: 1,422 (99.9%)
#   Non-printable: 1 (0.1%)
#
# Mojibake (U+FFFD replacement characters):
#   Mojibake: 1,119 (78.6%)
#   Valid: 304 (21.4%)
#
# Script distribution:
#   REPLACEMENT         : 1,351 ( 94.9%)
#   CJK                 :   18 (  1.3%)
#   KATAKANA            :   11 (  0.8%)
#   CYRILLIC            :    7 (  0.5%)
#   HIRAGANA            :    7 (  0.5%)
#   HANGUL              :    7 (  0.5%)
#   DEVANAGARI          :    4 (  0.3%)
#   HEBREW              :    4 (  0.3%)
#   BENGALI             :    3 (  0.2%)
#   KATAKANA-HIRAGANA   :    2 (  0.1%)
#   LATIN               :    2 (  0.1%)
#   TAMIL               :    2 (  0.1%)
#   KHMER               :    2 (  0.1%)
#   ARABIC              :    1 (  0.1%)
#   MALAYALAM           :    1 (  0.1%)
#   LEFT                :    1 (  0.1%)
#
# ============================================================

# %% [markdown]
# ## Full Token Table

# %%
# Display settings for full table
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 50)

print(f"\nFull table of {len(df):,} halo tokens:\n")
display(df)
# Out:
# Full table of 1,423 halo tokens:
#       token_id decoded  byte_length  printable             script  is_mojibake
# 0           94       �            3       True        REPLACEMENT         True
# 1           95       �            3       True        REPLACEMENT         True
# 2           96       �            3       True        REPLACEMENT         True
# 3           97       �            3       True        REPLACEMENT         True
# 4           98       �            3       True        REPLACEMENT         True
# 5           99       �            3       True        REPLACEMENT         True
# 6          100       �            3       True        REPLACEMENT         True
# 7          101       �            3       True        REPLACEMENT         True
# 8          102       �            3       True        REPLACEMENT         True
# 9          103       �            3       True        REPLACEMENT         True
# 10         104       �            3       True        REPLACEMENT         True
# 11         105       �            3       True        REPLACEMENT         True
# 12         106       �            3       True        REPLACEMENT         True
# 13         107       �            3       True        REPLACEMENT         True
# 14         108       �            3       True        REPLACEMENT         True
# 15         109       �            3       True        REPLACEMENT         True
# 16         110       �            3       True        REPLACEMENT         True
# 17         111       �            3       True        REPLACEMENT         True
# 18         112       �            3       True        REPLACEMENT         True
# 19         113       �            3       True        REPLACEMENT         True
# 20         114       �            3       True        REPLACEMENT         True
# 21         115       �            3       True        REPLACEMENT         True
# 22         116       �            3       True        REPLACEMENT         True
# 23         117       �            3       True        REPLACEMENT         True
# 24         118       �            3       True        REPLACEMENT         True
# 25         119       �            3       True        REPLACEMENT         True
# 26         120       �            3       True        REPLACEMENT         True
# 27         121       �            3       True        REPLACEMENT         True
# 28         122       �            3       True        REPLACEMENT         True
# 29         123       �            3       True        REPLACEMENT         True
# 30         126       �            3       True        REPLACEMENT         True
# 31         127       �            3       True        REPLACEMENT         True
# 32         128       �            3       True        REPLACEMENT         True
# 33         129       �            3       True        REPLACEMENT         True
# 34         130       �            3       True        REPLACEMENT         True
# 35         131       �            3       True        REPLACEMENT         True
# 36         132       �            3       True        REPLACEMENT         True
# 37         133       �            3       True        REPLACEMENT         True
# 38         134       �            3       True        REPLACEMENT         True
# 39         135       �            3       True        REPLACEMENT         True
# 40         136       �            3       True        REPLACEMENT         True
# 41         137       �            3       True        REPLACEMENT         True
# 42         138       �            3       True        REPLACEMENT         True
# 43         139       �            3       True        REPLACEMENT         True
# 44         140       �            3       True        REPLACEMENT         True
# 45         141       �            3       True        REPLACEMENT         True
# 46         142       �            3       True        REPLACEMENT         True
# 47         143       �            3       True        REPLACEMENT         True
# 48         144       �            3       True        REPLACEMENT         True
# 49         145       �            3       True        REPLACEMENT         True
# 50         146       �            3       True        REPLACEMENT         True
# 51         147       �            3       True        REPLACEMENT         True
# 52         148       �            3       True        REPLACEMENT         True
# 53         149       �            3       True        REPLACEMENT         True
# 54         150       �            3       True        REPLACEMENT         True
# 55         151       �            3       True        REPLACEMENT         True
# 56         152       �            3       True        REPLACEMENT         True
# 57         153       �            3       True        REPLACEMENT         True
# 58         154       �            3       True        REPLACEMENT         True
# 59         155       �            3       True        REPLACEMENT         True
# 60         156       �            3       True        REPLACEMENT         True
# 61         157       �            3       True        REPLACEMENT         True
# 62         158       �            3       True        REPLACEMENT         True
# 63         159       �            3       True        REPLACEMENT         True
# 64         160       �            3       True        REPLACEMENT         True
# 65         161       �            3       True        REPLACEMENT         True
# 66         162       �            3       True        REPLACEMENT         True
# 67         163       �            3       True        REPLACEMENT         True
# 68         164       �            3       True        REPLACEMENT         True
# 69         165       �            3       True        REPLACEMENT         True
# 70         166       �            3       True        REPLACEMENT         True
# 71         167       �            3       True        REPLACEMENT         True
# 72         168       �            3       True        REPLACEMENT         True
# 73         169       �            3       True        REPLACEMENT         True
# 74         170       �            3       True        REPLACEMENT         True
# 75         171       �            3       True        REPLACEMENT         True
# 76         172       �            3       True        REPLACEMENT         True
# 77         173       �            3       True        REPLACEMENT         True
# 78         174       �            3       True        REPLACEMENT         True
# 79         175       �            3       True        REPLACEMENT         True
# 80         176       �            3       True        REPLACEMENT         True
# 81         222       �            3       True        REPLACEMENT         True
# 82         223       �            3       True        REPLACEMENT         True
# 83         224       �            3       True        REPLACEMENT         True
# 84         225       �            3       True        REPLACEMENT         True
# 85         226       �            3       True        REPLACEMENT         True
# 86         227       �            3       True        REPLACEMENT         True
# 87         228       �            3       True        REPLACEMENT         True
# 88         229       �            3       True        REPLACEMENT         True
# 89         230       �            3       True        REPLACEMENT         True
# 90         231       �            3       True        REPLACEMENT         True
# 91         232       �            3       True        REPLACEMENT         True
# 92         233       �            3       True        REPLACEMENT         True
# 93         234       �            3       True        REPLACEMENT         True
# 94         235       �            3       True        REPLACEMENT         True
# 95         236       �            3       True        REPLACEMENT         True
# 96         237       �            3       True        REPLACEMENT         True
# 97         238       �            3       True        REPLACEMENT         True
# 98         239       �            3       True        REPLACEMENT         True
# 99         240       �            3       True        REPLACEMENT         True
# 100        241       �            3       True        REPLACEMENT         True
# 101        242       �            3       True        REPLACEMENT         True
# 102        243       �            3       True        REPLACEMENT         True
# 103        244       �            3       True        REPLACEMENT         True
# 104        245       �            3       True        REPLACEMENT         True
# 105        246       �            3       True        REPLACEMENT         True
# 106        247       �            3       True        REPLACEMENT         True
# 107        248       �            3       True        REPLACEMENT         True
# 108        249       �            3       True        REPLACEMENT         True
# 109        250       �            3       True        REPLACEMENT         True
# 110        251       �            3       True        REPLACEMENT         True
# 111        252       �            3       True        REPLACEMENT         True
# 112        253       �            3       True        REPLACEMENT         True
# 113        254       �            3       True        REPLACEMENT         True
# 114        255       �            3       True        REPLACEMENT         True
# 115        378       �            3       True        REPLACEMENT         True
# 116        636       �            4       True        REPLACEMENT        False
# 117       1277       �            3       True        REPLACEMENT         True
# 118       1278       �            4       True        REPLACEMENT        False
# 119       1540       �            3       True        REPLACEMENT         True
# 120       1683       �            4       True        REPLACEMENT        False
# 121       2139       �            4       True        REPLACEMENT        False
# 122       2194       �            3       True        REPLACEMENT         True
# 123       2226      о�            5       True           CYRILLIC        False
# 124       2775       �            3       True        REPLACEMENT         True
# 125       2858       �            4       True        REPLACEMENT        False
# 126       3023       �            3       True        REPLACEMENT         True
# 127       3219      ��            6       True        REPLACEMENT         True
# 128       3315       �            4       True        REPLACEMENT        False
# 129       3402       �            3       True        REPLACEMENT         True
# 130       3490       �            3       True        REPLACEMENT         True
# 131       3648      а�            5       True           CYRILLIC        False
# 132       4175      е�            5       True           CYRILLIC        False
# 133       4811       �            3       True        REPLACEMENT         True
# 134       4891       �            4       True        REPLACEMENT        False
# 135       4973       �            3       True        REPLACEMENT         True
# 136       5140       �            4       True        REPLACEMENT        False
# 137       5502       �            3       True        REPLACEMENT         True
# 138       5564       �            3       True        REPLACEMENT         True
# 139       5758       �            3       True        REPLACEMENT         True
# 140       5902       �            3       True        REPLACEMENT         True
# 141       5953       �            3       True        REPLACEMENT         True
# 142       6142       �            3       True        REPLACEMENT         True
# 143       6518       �            3       True        REPLACEMENT         True
# 144       6564       �            3       True        REPLACEMENT         True
# 145       6567       �            4       True        REPLACEMENT        False
# 146       6571       �            3       True        REPLACEMENT         True
# 147       6606       �            3       True        REPLACEMENT         True
# 148       6684       �            3       True        REPLACEMENT         True
# 149       7045       �            3       True        REPLACEMENT         True
# 150       7158       �            3       True        REPLACEMENT         True
# 151       7311       �            3       True        REPLACEMENT         True
# 152       7367       �            3       True        REPLACEMENT         True
# 153       7492      ��            6       True        REPLACEMENT         True
# 154       7536       �            3       True        REPLACEMENT         True
# 155       7588       �            3       True        REPLACEMENT         True
# 156       7851       �            4       True        REPLACEMENT        False
# 157       7908       �            3       True        REPLACEMENT         True
# 158       8032       �            3       True        REPLACEMENT         True
# 159       8079       �            3       True        REPLACEMENT         True
# 160       8158       �            3       True        REPLACEMENT         True
# 161       8508       �            3       True        REPLACEMENT         True
# 162       8519       �            3       True        REPLACEMENT         True
# 163       8620       �            4       True        REPLACEMENT        False
# 164       8803       �            4       True        REPLACEMENT        False
# 165       8839       �            4       True        REPLACEMENT        False
# 166       8843       �            3       True        REPLACEMENT         True
# 167       8908       �            4       True        REPLACEMENT        False
# 168       9035       �            4       True        REPLACEMENT        False
# 169       9260       �            3       True        REPLACEMENT         True
# 170       9284       �            3       True        REPLACEMENT         True
# 171       9722       �            3       True        REPLACEMENT         True
# 172       9843       �            4       True        REPLACEMENT        False
# 173      10081       �            3       True        REPLACEMENT         True
# 174      10203       �            3       True        REPLACEMENT         True
# 175      10236       �            4       True        REPLACEMENT        False
# 176      10417       �            3       True        REPLACEMENT         True
# 177      10663       �            3       True        REPLACEMENT         True
# 178      10764       �            4       True        REPLACEMENT        False
# 179      10768     ра�            7       True           CYRILLIC        False
# 180      10996       �            3       True        REPLACEMENT         True
# 181      11125       �            3       True        REPLACEMENT         True
# 182      11162       �            4       True        REPLACEMENT        False
# 183      11336       �            3       True        REPLACEMENT         True
# 184      11484       �            3       True        REPLACEMENT         True
# 185      11534       �            3       True        REPLACEMENT         True
# 186      11620       �            3       True        REPLACEMENT         True
# 187      11621       �            3       True        REPLACEMENT         True
# 188      11995       �            4       True        REPLACEMENT        False
# 189      12274       �            3       True        REPLACEMENT         True
# 190      12491       �            3       True        REPLACEMENT         True
# 191      12585       �            3       True        REPLACEMENT         True
# 192      12619       �            3       True        REPLACEMENT         True
# 193      12787       �            3       True        REPLACEMENT         True
# 194      13058       �            3       True        REPLACEMENT         True
# 195      13092       �            3       True        REPLACEMENT         True
# 196      13165       �            3       True        REPLACEMENT         True
# 197      13344       �            3       True        REPLACEMENT         True
# 198      13465       �            3       True        REPLACEMENT         True
# 199      13512       �            3       True        REPLACEMENT         True
# 200      13519       �            3       True        REPLACEMENT         True
# 201      13531       �            3       True        REPLACEMENT         True
# 202      13558       �            3       True        REPLACEMENT         True
# 203      13567       �            3       True        REPLACEMENT         True
# 204      13846       �            3       True        REPLACEMENT         True
# 205      13869       �            3       True        REPLACEMENT         True
# 206      13949       �            3       True        REPLACEMENT         True
# 207      13982       �            3       True        REPLACEMENT         True
# 208      14273       �            3       True        REPLACEMENT         True
# 209      14368       �            3       True        REPLACEMENT         True
# 210      14467       �            3       True        REPLACEMENT         True
# 211      14520       �            4       True        REPLACEMENT        False
# 212      14546       �            3       True        REPLACEMENT         True
# 213      14559       �            3       True        REPLACEMENT         True
# 214      14675       �            3       True        REPLACEMENT         True
# 215      14922       �            3       True        REPLACEMENT         True
# 216      14925       �            4       True        REPLACEMENT        False
# 217      14936       �            3       True        REPLACEMENT         True
# 218      14942       �            3       True        REPLACEMENT         True
# 219      14959       �            3       True        REPLACEMENT         True
# 220      15005       �            3       True        REPLACEMENT         True
# 221      15127       �            3       True        REPLACEMENT         True
# 222      15213       �            3       True        REPLACEMENT         True
# 223      15224       �            3       True        REPLACEMENT         True
# 224      15362       �            3       True        REPLACEMENT         True
# 225      15393       �            3       True        REPLACEMENT         True
# 226      15600       �            3       True        REPLACEMENT         True
# 227      15675      ��            6       True        REPLACEMENT         True
# 228      15798       �            3       True        REPLACEMENT         True
# 229      15827       �            3       True        REPLACEMENT         True
# 230      15896       �            3       True        REPLACEMENT         True
# 231      15902      ��            6       True        REPLACEMENT         True
# 232      15927       �            3       True        REPLACEMENT         True
# 233      16160       �            3       True        REPLACEMENT         True
# 234      16235       �            4       True        REPLACEMENT        False
# 235      16499       �            3       True        REPLACEMENT         True
# 236      16633       �            3       True        REPLACEMENT         True
# 237      16747       �            3       True        REPLACEMENT         True
# 238      16751       �            4       True        REPLACEMENT        False
# 239      16778       �            4       True        REPLACEMENT        False
# 240      16825       �            3       True        REPLACEMENT         True
# 241      17049       �            3       True        REPLACEMENT         True
# 242      17156       �            3       True        REPLACEMENT         True
# 243      17158       �            3       True        REPLACEMENT         True
# 244      17284       �            4       True        REPLACEMENT        False
# 245      17383       �            4       True        REPLACEMENT        False
# 246      17401       �            3       True        REPLACEMENT         True
# 247      17429       �            3       True        REPLACEMENT         True
# 248      17462       �            3       True        REPLACEMENT         True
# 249      17467       �            3       True        REPLACEMENT         True
# 250      17587       �            4       True        REPLACEMENT        False
# 251      17641       �            3       True        REPLACEMENT         True
# 252      17730       �            3       True        REPLACEMENT         True
# 253      17783       �            3       True        REPLACEMENT         True
# 254      18059       �            3       True        REPLACEMENT         True
# 255      18137       �            4       True        REPLACEMENT        False
# 256      18505       �            3       True        REPLACEMENT         True
# 257      18535      ��            6       True        REPLACEMENT         True
# 258      18585       �            4       True        REPLACEMENT        False
# 259      19088       �            3       True        REPLACEMENT         True
# 260      19113       �            3       True        REPLACEMENT         True
# 261      19261       �            3       True        REPLACEMENT         True
# 262      19457       �            3       True        REPLACEMENT         True
# 263      19468       �            4       True        REPLACEMENT        False
# 264      19549       �            3       True        REPLACEMENT         True
# 265      19564       �            3       True        REPLACEMENT         True
# 266      19741       �            3       True        REPLACEMENT         True
# 267      19946      �다            6       True        REPLACEMENT        False
# 268      19956       �            3       True        REPLACEMENT         True
# 269      20026       �            3       True        REPLACEMENT         True
# 270      20047       �            3       True        REPLACEMENT         True
# 271      20098       �            3       True        REPLACEMENT         True
# 272      20136       �            4       True        REPLACEMENT        False
# 273      20382       �            3       True        REPLACEMENT         True
# 274      20472      し�            6       True           HIRAGANA        False
# 275      20711       �            4       True        REPLACEMENT        False
# 276      20741       �            3       True        REPLACEMENT         True
# 277      20778       �            3       True        REPLACEMENT         True
# 278      20879       �            3       True        REPLACEMENT         True
# 279      20885       �            3       True        REPLACEMENT         True
# 280      20919       �            3       True        REPLACEMENT         True
# 281      21012       �            3       True        REPLACEMENT         True
# 282      21103       �            4       True        REPLACEMENT        False
# 283      21135       �            3       True        REPLACEMENT         True
# 284      21280       �            3       True        REPLACEMENT         True
# 285      21530       �            3       True        REPLACEMENT         True
# 286      21562       �            3       True        REPLACEMENT         True
# 287      21704       �            3       True        REPLACEMENT         True
# 288      21849       �            3       True        REPLACEMENT         True
# 289      22009       �            3       True        REPLACEMENT         True
# 290      22042       �            4       True        REPLACEMENT        False
# 291      22129      ��            6       True        REPLACEMENT         True
# 292      22247       �            3       True        REPLACEMENT         True
# 293      22597      ��            6       True        REPLACEMENT         True
# 294      22612       �            4       True        REPLACEMENT        False
# 295      22762       �            3       True        REPLACEMENT         True
# 296      22859       �            3       True        REPLACEMENT         True
# 297      23093       �            3       True        REPLACEMENT         True
# 298      23272      ��            6       True        REPLACEMENT         True
# 299      23433       �            3       True        REPLACEMENT         True
# 300      23444      ��            6       True        REPLACEMENT         True
# 301      23687       �            3       True        REPLACEMENT         True
# 302      23781      ��            6       True        REPLACEMENT         True
# 303      23872       �            4       True        REPLACEMENT        False
# 304      23894       �            4       True        REPLACEMENT        False
# 305      24041      ー�            6       True  KATAKANA-HIRAGANA        False
# 306      24045      �除            6       True        REPLACEMENT        False
# 307      24071       �            3       True        REPLACEMENT         True
# 308      24159       �            3       True        REPLACEMENT         True
# 309      24212     ра�            8       True           CYRILLIC        False
# 310      24345       �            3       True        REPLACEMENT         True
# 311      24447      ��            6       True        REPLACEMENT         True
# 312      24485       �            4       True        REPLACEMENT        False
# 313      24735       �            3       True        REPLACEMENT         True
# 314      24749       �            3       True        REPLACEMENT         True
# 315      24831       �            3       True        REPLACEMENT         True
# 316      24864       �            3       True        REPLACEMENT         True
# 317      25011      �回            6       True        REPLACEMENT        False
# 318      25125       �            4       True        REPLACEMENT        False
# 319      25145       �            3       True        REPLACEMENT         True
# 320      25209       �            3       True        REPLACEMENT         True
# 321      25452      ��            6       True        REPLACEMENT         True
# 322      25521       �            4       True        REPLACEMENT        False
# 323      25703       �            3       True        REPLACEMENT         True
# 324      25772      ư�            5       True              LATIN        False
# 325      25870       �            3       True        REPLACEMENT         True
# 326      25917       �            4       True        REPLACEMENT        False
# 327      25928       �            3       True        REPLACEMENT         True
# 328      26188       �            3       True        REPLACEMENT         True
# 329      26254      ��            6       True        REPLACEMENT         True
# 330      26336       �            3       True        REPLACEMENT         True
# 331      26454       �            3       True        REPLACEMENT         True
# 332      26525       �            4       True        REPLACEMENT        False
# 333      26601       �            3       True        REPLACEMENT         True
# 334      26771       �            3       True        REPLACEMENT         True
# 335      26853       �            4       True        REPLACEMENT        False
# 336      26927       �            3       True        REPLACEMENT         True
# 337      27095       �            3       True        REPLACEMENT         True
# 338      27209       �            3       True        REPLACEMENT         True
# 339      27214       �            3       True        REPLACEMENT         True
# 340      27260      �数            6       True        REPLACEMENT        False
# 341      27325       �            3       True        REPLACEMENT         True
# 342      27398       �            3       True        REPLACEMENT         True
# 343      27487     ��取            9       True        REPLACEMENT        False
# 344      27517       �            3       True        REPLACEMENT         True
# 345      27538       �            3       True        REPLACEMENT         True
# 346      27640       �            3       True        REPLACEMENT         True
# 347      27757      ��            6       True        REPLACEMENT         True
# 348      27767       �            4       True        REPLACEMENT        False
# 349      27982       �            4       True        REPLACEMENT        False
# 350      27999       �            3       True        REPLACEMENT         True
# 351      28107       �            3       True        REPLACEMENT         True
# 352      28145       �            3       True        REPLACEMENT         True
# 353      28653       �            4       True        REPLACEMENT        False
# 354      28757       �            3       True        REPLACEMENT         True
# 355      28927       �            4       True        REPLACEMENT        False
# 356      29150       �            3       True        REPLACEMENT         True
# 357      29220       �            3       True        REPLACEMENT         True
# 358      29237       �            3       True        REPLACEMENT         True
# 359      29389      ��            6       True        REPLACEMENT         True
# 360      29675       �            3       True        REPLACEMENT         True
# 361      29768       �            3       True        REPLACEMENT         True
# 362      29941      �数            6       True        REPLACEMENT        False
# 363      29955       �            3       True        REPLACEMENT         True
# 364      29975       �            3       True        REPLACEMENT         True
# 365      30006       �            3       True        REPLACEMENT         True
# 366      30274       �            3       True        REPLACEMENT         True
# 367      30395       �            3       True        REPLACEMENT         True
# 368      30484      ्�            6       True         DEVANAGARI        False
# 369      30520       �            4       True        REPLACEMENT        False
# 370      30828      ��            6       True        REPLACEMENT         True
# 371      30838       �            3       True        REPLACEMENT         True
# 372      30916       �            3       True        REPLACEMENT         True
# 373      31286       �            4       True        REPLACEMENT        False
# 374      31305       �            3       True        REPLACEMENT         True
# 375      31338      �建            6       True        REPLACEMENT        False
# 376      31411      ा�            6       True         DEVANAGARI        False
# 377      31482       �            3       True        REPLACEMENT         True
# 378      31501       �            3       True        REPLACEMENT         True
# 379      32181       �            4       True        REPLACEMENT        False
# 380      32208       �            3       True        REPLACEMENT         True
# 381      32254       �            3       True        REPLACEMENT         True
# 382      32343       �            3       True        REPLACEMENT         True
# 383      32465       �            3       True        REPLACEMENT         True
# 384      32495       �            4       True        REPLACEMENT        False
# 385      32843       �            3       True        REPLACEMENT         True
# 386      32926      ��            6       True        REPLACEMENT         True
# 387      32985       �            4       True        REPLACEMENT        False
# 388      33173       �            3       True        REPLACEMENT         True
# 389      33352       �            3       True        REPLACEMENT         True
# 390      33424       �            4       True        REPLACEMENT        False
# 391      33543      ��            6       True        REPLACEMENT         True
# 392      33556       �            3       True        REPLACEMENT         True
# 393      33593       �            3       True        REPLACEMENT         True
# 394      33739       �            3       True        REPLACEMENT         True
# 395      33986       �            3       True        REPLACEMENT         True
# 396      34143       �            4       True        REPLACEMENT        False
# 397      34369       �            4       True        REPLACEMENT        False
# 398      34410       �            4       True        REPLACEMENT        False
# 399      34429      ��            6       True        REPLACEMENT         True
# 400      34577       �            3       True        REPLACEMENT         True
# 401      34622       �            3       True        REPLACEMENT         True
# 402      34629       �            3       True        REPLACEMENT         True
# 403      34759       �            3       True        REPLACEMENT         True
# 404      34811      ��            6       True        REPLACEMENT         True
# 405      34992       �            3       True        REPLACEMENT         True
# 406      35017       �            3       True        REPLACEMENT         True
# 407      35049       �            3       True        REPLACEMENT         True
# 408      35055       �            3       True        REPLACEMENT         True
# 409      35125     ��加            9       True        REPLACEMENT        False
# 410      35146      ��            6       True        REPLACEMENT         True
# 411      35178       �            4       True        REPLACEMENT        False
# 412      35293       �            3       True        REPLACEMENT         True
# 413      35358       �            4       True        REPLACEMENT        False
# 414      35496       �            3       True        REPLACEMENT         True
# 415      35635       �            3       True        REPLACEMENT         True
# 416      35720     �от            7       True           CYRILLIC        False
# 417      36097      ��            6       True        REPLACEMENT         True
# 418      36109      ��            6       True        REPLACEMENT         True
# 419      36330       �            4       True        REPLACEMENT        False
# 420      36548     ��作            9       True        REPLACEMENT        False
# 421      36669      ו�            5       True             HEBREW        False
# 422      36677      ��            6       True        REPLACEMENT         True
# 423      36695       �            3       True        REPLACEMENT         True
# 424      36978       �            4       True        REPLACEMENT        False
# 425      37064       �            4       True        REPLACEMENT        False
# 426      37148      ー�            6       True  KATAKANA-HIRAGANA        False
# 427      37195       �            4       True        REPLACEMENT        False
# 428      37289       �            3       True        REPLACEMENT         True
# 429      37440      ��            6       True        REPLACEMENT         True
# 430      37472       �            3       True        REPLACEMENT         True
# 431      37509      �认            6       True        REPLACEMENT        False
# 432      37698       �            3       True        REPLACEMENT         True
# 433      37913       �            3       True        REPLACEMENT         True
# 434      38177       �            3       True        REPLACEMENT         True
# 435      38419       �            3       True        REPLACEMENT         True
# 436      38433       �            4       True        REPLACEMENT        False
# 437      38522       �            3       True        REPLACEMENT         True
# 438      38523       �            4       True        REPLACEMENT        False
# 439      38903       �            4       True        REPLACEMENT        False
# 440      38911       �            3       True        REPLACEMENT         True
# 441      39098       �            3       True        REPLACEMENT         True
# 442      39175       �            3       True        REPLACEMENT         True
# 443      39317       �            3       True        REPLACEMENT         True
# 444      39366     ��态            9       True        REPLACEMENT        False
# 445      39834      ��            6       True        REPLACEMENT         True
# 446      40419      ��            6       True        REPLACEMENT         True
# 447      40666       �            4       True        REPLACEMENT        False
# 448      40714       �            3       True        REPLACEMENT         True
# 449      40732       �            3       True        REPLACEMENT         True
# 450      40747       �            3       True        REPLACEMENT         True
# 451      40771       �            4       True        REPLACEMENT        False
# 452      41479       �            4       True        REPLACEMENT        False
# 453      41902      ��            6       True        REPLACEMENT         True
# 454      42144       �            3       True        REPLACEMENT         True
# 455      42236      י�            5       True             HEBREW        False
# 456      42311      ि�            6       True         DEVANAGARI        False
# 457      42476      �            5      False        REPLACEMENT        False
# 458      42849       �            4       True        REPLACEMENT        False
# 459      43410       �            3       True        REPLACEMENT         True
# 460      43459       �            3       True        REPLACEMENT         True
# 461      43547       �            3       True        REPLACEMENT         True
# 462      43559       �            3       True        REPLACEMENT         True
# 463      43614       �            4       True        REPLACEMENT        False
# 464      43716      �始            6       True        REPLACEMENT        False
# 465      43720      �单            6       True        REPLACEMENT        False
# 466      43752       �            3       True        REPLACEMENT         True
# 467      44014       �            3       True        REPLACEMENT         True
# 468      44044       �            3       True        REPLACEMENT         True
# 469      44054       �            4       True        REPLACEMENT        False
# 470      44104      ��            6       True        REPLACEMENT         True
# 471      44258       �            3       True        REPLACEMENT         True
# 472      44401      ��            6       True        REPLACEMENT         True
# 473      44680      ��            6       True        REPLACEMENT         True
# 474      44706      ��            6       True        REPLACEMENT         True
# 475      44726       �            3       True        REPLACEMENT         True
# 476      44818       �            3       True        REPLACEMENT         True
# 477      44832       �            3       True        REPLACEMENT         True
# 478      44834      �述            6       True        REPLACEMENT        False
# 479      44851       �            3       True        REPLACEMENT         True
# 480      44965       �            3       True        REPLACEMENT         True
# 481      45104       �            4       True        REPLACEMENT        False
# 482      45130       �            4       True        REPLACEMENT        False
# 483      45313       �            4       True        REPLACEMENT        False
# 484      45881      ��            6       True        REPLACEMENT         True
# 485      46018       �            4       True        REPLACEMENT        False
# 486      46218     ��이            9       True        REPLACEMENT        False
# 487      46282      ��            6       True        REPLACEMENT         True
# 488      46353       �            3       True        REPLACEMENT         True
# 489      46500      t�            5       True              LATIN        False
# 490      46602       �            4       True        REPLACEMENT        False
# 491      46750       �            4       True        REPLACEMENT        False
# 492      46800       �            3       True        REPLACEMENT         True
# 493      46832       �            4       True        REPLACEMENT        False
# 494      46871      �示            6       True        REPLACEMENT        False
# 495      47378      ��            6       True        REPLACEMENT         True
# 496      47379      ��            6       True        REPLACEMENT         True
# 497      47455       �            4       True        REPLACEMENT        False
# 498      47665       �            4       True        REPLACEMENT        False
# 499      47911       �            4       True        REPLACEMENT        False
# 500      47972       �            3       True        REPLACEMENT         True
# 501      48108       �            4       True        REPLACEMENT        False
# 502      48312       �            3       True        REPLACEMENT         True
# 503      48364       �            4       True        REPLACEMENT        False
# 504      48458     �니다            9       True             HANGUL        False
# 505      48533       �            3       True        REPLACEMENT         True
# 506      48591       �            3       True        REPLACEMENT         True
# 507      48749       �            3       True        REPLACEMENT         True
# 508      48754       �            4       True        REPLACEMENT        False
# 509      48800      ��            6       True        REPLACEMENT         True
# 510      48840       �            4       True        REPLACEMENT        False
# 511      49128      া�            6       True            BENGALI        False
# 512      49166       �            3       True        REPLACEMENT         True
# 513      49173       �            3       True        REPLACEMENT         True
# 514      49420       �            3       True        REPLACEMENT         True
# 515      49434       �            4       True        REPLACEMENT        False
# 516      49602       �            4       True        REPLACEMENT        False
# 517      49943       �            3       True        REPLACEMENT         True
# 518      50102      选�            6       True                CJK        False
# 519      50111       �            3       True        REPLACEMENT         True
# 520      50362    ��이터           12       True        REPLACEMENT        False
# 521      51088     �始化            9       True                CJK        False
# 522      51275      ��            6       True        REPLACEMENT         True
# 523      51414       �            4       True        REPLACEMENT        False
# 524      51461       �            4       True        REPLACEMENT        False
# 525      51497       �            3       True        REPLACEMENT         True
# 526      52133       �            3       True        REPLACEMENT         True
# 527      52408       �            3       True        REPLACEMENT         True
# 528      52506       �            4       True        REPLACEMENT        False
# 529      52798       �            3       True        REPLACEMENT         True
# 530      52806      ্�            6       True            BENGALI        False
# 531      52887       �            3       True        REPLACEMENT         True
# 532      53025       �            4       True        REPLACEMENT        False
# 533      53496       �            3       True        REPLACEMENT         True
# 534      53497       �            4       True        REPLACEMENT        False
# 535      53556       �            3       True        REPLACEMENT         True
# 536      53599       �            4       True        REPLACEMENT        False
# 537      53989       �            4       True        REPLACEMENT        False
# 538      54128       �            3       True        REPLACEMENT         True
# 539      54470      �장            6       True        REPLACEMENT        False
# 540      54492      ��            6       True        REPLACEMENT         True
# 541      54599       �            4       True        REPLACEMENT        False
# 542      54642       �            3       True        REPLACEMENT         True
# 543      54699   обра�           11       True           CYRILLIC        False
# 544      54784      े�            6       True         DEVANAGARI        False
# 545      54955       �            4       True        REPLACEMENT        False
# 546      55059       �            4       True        REPLACEMENT        False
# 547      55729       �            4       True        REPLACEMENT        False
# 548      55838       �            4       True        REPLACEMENT        False
# 549      55890       �            3       True        REPLACEMENT         True
# 550      56252       �            3       True        REPLACEMENT         True
# 551      56823      ��            6       True        REPLACEMENT         True
# 552      56842       �            3       True        REPLACEMENT         True
# 553      57133      �력            6       True        REPLACEMENT        False
# 554      57154       �            3       True        REPLACEMENT         True
# 555      57160      ��            6       True        REPLACEMENT         True
# 556      57599       �            3       True        REPLACEMENT         True
# 557      57743       �            3       True        REPLACEMENT         True
# 558      58098      ��            6       True        REPLACEMENT         True
# 559      58169       �            3       True        REPLACEMENT         True
# 560      58208       �            4       True        REPLACEMENT        False
# 561      58230       �            4       True        REPLACEMENT        False
# 562      58299       �            3       True        REPLACEMENT         True
# 563      58464       �            4       True        REPLACEMENT        False
# 564      58522      �行            6       True        REPLACEMENT        False
# 565      58557       �            3       True        REPLACEMENT         True
# 566      58715      ��            6       True        REPLACEMENT         True
# 567      58899       �            3       True        REPLACEMENT         True
# 568      58994       �            3       True        REPLACEMENT         True
# 569      59053       �            4       True        REPLACEMENT        False
# 570      59139      �性            6       True        REPLACEMENT        False
# 571      60596       �            4       True        REPLACEMENT        False
# 572      60627       �            3       True        REPLACEMENT         True
# 573      60757      ��            6       True        REPLACEMENT         True
# 574      60864       �            3       True        REPLACEMENT         True
# 575      60985      실�            7       True             HANGUL        False
# 576      61617      �名            6       True        REPLACEMENT        False
# 577      61804       �            4       True        REPLACEMENT        False
# 578      62005       �            3       True        REPLACEMENT         True
# 579      62099       �            4       True        REPLACEMENT        False
# 580      62416       �            3       True        REPLACEMENT         True
# 581      62544      ��            6       True        REPLACEMENT         True
# 582      62618      �이            6       True        REPLACEMENT        False
# 583      62740       �            4       True        REPLACEMENT        False
# 584      62823       �            4       True        REPLACEMENT        False
# 585      63039       �            4       True        REPLACEMENT        False
# 586      63046      ��            6       True        REPLACEMENT         True
# 587      63219      ��            6       True        REPLACEMENT         True
# 588      63400      ்�            6       True              TAMIL        False
# 589      63761       �            3       True        REPLACEMENT         True
# 590      64388       �            4       True        REPLACEMENT        False
# 591      64520      ��            6       True        REPLACEMENT         True
# 592      64805       �            4       True        REPLACEMENT        False
# 593      64893       �            3       True        REPLACEMENT         True
# 594      65185       �            3       True        REPLACEMENT         True
# 595      65197       �            4       True        REPLACEMENT        False
# 596      65291      ��            6       True        REPLACEMENT         True
# 597      65456       �            4       True        REPLACEMENT        False
# 598      65519     ��제            9       True        REPLACEMENT        False
# 599      65553       �            4       True        REPLACEMENT        False
# 600      65699       �            4       True        REPLACEMENT        False
# 601      65722       �            4       True        REPLACEMENT        False
# 602      65727       �            4       True        REPLACEMENT        False
# 603      65850       �            3       True        REPLACEMENT         True
# 604      65877       �            3       True        REPLACEMENT         True
# 605      66118       �            3       True        REPLACEMENT         True
# ...
# 1221    124582       �            3       True        REPLACEMENT         True
# 1222    124583       �            3       True        REPLACEMENT         True
# 1223    124584       �            3       True        REPLACEMENT         True
# 1224    124585       �            3       True        REPLACEMENT         True
# 1225    124586       �            3       True        REPLACEMENT         True
# 1226    124587       �            3       True        REPLACEMENT         True
# 1227    124588       �            3       True        REPLACEMENT         True
# 1228    124589       �            3       True        REPLACEMENT         True
# 1229    124590       �            3       True        REPLACEMENT         True
# 1230    124591       �            3       True        REPLACEMENT         True
# 1231    124592       �            3       True        REPLACEMENT         True
# 1232    124593       �            3       True        REPLACEMENT         True
# 1233    124594       �            3       True        REPLACEMENT         True
# 1234    124595       �            3       True        REPLACEMENT         True
# 1235    124596       �            3       True        REPLACEMENT         True
# 1236    124693      사�            7       True             HANGUL        False
# 1237    124727       �            3       True        REPLACEMENT         True
# 1238    124744       �            3       True        REPLACEMENT         True
# 1239    124745       �            3       True        REPLACEMENT         True
# 1240    124746       �            3       True        REPLACEMENT         True
# 1241    124747       �            3       True        REPLACEMENT         True
# 1242    124748       �            3       True        REPLACEMENT         True
# 1243    124749       �            3       True        REPLACEMENT         True
# 1244    124750       �            3       True        REPLACEMENT         True
# 1245    124751       �            3       True        REPLACEMENT         True
# 1246    124752       �            3       True        REPLACEMENT         True
# 1247    124753       �            3       True        REPLACEMENT         True
# 1248    124754       �            3       True        REPLACEMENT         True
# 1249    124755       �            3       True        REPLACEMENT         True
# 1250    124995       �            3       True        REPLACEMENT         True
# 1251    124996       �            3       True        REPLACEMENT         True
# 1252    124997       �            3       True        REPLACEMENT         True
# 1253    124998       �            3       True        REPLACEMENT         True
# 1254    124999       �            3       True        REPLACEMENT         True
# 1255    125000       �            3       True        REPLACEMENT         True
# 1256    125001       �            3       True        REPLACEMENT         True
# 1257    125002       �            3       True        REPLACEMENT         True
# 1258    125003       �            3       True        REPLACEMENT         True
# 1259    125004       �            3       True        REPLACEMENT         True
# 1260    125388      っ�            6       True           HIRAGANA        False
# 1261    125413       �            3       True        REPLACEMENT         True
# 1262    125414       �            3       True        REPLACEMENT         True
# 1263    125415       �            3       True        REPLACEMENT         True
# 1264    125416       �            3       True        REPLACEMENT         True
# 1265    125417       �            3       True        REPLACEMENT         True
# 1266    125418       �            3       True        REPLACEMENT         True
# 1267    125419       �            3       True        REPLACEMENT         True
# 1268    125420       �            3       True        REPLACEMENT         True
# 1269    125421       �            3       True        REPLACEMENT         True
# 1270    125422       �            3       True        REPLACEMENT         True
# 1271    125423       �            3       True        REPLACEMENT         True
# 1272    125424       �            3       True        REPLACEMENT         True
# 1273    125425       �            3       True        REPLACEMENT         True
# 1274    125426       �            3       True        REPLACEMENT         True
# 1275    125427       �            3       True        REPLACEMENT         True
# 1276    125428       �            3       True        REPLACEMENT         True
# 1277    125429       �            3       True        REPLACEMENT         True
# 1278    125430       �            3       True        REPLACEMENT         True
# 1279    125639       �            4       True        REPLACEMENT        False
# 1280    125713       �            4       True        REPLACEMENT        False
# 1281    126159       �            3       True        REPLACEMENT         True
# 1282    126177       �            3       True        REPLACEMENT         True
# 1283    126178       �            3       True        REPLACEMENT         True
# 1284    126179       �            3       True        REPLACEMENT         True
# 1285    126180       �            3       True        REPLACEMENT         True
# 1286    126181       �            3       True        REPLACEMENT         True
# 1287    126182       �            3       True        REPLACEMENT         True
# 1288    126183       �            3       True        REPLACEMENT         True
# 1289    126184       �            3       True        REPLACEMENT         True
# 1290    126185       �            3       True        REPLACEMENT         True
# 1291    126186       �            3       True        REPLACEMENT         True
# 1292    126187       �            3       True        REPLACEMENT         True
# 1293    126188       �            3       True        REPLACEMENT         True
# 1294    126189       �            3       True        REPLACEMENT         True
# 1295    126190       �            3       True        REPLACEMENT         True
# 1296    126191       �            3       True        REPLACEMENT         True
# 1297    126192       �            3       True        REPLACEMENT         True
# 1298    126193       �            3       True        REPLACEMENT         True
# 1299    126365       �            4       True        REPLACEMENT        False
# 1300    126537      어�            7       True             HANGUL        False
# 1301    127041       �            4       True        REPLACEMENT        False
# 1302    127124      に�            6       True           HIRAGANA        False
# 1303    127165       �            4       True        REPLACEMENT        False
# 1304    127572      ו�            5       True             HEBREW        False
# 1305    127708      一�            6       True                CJK        False
# 1306    127819       �            4       True        REPLACEMENT        False
# 1307    127964      ��            6       True        REPLACEMENT         True
# 1308    128222       �            3       True        REPLACEMENT         True
# 1309    128223       �            3       True        REPLACEMENT         True
# 1310    128224       �            3       True        REPLACEMENT         True
# 1311    128225       �            3       True        REPLACEMENT         True
# 1312    128226       �            3       True        REPLACEMENT         True
# 1313    128227       �            3       True        REPLACEMENT         True
# 1314    128228       �            3       True        REPLACEMENT         True
# 1315    128229       �            3       True        REPLACEMENT         True
# 1316    128230       �            3       True        REPLACEMENT         True
# 1317    128231       �            3       True        REPLACEMENT         True
# 1318    128232       �            3       True        REPLACEMENT         True
# 1319    128233       �            3       True        REPLACEMENT         True
# 1320    128234       �            3       True        REPLACEMENT         True
# 1321    128235       �            3       True        REPLACEMENT         True
# 1322    128236       �            3       True        REPLACEMENT         True
# 1323    128237       �            3       True        REPLACEMENT         True
# 1324    128238       �            3       True        REPLACEMENT         True
# 1325    128239       �            3       True        REPLACEMENT         True
# 1326    128240       �            3       True        REPLACEMENT         True
# 1327    128241       �            3       True        REPLACEMENT         True
# 1328    128242       �            3       True        REPLACEMENT         True
# 1329    129176     サー�            9       True           KATAKANA        False
# 1330    130507       �            4       True        REPLACEMENT        False
# 1331    132202     楽し�            9       True                CJK        False
# 1332    132376       �            4       True        REPLACEMENT        False
# 1333    133552       �            4       True        REPLACEMENT        False
# 1334    134312       �            4       True        REPLACEMENT        False
# 1335    134380      簡�            6       True                CJK        False
# 1336    134582       �            4       True        REPLACEMENT        False
# 1337    135078      ご�            6       True           HIRAGANA        False
# 1338    136279     メー�            9       True           KATAKANA        False
# 1339    136516   インター�           15       True           KATAKANA        False
# 1340    136661     テー�            9       True           KATAKANA        False
# 1341    136940    スポー�           12       True           KATAKANA        False
# 1342    136946     スー�            9       True           KATAKANA        False
# 1343    137345     ユー�            9       True           KATAKANA        False
# 1344    137661      ש�            5       True             HEBREW        False
# 1345    137767       �            4       True        REPLACEMENT        False
# 1346    137973      に�            6       True           HIRAGANA        False
# 1347    138658       �            4       True        REPLACEMENT        False
# 1348    139816      ご�            6       True           HIRAGANA        False
# 1349    140356      気�            6       True                CJK        False
# 1350    141539       �            4       True        REPLACEMENT        False
# 1351    142067       �            4       True        REPLACEMENT        False
# 1352    142209      오�            7       True             HANGUL        False
# 1353    142210      오�            7       True             HANGUL        False
# 1354    142258     コー�            9       True           KATAKANA        False
# 1355    142274     パー�            9       True           KATAKANA        False
# 1356    142451       �            4       True        REPLACEMENT        False
# 1357    142509       �            4       True        REPLACEMENT        False
# 1358    142731     ケー�            9       True           KATAKANA        False
# 1359    142834      お�            6       True           HIRAGANA        False
# 1360    143241       �            4       True        REPLACEMENT        False
# 1361    143861       �            4       True        REPLACEMENT        False
# 1362    143887     久し�            9       True                CJK        False
# 1363    145773       �            3       True        REPLACEMENT         True
# 1364    146047       �            3       True        REPLACEMENT         True
# 1365    146632       �            3       True        REPLACEMENT         True
# 1366    148462       �            3       True        REPLACEMENT         True
# 1367    148774       �            3       True        REPLACEMENT         True
# 1368    148827       �            3       True        REPLACEMENT         True
# 1369    148860       �            3       True        REPLACEMENT         True
# 1370    148864       �            3       True        REPLACEMENT         True
# 1371    148880       �            3       True        REPLACEMENT         True
# 1372    149175       �            3       True        REPLACEMENT         True
# 1373    149178       �            3       True        REPLACEMENT         True
# 1374    149287       �            3       True        REPLACEMENT         True
# 1375    149352       �            3       True        REPLACEMENT         True
# 1376    149392       �            3       True        REPLACEMENT         True
# 1377    149394       �            3       True        REPLACEMENT         True
# 1378    149589       �            3       True        REPLACEMENT         True
# 1379    149591       �            3       True        REPLACEMENT         True
# 1380    149593       �            3       True        REPLACEMENT         True
# 1381    149714       �            3       True        REPLACEMENT         True
# 1382    149716       �            3       True        REPLACEMENT         True
# 1383    149718       �            3       True        REPLACEMENT         True
# 1384    149721       �            3       True        REPLACEMENT         True
# 1385    149946       �            3       True        REPLACEMENT         True
# 1386    149961       �            3       True        REPLACEMENT         True
# 1387    149963       �            3       True        REPLACEMENT         True
# 1388    149990       �            3       True        REPLACEMENT         True
# 1389    150114       �            3       True        REPLACEMENT         True
# 1390    150151       �            3       True        REPLACEMENT         True
# 1391    150168       �            3       True        REPLACEMENT         True
# 1392    150195       �            3       True        REPLACEMENT         True
# 1393    150223       �            3       True        REPLACEMENT         True
# 1394    150270       �            3       True        REPLACEMENT         True
# 1395    150479       �            3       True        REPLACEMENT         True
# 1396    150579       �            3       True        REPLACEMENT         True
# 1397    150792       �            3       True        REPLACEMENT         True
# 1398    150794       �            3       True        REPLACEMENT         True
# 1399    150800       �            3       True        REPLACEMENT         True
# 1400    150802       �            3       True        REPLACEMENT         True
# 1401    150807       �            3       True        REPLACEMENT         True
# 1402    150809       �            3       True        REPLACEMENT         True
# 1403    150814       �            3       True        REPLACEMENT         True
# 1404    150817       �            3       True        REPLACEMENT         True
# 1405    150819       �            3       True        REPLACEMENT         True
# 1406    150821       �            3       True        REPLACEMENT         True
# 1407    150824       �            3       True        REPLACEMENT         True
# 1408    150829       �            3       True        REPLACEMENT         True
# 1409    150836       �            3       True        REPLACEMENT         True
# 1410    151233       �            3       True        REPLACEMENT         True
# 1411    151254       �            3       True        REPLACEMENT         True
# 1412    151264       �            3       True        REPLACEMENT         True
# 1413    151266       �            3       True        REPLACEMENT         True
# 1414    151268       �            3       True        REPLACEMENT         True
# 1415    151270       �            3       True        REPLACEMENT         True
# 1416    151272       �            3       True        REPLACEMENT         True
# 1417    151274       �            3       True        REPLACEMENT         True
# 1418    151276       �            3       True        REPLACEMENT         True
# 1419    151278       �            3       True        REPLACEMENT         True
# 1420    151282       �            3       True        REPLACEMENT         True
# 1421    151366       �            3       True        REPLACEMENT         True
# 1422    151560       �            3       True        REPLACEMENT         True

# %% [markdown]
# ## Sample by Category
#
# Let's look at some examples from each category to understand what these tokens actually are.

# %%
print("\n" + "="*60)
print("SAMPLE TOKENS BY CATEGORY")
print("="*60)

# Mojibake samples
if df['is_mojibake'].any():
    print(f"\nMojibake tokens (U+FFFD replacement characters):")
    mojibake_samples = df[df['is_mojibake']].head(10)
    for _, row in mojibake_samples.iterrows():
        print(f"  Token {row['token_id']:6d}: {repr(row['decoded'])}")

# Non-mojibake but non-printable
non_printable = df[~df['is_mojibake'] & ~df['printable']]
if len(non_printable) > 0:
    print(f"\nNon-printable but not mojibake:")
    for _, row in non_printable.head(10).iterrows():
        print(f"  Token {row['token_id']:6d}: {repr(row['decoded'])} (script: {row['script']})")

# Printable samples from each script
printable = df[df['printable']]
if len(printable) > 0:
    print(f"\nPrintable tokens by script:")
    for script in printable['script'].unique()[:5]:  # First 5 scripts
        print(f"\n  {script}:")
        script_samples = printable[printable['script'] == script].head(5)
        for _, row in script_samples.iterrows():
            print(f"    Token {row['token_id']:6d}: {repr(row['decoded'])}")
# Out:
# ============================================================
# SAMPLE TOKENS BY CATEGORY
# ============================================================
#
# Mojibake tokens (U+FFFD replacement characters):
#   Token     94: '�'
#   Token     95: '�'
#   Token     96: '�'
#   Token     97: '�'
#   Token     98: '�'
#   Token     99: '�'
#   Token    100: '�'
#   Token    101: '�'
#   Token    102: '�'
#   Token    103: '�'
#
# Non-printable but not mojibake:
#   Token  42476: '\x80�' (script: REPLACEMENT)
#
# Printable tokens by script:
#
#   REPLACEMENT:
#     Token     94: '�'
#     Token     95: '�'
#     Token     96: '�'
#     Token     97: '�'
#     Token     98: '�'
#
#   CYRILLIC:
#     Token   2226: 'о�'
#     Token   3648: 'а�'
#     Token   4175: 'е�'
#     Token  10768: 'ра�'
#     Token  24212: ' ра�'
#
#   HIRAGANA:
#     Token  20472: 'し�'
#     Token 125388: 'っ�'
#     Token 127124: 'に�'
#     Token 135078: 'ご�'
#     Token 137973: 'に�'
#
#   KATAKANA-HIRAGANA:
#     Token  24041: 'ー�'
#     Token  37148: 'ー�'
#
#   LATIN:
#     Token  25772: 'ư�'
#     Token  46500: ' t�'

# %% [markdown]
# ## Diagnosis
#
# **If most tokens are mojibake (U+FFFD):**
# - These are genuinely broken tokens (malformed UTF-8)
# - The round-trip test is correct
# - These tokens are truly unreachable
#
# **If most tokens are valid linguistic content:**
# - The round-trip test has false positives
# - These tokens might be reachable in other contexts
# - We need a better test for reachability
#
# **If mixed:**
# - Some tokens are genuinely broken
# - Others might be test artifacts
# - Need to investigate specific cases
